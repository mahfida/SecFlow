# %%
'''Main'''
import numpy as np
import pandas as pd
import os

'''Data Viz'''
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
import matplotlib as mpl

# %matplotlib inline

'''Data Prep'''
from sklearn import preprocessing as pp 
from sklearn.preprocessing import LabelEncoder, StandardScaler
from scipy.stats import pearsonr 
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold 
from sklearn.metrics import log_loss 
from sklearn.metrics import precision_recall_curve, average_precision_score 
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.metrics import confusion_matrix, classification_report 
from statistics import mean, stdev

from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB 
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# # Load UDP Benign and DDoS CIC2023 Flows

# %%
# Acquire Data
# Data here has all features
current_path = os.getcwd()

# BENIGN DATA FILES ***************************************
file1='dataset/Benign.csv'
benign = pd.read_csv(file1)
benign = benign[(benign['proto_type'] == 17)]
benign['attack'] = 0

# DDOS-VOLUMETRIC ATTACK ***********************************
file2='dataset/UDPFlood.csv'
udp = pd.read_csv(file2)
udp['attack'] = 1

# DDOS-TRANSPORT PROTOCOL VULNERABILITIES *******************
file3='dataset/UDPFrag.csv'
udp_frag = pd.read_csv(file3)
udp_frag['attack'] = 1

## CONCATE ALL THE RECORDS ************************************
frames = [benign, 
          udp, 
          udp_frag]

data = pd.concat(frames)

# %%
# Size of the data
print("Shape of data: ", data.shape)
# Attack wise size
print("Attack and Benign Records: ", data["attack"].value_counts())
# Out:
# Shape of data:  (79144, 34)
# Attack and Benign Records:  attack
# 1    65800
# 0    13344
# Name: count, dtype: int64

# %%
udp.shape
# Out:
# (39376, 34)

# %%
data.columns
# Out:
# Index(['ts', 'srcip', 'dstip', 'srcport', 'dstport', 'proto_type', 'sbytes',
#        'dbytes', 'flow_bytes', 'rate', 'srate', 'drate', 'spkts', 'dpkts',
#        'ttl', 'iat', 'max_iat', 'min_iat', 'total_duration',
#        'N_IN_Conn_P_Src_IP', 'N_IN_Conn_P_Dst_IP', 'avg_pkt_len', 'state_con',
#        'state_int', 'state_rst', 'fin_flag_number', 'syn_flag_number',
#        'psh_flag_number', 'ack_flag_number', 'urg_flag_number',
#        'ece_flag_number', 'cwr_flag_number', 'attack', 'x'],
#       dtype='object')

# %% [markdown]
# # Select parameters based on the model i.e. with or without time based features

# %%
# Features according to Importance
features =  ['flow_bytes', 'spkts','dpkts','ttl',
             'N_IN_Conn_P_Src_IP', 'N_IN_Conn_P_Dst_IP', 'avg_pkt_len']
best_features = data[features] 
target_features = data[['attack']]

# %% [markdown]
# ## Descriptio of the parametes
#
# **(1) N_IN_Conn_P_Src_IP**: number of packets sent from a source ip address (note src_ip_bytes is similar to it)
# **(2) N_IN_Conn_P_Dst_IP**: number of incoming packets to a destination ip address
# **(3) spkts**: number of packets transmitted by a source in a flow till now
# **(4) dpkts**: number of packets transmitted by a destination in a flow till now
# **(5) srate**: spkts/duration of flow
# **(6) drate**: dpkts/duration of flow
# **(7) avg_packet_len**: mean packet length in bytes in either direction of the a flow
# **(8) state_con**: if this is a TCP packet and not first packet in the flow, with RESET flag not on
# **(9) state_int**: 1, if this is first packet in a UDP flow
# **(10) state_rst**: if this is a TCP packet and reset flag is on, this is the thir flag in tcp
# **(11-17) Flags of TCP**: FIN, SYN, PUSH, URG, ECE, CWR, ACK

# %% [markdown]
# # Split Dataset into X and Y

# %%
# Split of  predictors and response variable
X= best_features
y= target_features

# %% [markdown]
# # Use StratifiedKFold with K=10

# %%
# Create  classifier object.
rf = RandomForestClassifier(n_estimators = 1, n_jobs=2, random_state=0, max_depth=8)  
n_splits = 10
# Create StratifiedKFold object.
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=1)
accu_stratified = []
conf_matrices = []  # Store confusion matrices
per_class_accuracies = []

# %%
# Create model with StratifiedKFold   
for train_index, test_index in skf.split(X, y):
    x_train_fold, x_test_fold = X.iloc[train_index], X.iloc[test_index]
    y_train_fold, y_test_fold = y.iloc[train_index], y.iloc[test_index]
    rf.fit(x_train_fold, y_train_fold)
    #accu_stratified.append(rf.score(x_test_fold, y_test_fold))

    # Compute confusion matrix
    conf_matrix = confusion_matrix(y_test_fold,rf.predict(x_test_fold))
    conf_matrices.append(conf_matrix)
    
    # Compute per-class accuracies
    per_class_accuracy = conf_matrix.diagonal() / conf_matrix.sum(axis=1)
    per_class_accuracies.append(per_class_accuracy)

# Convert lists to numpy arrays for easier manipulation
conf_matrices = np.array(conf_matrices)
per_class_accuracies = np.array(per_class_accuracies)
# Out:
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
# Plotting per-class accuracies

plt.figure(figsize=(10, 6))
for i, class_accuracy in enumerate(per_class_accuracies.T, 1):
    if(i==1):
        plt.plot(range(1, n_splits + 1), class_accuracy, marker='o', label=f'Benign', color='green',  linestyle='dashed', markersize=10)
        print("Accuracy of Attack Records: ", class_accuracy)
        print('\nMedian Accuracy of Attack Records:', np.median(class_accuracy)*100, '%')
        print('\nStandard Deviation of Attack Records:', stdev(class_accuracy))
    else:
        plt.plot(range(1, n_splits + 1), class_accuracy, marker='*', label=f'Attack', color='red',  linestyle='dotted', markersize=10)  
        print("Accuracy of Benign Records: ", class_accuracy)
        print('\nMedian Accuracy of Benign Records:', np.median(class_accuracy)*100, '%')
        print('\nStandard Deviation of Benign Records:', stdev(class_accuracy))
    
plt.title('')
plt.xlabel('Fold', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)
plt.xticks(range(1, n_splits + 1))
plt.tick_params(axis='both', which='major', labelsize=16)
plt.tick_params(axis='both', which='minor', labelsize=16)
plt.legend()
plt.grid(True)
# Save the plot as a PNG file
plt.savefig('StratifiedKFold_5Tree.png', bbox_inches='tight')
plt.show()
# Out:
# Accuracy of Attack Records:  [0.99550562 0.97752809 0.98426966 0.99475655 0.97301349 0.99475262
#  0.9910045  0.99325337 0.99325337 0.98875562]
#
# Median Accuracy of Attack Records: 99.21289355322338 %
#
# Standard Deviation of Attack Records: 0.007865793984337257
# Accuracy of Benign Records:  [0.98860182 0.9843465  0.9893617  0.99057751 0.98844985 0.98829787
#  0.98966565 0.98723404 0.98951368 0.98966565]
#
# Median Accuracy of Benign Records: 98.89817629179332 %
#
# Standard Deviation of Benign Records: 0.0017531082977394119

# %% [markdown]
# # Training model on the whole dataset

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import SelectFromModel
rf = RandomForestClassifier(n_estimators = 1, n_jobs=2, random_state=0, max_depth=8)
rf.fit(X, y)
# Out:
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(max_depth=8, n_estimators=1, n_jobs=2, random_state=0)

# %% [markdown]
# # Mean Decrease of Accuracy of the Parameters

# %%
best_features.rename(columns={"N_IN_Conn_P_Src_IP": "N_IN_Conn_Src_IP", "N_IN_Conn_P_Dst_IP": "N_IN_Conn_Dst_IP"})
labels = best_features.columns

importances = list(rf.feature_importances_)
print(importances)
colors = (0.2, # redness
         0.4, # greenness
         0.2, # blueness
         0.6 # transparency
         ) 
# Sort feature importances in descending order
sorted_indices = np.argsort(importances)[::-1]
sorted_list =[importances[i] for i in sorted_indices]
# Plot feature importances
plt.figure(figsize=(10, 6))
plt.title('')
plt.barh(range(X.shape[1]), sorted_list, align="center",color=colors )
plt.yticks(range(X.shape[1]), labels[sorted_indices], fontsize=12)
plt.xlabel("Importance", fontsize=16)
plt.ylabel("Features", fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=12)
plt.tick_params(axis='both', which='minor', labelsize=12)
# Save the plot as a PNG file
plt.savefig('Importance.png', bbox_inches='tight')
plt.show()
# Out:
# [np.float64(0.5350603853088947), np.float64(0.024668793962426876), np.float64(0.005317370828913993), np.float64(0.05890488421887631), np.float64(0.1023148231194941), np.float64(0.0723342151059176), np.float64(0.20139952745547635)]

# %% [markdown]
# # Generate Tree

# %%
from sklearn import tree
from sklearn.tree import export_text
i_tree = 0
for tree_in_forest in rf.estimators_:
    with open('tree_' + str(i_tree) + '.dot', 'w') as my_file:
        my_file = tree.export_graphviz(tree_in_forest, out_file = my_file)
        r = export_text(tree_in_forest)
        print("TREE ", i_tree)
        print(r)  
    i_tree = i_tree + 1
# Out:
# TREE  0
# |--- feature_0 <= 5790.50
# |   |--- feature_3 <= 118.00
# |   |   |--- feature_6 <= 50.44
# |   |   |   |--- feature_6 <= 48.00
# |   |   |   |   |--- feature_0 <= 66.00
# |   |   |   |   |   |--- feature_5 <= 1.50
# |   |   |   |   |   |   |--- feature_3 <= 33.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_3 >  33.50
# |   |   |   |   |   |   |   |--- feature_6 <= 44.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_6 >  44.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_5 >  1.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- feature_0 >  66.00
# |   |   |   |   |   |--- feature_5 <= 1.50
# |   |   |   |   |   |   |--- feature_4 <= 3.50
# |   |   |   |   |   |   |   |--- feature_1 <= 7.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_1 >  7.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_4 >  3.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_5 >  1.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- feature_6 >  48.00
# |   |   |   |   |--- feature_0 <= 828.00
# |   |   |   |   |   |--- feature_5 <= 4.50
# |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |--- feature_0 <= 125.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_0 >  125.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |--- feature_3 <= 57.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_3 >  57.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_5 >  4.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- feature_0 >  828.00
# |   |   |   |   |   |--- feature_3 <= 57.00
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_3 >  57.00
# |   |   |   |   |   |   |--- feature_1 <= 54.50
# |   |   |   |   |   |   |   |--- feature_1 <= 16.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_1 >  16.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_1 >  54.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |--- feature_6 >  50.44
# |   |   |   |--- feature_6 <= 1453.00
# |   |   |   |   |--- feature_0 <= 66.00
# |   |   |   |   |   |--- feature_3 <= 48.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_3 >  48.50
# |   |   |   |   |   |   |--- feature_0 <= 54.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_0 >  54.50
# |   |   |   |   |   |   |   |--- feature_4 <= 5.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_4 >  5.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- feature_0 >  66.00
# |   |   |   |   |   |--- feature_5 <= 1.50
# |   |   |   |   |   |   |--- feature_2 <= 16.50
# |   |   |   |   |   |   |   |--- feature_6 <= 57.78
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_6 >  57.78
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_2 >  16.50
# |   |   |   |   |   |   |   |--- feature_0 <= 2879.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_0 >  2879.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_5 >  1.50
# |   |   |   |   |   |   |--- feature_4 <= 1.50
# |   |   |   |   |   |   |   |--- feature_1 <= 3.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_1 >  3.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_4 >  1.50
# |   |   |   |   |   |   |   |--- feature_1 <= 1.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_1 >  1.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- feature_6 >  1453.00
# |   |   |   |   |--- class: 1.0
# |   |--- feature_3 >  118.00
# |   |   |--- feature_4 <= 1.50
# |   |   |   |--- feature_0 <= 422.50
# |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |--- feature_0 <= 147.50
# |   |   |   |   |   |   |--- feature_5 <= 2.50
# |   |   |   |   |   |   |   |--- feature_0 <= 75.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_0 >  75.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_5 >  2.50
# |   |   |   |   |   |   |   |--- feature_0 <= 84.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_0 >  84.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_0 >  147.50
# |   |   |   |   |   |   |--- feature_0 <= 191.00
# |   |   |   |   |   |   |   |--- feature_5 <= 4.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_5 >  4.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_0 >  191.00
# |   |   |   |   |   |   |   |--- feature_0 <= 207.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_0 >  207.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |--- feature_1 <= 1.50
# |   |   |   |   |   |   |--- feature_6 <= 88.00
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_6 >  88.00
# |   |   |   |   |   |   |   |--- feature_3 <= 125.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_3 >  125.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_1 >  1.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- feature_0 >  422.50
# |   |   |   |   |--- feature_2 <= 1.00
# |   |   |   |   |   |--- feature_6 <= 357.15
# |   |   |   |   |   |   |--- feature_0 <= 1404.00
# |   |   |   |   |   |   |   |--- feature_6 <= 103.82
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_6 >  103.82
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_0 >  1404.00
# |   |   |   |   |   |   |   |--- feature_1 <= 7.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_1 >  7.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_6 >  357.15
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- feature_2 >  1.00
# |   |   |   |   |   |--- feature_5 <= 4.00
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_5 >  4.00
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |--- feature_4 >  1.50
# |   |   |   |--- feature_1 <= 3.50
# |   |   |   |   |--- feature_3 <= 125.50
# |   |   |   |   |   |--- feature_6 <= 158.50
# |   |   |   |   |   |   |--- feature_6 <= 132.00
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_6 >  132.00
# |   |   |   |   |   |   |   |--- feature_5 <= 4.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_5 >  4.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_6 >  158.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- feature_3 >  125.50
# |   |   |   |   |   |--- feature_3 <= 181.50
# |   |   |   |   |   |   |--- feature_6 <= 88.00
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_6 >  88.00
# |   |   |   |   |   |   |   |--- feature_0 <= 597.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_0 >  597.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_3 >  181.50
# |   |   |   |   |   |   |--- feature_5 <= 4.50
# |   |   |   |   |   |   |   |--- feature_4 <= 2.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_4 >  2.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_5 >  4.50
# |   |   |   |   |   |   |   |--- feature_4 <= 2.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_4 >  2.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- feature_1 >  3.50
# |   |   |   |   |--- feature_6 <= 83.45
# |   |   |   |   |   |--- feature_6 <= 83.20
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_6 >  83.20
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- feature_6 >  83.45
# |   |   |   |   |   |--- class: 0.0
# |--- feature_0 >  5790.50
# |   |--- feature_4 <= 9.50
# |   |   |--- feature_1 <= 163.50
# |   |   |   |--- feature_0 <= 17886.00
# |   |   |   |   |--- feature_5 <= 11.50
# |   |   |   |   |   |--- feature_5 <= 3.50
# |   |   |   |   |   |   |--- feature_5 <= 1.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_5 >  1.50
# |   |   |   |   |   |   |   |--- feature_6 <= 1140.62
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_6 >  1140.62
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_5 >  3.50
# |   |   |   |   |   |   |--- feature_4 <= 2.50
# |   |   |   |   |   |   |   |--- feature_5 <= 7.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_5 >  7.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_4 >  2.50
# |   |   |   |   |   |   |   |--- feature_6 <= 927.02
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_6 >  927.02
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- feature_5 >  11.50
# |   |   |   |   |   |--- feature_4 <= 1.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_4 >  1.50
# |   |   |   |   |   |   |--- feature_4 <= 2.50
# |   |   |   |   |   |   |   |--- feature_6 <= 132.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_6 >  132.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_4 >  2.50
# |   |   |   |   |   |   |   |--- feature_6 <= 140.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_6 >  140.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- feature_0 >  17886.00
# |   |   |   |   |--- class: 1.0
# |   |   |--- feature_1 >  163.50
# |   |   |   |--- feature_6 <= 786.00
# |   |   |   |   |--- feature_4 <= 4.50
# |   |   |   |   |   |--- feature_0 <= 18796.00
# |   |   |   |   |   |   |--- feature_6 <= 54.00
# |   |   |   |   |   |   |   |--- feature_2 <= 81.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_2 >  81.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_6 >  54.00
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_0 >  18796.00
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- feature_4 >  4.50
# |   |   |   |   |   |--- feature_1 <= 222.50
# |   |   |   |   |   |   |--- feature_5 <= 18.00
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_5 >  18.00
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_1 >  222.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- feature_6 >  786.00
# |   |   |   |   |--- class: 1.0
# |   |--- feature_4 >  9.50
# |   |   |--- class: 0.0

# %% [markdown]
# # Save the RF Attack Detector

# %%
import pickle as pickle
filename = 'udp_notime.sav'
pickle.dump(rf, open(filename, 'wb'))

# %% [markdown]
# # Display (Match-Action) Rules of the RF Tree, acceptable to P4

# %%
from io import StringIO
from numbers import Integral

import numpy as np
import pandas
import pickle 
import sklearn
from sklearn import tree 
from sklearn.tree import export_text

from sklearn.tree import _tree

from sklearn.tree import DecisionTreeClassifier

filename = 'udp_notime.sav'
rf = pickle.load(open(filename, 'rb'))

i_tree = 0 

global_id = 0

def export_p4(decision_tree):
    tree_ = decision_tree.tree_
    class_names = decision_tree.classes_
    right_child_fmt = "{} {} <= {}\n"
    left_child_fmt = "{} {} >  {}\n"
    truncation_fmt = "{} {}\n"
    feature_names_ = ["{}".format(i) for i in tree_.feature]  
    export_text.report = ""
    max_depth=10
    spacing=3
    decimals=2
    show_weights=False

    if isinstance(decision_tree, DecisionTreeClassifier):
        value_fmt = "{}{} weights: {}\n"
        if not show_weights:
            value_fmt = "{}{}{}\n"
    else:
        value_fmt = "{}{} value: {}\n"

    def _add_leaf(value, class_name, indent, prevfeature, result, depth, previous_id):
        global global_id
        global i_tree 
        current_id = global_id

        val = ''
        is_classification = isinstance(decision_tree,
                                       DecisionTreeClassifier)
        if show_weights or not is_classification:
            val = ["{1:.{0}f}, ".format(decimals, v) for v in value]
            val = '['+''.join(val)[:-2]+']'
        if is_classification:
            val += ' class: ' + str(class_name)
        export_text.report += value_fmt.format(indent, '', val)
        #print("table_add MyIngress.level_", i_tree,"_", depth, " ", "MyIngress.SetClass",i_tree," ", previous_id," ",prevfeature," ", result," ", "=>"," ", current_id, " ", int(float(class_name)), sep="")
        print("table_add MyIngress.UDPlevel_", depth, " ", "MyIngress.SetClassUDP"," ", previous_id," ",prevfeature," ", result," ", "=>"," ", current_id, " ", int(float(class_name)), sep="")

    def print_tree_recurse(node, depth, prevfeature, result, previous_id):
        indent = ("|" + (" " * spacing)) * depth
        indent = indent[:-spacing] + "-" * spacing
        global global_id
        global i_tree 
        global_id = global_id + 1
        current_id = global_id

        value = None
        if tree_.n_outputs == 1:
            value = tree_.value[node][0]
        else:
            value = tree_.value[node].T[0]
        class_name = np.argmax(value)

        if (tree_.n_classes[0] != 1 and
                tree_.n_outputs == 1):
            class_name = class_names[class_name]

        if depth <= max_depth+1:
            info_fmt = ""
            info_fmt_left = info_fmt
            info_fmt_right = info_fmt

            if tree_.feature[node] != _tree.TREE_UNDEFINED:
                name = feature_names_[node]
                threshold = tree_.threshold[node]
                threshold = "{1:.{0}f}".format(decimals, threshold)
                export_text.report += right_child_fmt.format(indent,
                                                             name,
                                                             threshold)
                export_text.report += info_fmt_left
                #print("table_add MyIngress.level_", i_tree,"_", depth, " MyIngress.CheckFeature ", previous_id, " ", prevfeature, " ", result, " ", "=>", " ", current_id, " ", name," ", int(float(threshold)), sep='')
                print("table_add MyIngress.UDPlevel_", depth, " MyIngress.CheckFeatureUDP ", previous_id, " ", prevfeature, " ", result, " ", "=>", " ", current_id, " ", name," ", int(float(threshold)), sep='')

                
                print_tree_recurse(tree_.children_left[node], depth+1, name, 1, current_id)

                export_text.report += left_child_fmt.format(indent,
                                                            name,
                                                            threshold)
                export_text.report += info_fmt_right
           #     print("level", depth, "checkfeature", prevfeature, result, "=>", name, threshold)
 

                print_tree_recurse(tree_.children_right[node], depth+1, name, 0, current_id)
            else:  # leaf
                _add_leaf(value, class_name, indent, prevfeature, result, depth, previous_id)
        else:
            subtree_depth = _compute_depth(tree_, node)
            if subtree_depth == 1:
                _add_leaf(value, class_name, indent, prevfeature, result, depth, previous_id)
            else:
                trunc_report = 'truncated branch of depth %d' % subtree_depth
                export_text.report += truncation_fmt.format(indent,
                                                            trunc_report)

    print_tree_recurse(0, 1, 0, 1, global_id)


for tree_in_forest in rf.estimators_:
  #r = export_text(tree_in_forest)
  #print(r)
  global i_tree

  i_tree = i_tree + 1
  export_p4(tree_in_forest)
# Out:
# table_add MyIngress.UDPlevel_1 MyIngress.CheckFeatureUDP 0 0 1 => 1 0 5790
# table_add MyIngress.UDPlevel_2 MyIngress.CheckFeatureUDP 1 0 1 => 2 3 118
# table_add MyIngress.UDPlevel_3 MyIngress.CheckFeatureUDP 2 3 1 => 3 6 50
# table_add MyIngress.UDPlevel_4 MyIngress.CheckFeatureUDP 3 6 1 => 4 6 48
# table_add MyIngress.UDPlevel_5 MyIngress.CheckFeatureUDP 4 6 1 => 5 0 66
# table_add MyIngress.UDPlevel_6 MyIngress.CheckFeatureUDP 5 0 1 => 6 5 1
# table_add MyIngress.UDPlevel_7 MyIngress.CheckFeatureUDP 6 5 1 => 7 3 33
# table_add MyIngress.UDPlevel_8 MyIngress.SetClassUDP 7 3 1 => 8 0
# table_add MyIngress.UDPlevel_8 MyIngress.CheckFeatureUDP 7 3 0 => 9 6 44
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 9 6 1 => 10 0
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 9 6 0 => 11 0
# table_add MyIngress.UDPlevel_7 MyIngress.SetClassUDP 6 5 0 => 12 0
# table_add MyIngress.UDPlevel_6 MyIngress.CheckFeatureUDP 5 0 0 => 13 5 1
# table_add MyIngress.UDPlevel_7 MyIngress.CheckFeatureUDP 13 5 1 => 14 4 3
# table_add MyIngress.UDPlevel_8 MyIngress.CheckFeatureUDP 14 4 1 => 15 1 7
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 15 1 1 => 16 0
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 15 1 0 => 17 0
# table_add MyIngress.UDPlevel_8 MyIngress.SetClassUDP 14 4 0 => 18 0
# table_add MyIngress.UDPlevel_7 MyIngress.SetClassUDP 13 5 0 => 19 1
# table_add MyIngress.UDPlevel_5 MyIngress.CheckFeatureUDP 4 6 0 => 20 0 828
# table_add MyIngress.UDPlevel_6 MyIngress.CheckFeatureUDP 20 0 1 => 21 5 4
# table_add MyIngress.UDPlevel_7 MyIngress.CheckFeatureUDP 21 5 1 => 22 2 0
# table_add MyIngress.UDPlevel_8 MyIngress.CheckFeatureUDP 22 2 1 => 23 0 125
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 23 0 1 => 24 0
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 23 0 0 => 25 1
# table_add MyIngress.UDPlevel_8 MyIngress.CheckFeatureUDP 22 2 0 => 26 3 57
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 26 3 1 => 27 0
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 26 3 0 => 28 0
# table_add MyIngress.UDPlevel_7 MyIngress.SetClassUDP 21 5 0 => 29 1
# table_add MyIngress.UDPlevel_6 MyIngress.CheckFeatureUDP 20 0 0 => 30 3 57
# table_add MyIngress.UDPlevel_7 MyIngress.SetClassUDP 30 3 1 => 31 0
# table_add MyIngress.UDPlevel_7 MyIngress.CheckFeatureUDP 30 3 0 => 32 1 54
# table_add MyIngress.UDPlevel_8 MyIngress.CheckFeatureUDP 32 1 1 => 33 1 16
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 33 1 1 => 34 0
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 33 1 0 => 35 1
# table_add MyIngress.UDPlevel_8 MyIngress.SetClassUDP 32 1 0 => 36 1
# table_add MyIngress.UDPlevel_4 MyIngress.CheckFeatureUDP 3 6 0 => 37 6 1453
# table_add MyIngress.UDPlevel_5 MyIngress.CheckFeatureUDP 37 6 1 => 38 0 66
# table_add MyIngress.UDPlevel_6 MyIngress.CheckFeatureUDP 38 0 1 => 39 3 48
# table_add MyIngress.UDPlevel_7 MyIngress.SetClassUDP 39 3 1 => 40 1
# table_add MyIngress.UDPlevel_7 MyIngress.CheckFeatureUDP 39 3 0 => 41 0 54
# table_add MyIngress.UDPlevel_8 MyIngress.SetClassUDP 41 0 1 => 42 0
# table_add MyIngress.UDPlevel_8 MyIngress.CheckFeatureUDP 41 0 0 => 43 4 5
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 43 4 1 => 44 1
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 43 4 0 => 45 0
# table_add MyIngress.UDPlevel_6 MyIngress.CheckFeatureUDP 38 0 0 => 46 5 1
# table_add MyIngress.UDPlevel_7 MyIngress.CheckFeatureUDP 46 5 1 => 47 2 16
# table_add MyIngress.UDPlevel_8 MyIngress.CheckFeatureUDP 47 2 1 => 48 6 57
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 48 6 1 => 49 0
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 48 6 0 => 50 0
# table_add MyIngress.UDPlevel_8 MyIngress.CheckFeatureUDP 47 2 0 => 51 0 2879
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 51 0 1 => 52 0
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 51 0 0 => 53 1
# table_add MyIngress.UDPlevel_7 MyIngress.CheckFeatureUDP 46 5 0 => 54 4 1
# table_add MyIngress.UDPlevel_8 MyIngress.CheckFeatureUDP 54 4 1 => 55 1 3
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 55 1 1 => 56 0
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 55 1 0 => 57 0
# table_add MyIngress.UDPlevel_8 MyIngress.CheckFeatureUDP 54 4 0 => 58 1 1
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 58 1 1 => 59 0
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 58 1 0 => 60 0
# table_add MyIngress.UDPlevel_5 MyIngress.SetClassUDP 37 6 0 => 61 1
# table_add MyIngress.UDPlevel_3 MyIngress.CheckFeatureUDP 2 3 0 => 62 4 1
# table_add MyIngress.UDPlevel_4 MyIngress.CheckFeatureUDP 62 4 1 => 63 0 422
# table_add MyIngress.UDPlevel_5 MyIngress.CheckFeatureUDP 63 0 1 => 64 2 0
# table_add MyIngress.UDPlevel_6 MyIngress.CheckFeatureUDP 64 2 1 => 65 0 147
# table_add MyIngress.UDPlevel_7 MyIngress.CheckFeatureUDP 65 0 1 => 66 5 2
# table_add MyIngress.UDPlevel_8 MyIngress.CheckFeatureUDP 66 5 1 => 67 0 75
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 67 0 1 => 68 1
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 67 0 0 => 69 0
# table_add MyIngress.UDPlevel_8 MyIngress.CheckFeatureUDP 66 5 0 => 70 0 84
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 70 0 1 => 71 0
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 70 0 0 => 72 0
# table_add MyIngress.UDPlevel_7 MyIngress.CheckFeatureUDP 65 0 0 => 73 0 191
# table_add MyIngress.UDPlevel_8 MyIngress.CheckFeatureUDP 73 0 1 => 74 5 4
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 74 5 1 => 75 1
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 74 5 0 => 76 0
# table_add MyIngress.UDPlevel_8 MyIngress.CheckFeatureUDP 73 0 0 => 77 0 207
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 77 0 1 => 78 0
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 77 0 0 => 79 0
# table_add MyIngress.UDPlevel_6 MyIngress.CheckFeatureUDP 64 2 0 => 80 1 1
# table_add MyIngress.UDPlevel_7 MyIngress.CheckFeatureUDP 80 1 1 => 81 6 88
# table_add MyIngress.UDPlevel_8 MyIngress.SetClassUDP 81 6 1 => 82 1
# table_add MyIngress.UDPlevel_8 MyIngress.CheckFeatureUDP 81 6 0 => 83 3 125
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 83 3 1 => 84 0
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 83 3 0 => 85 0
# table_add MyIngress.UDPlevel_7 MyIngress.SetClassUDP 80 1 0 => 86 0
# table_add MyIngress.UDPlevel_5 MyIngress.CheckFeatureUDP 63 0 0 => 87 2 1
# table_add MyIngress.UDPlevel_6 MyIngress.CheckFeatureUDP 87 2 1 => 88 6 357
# table_add MyIngress.UDPlevel_7 MyIngress.CheckFeatureUDP 88 6 1 => 89 0 1404
# table_add MyIngress.UDPlevel_8 MyIngress.CheckFeatureUDP 89 0 1 => 90 6 103
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 90 6 1 => 91 1
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 90 6 0 => 92 0
# table_add MyIngress.UDPlevel_8 MyIngress.CheckFeatureUDP 89 0 0 => 93 1 7
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 93 1 1 => 94 0
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 93 1 0 => 95 0
# table_add MyIngress.UDPlevel_7 MyIngress.SetClassUDP 88 6 0 => 96 1
# table_add MyIngress.UDPlevel_6 MyIngress.CheckFeatureUDP 87 2 0 => 97 5 4
# table_add MyIngress.UDPlevel_7 MyIngress.SetClassUDP 97 5 1 => 98 1
# table_add MyIngress.UDPlevel_7 MyIngress.SetClassUDP 97 5 0 => 99 0
# table_add MyIngress.UDPlevel_4 MyIngress.CheckFeatureUDP 62 4 0 => 100 1 3
# table_add MyIngress.UDPlevel_5 MyIngress.CheckFeatureUDP 100 1 1 => 101 3 125
# table_add MyIngress.UDPlevel_6 MyIngress.CheckFeatureUDP 101 3 1 => 102 6 158
# table_add MyIngress.UDPlevel_7 MyIngress.CheckFeatureUDP 102 6 1 => 103 6 132
# table_add MyIngress.UDPlevel_8 MyIngress.SetClassUDP 103 6 1 => 104 0
# table_add MyIngress.UDPlevel_8 MyIngress.CheckFeatureUDP 103 6 0 => 105 5 4
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 105 5 1 => 106 1
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 105 5 0 => 107 0
# table_add MyIngress.UDPlevel_7 MyIngress.SetClassUDP 102 6 0 => 108 0
# table_add MyIngress.UDPlevel_6 MyIngress.CheckFeatureUDP 101 3 0 => 109 3 181
# table_add MyIngress.UDPlevel_7 MyIngress.CheckFeatureUDP 109 3 1 => 110 6 88
# table_add MyIngress.UDPlevel_8 MyIngress.SetClassUDP 110 6 1 => 111 1
# table_add MyIngress.UDPlevel_8 MyIngress.CheckFeatureUDP 110 6 0 => 112 0 597
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 112 0 1 => 113 0
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 112 0 0 => 114 0
# table_add MyIngress.UDPlevel_7 MyIngress.CheckFeatureUDP 109 3 0 => 115 5 4
# table_add MyIngress.UDPlevel_8 MyIngress.CheckFeatureUDP 115 5 1 => 116 4 2
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 116 4 1 => 117 0
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 116 4 0 => 118 0
# table_add MyIngress.UDPlevel_8 MyIngress.CheckFeatureUDP 115 5 0 => 119 4 2
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 119 4 1 => 120 0
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 119 4 0 => 121 0
# table_add MyIngress.UDPlevel_5 MyIngress.CheckFeatureUDP 100 1 0 => 122 6 83
# table_add MyIngress.UDPlevel_6 MyIngress.CheckFeatureUDP 122 6 1 => 123 6 83
# table_add MyIngress.UDPlevel_7 MyIngress.SetClassUDP 123 6 1 => 124 0
# table_add MyIngress.UDPlevel_7 MyIngress.SetClassUDP 123 6 0 => 125 1
# table_add MyIngress.UDPlevel_6 MyIngress.SetClassUDP 122 6 0 => 126 0
# table_add MyIngress.UDPlevel_2 MyIngress.CheckFeatureUDP 1 0 0 => 127 4 9
# table_add MyIngress.UDPlevel_3 MyIngress.CheckFeatureUDP 127 4 1 => 128 1 163
# table_add MyIngress.UDPlevel_4 MyIngress.CheckFeatureUDP 128 1 1 => 129 0 17886
# table_add MyIngress.UDPlevel_5 MyIngress.CheckFeatureUDP 129 0 1 => 130 5 11
# table_add MyIngress.UDPlevel_6 MyIngress.CheckFeatureUDP 130 5 1 => 131 5 3
# table_add MyIngress.UDPlevel_7 MyIngress.CheckFeatureUDP 131 5 1 => 132 5 1
# table_add MyIngress.UDPlevel_8 MyIngress.SetClassUDP 132 5 1 => 133 1
# table_add MyIngress.UDPlevel_8 MyIngress.CheckFeatureUDP 132 5 0 => 134 6 1140
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 134 6 1 => 135 1
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 134 6 0 => 136 1
# table_add MyIngress.UDPlevel_7 MyIngress.CheckFeatureUDP 131 5 0 => 137 4 2
# table_add MyIngress.UDPlevel_8 MyIngress.CheckFeatureUDP 137 4 1 => 138 5 7
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 138 5 1 => 139 1
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 138 5 0 => 140 1
# table_add MyIngress.UDPlevel_8 MyIngress.CheckFeatureUDP 137 4 0 => 141 6 927
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 141 6 1 => 142 0
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 141 6 0 => 143 1
# table_add MyIngress.UDPlevel_6 MyIngress.CheckFeatureUDP 130 5 0 => 144 4 1
# table_add MyIngress.UDPlevel_7 MyIngress.SetClassUDP 144 4 1 => 145 0
# table_add MyIngress.UDPlevel_7 MyIngress.CheckFeatureUDP 144 4 0 => 146 4 2
# table_add MyIngress.UDPlevel_8 MyIngress.CheckFeatureUDP 146 4 1 => 147 6 132
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 147 6 1 => 148 1
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 147 6 0 => 149 0
# table_add MyIngress.UDPlevel_8 MyIngress.CheckFeatureUDP 146 4 0 => 150 6 140
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 150 6 1 => 151 1
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 150 6 0 => 152 0
# table_add MyIngress.UDPlevel_5 MyIngress.SetClassUDP 129 0 0 => 153 1
# table_add MyIngress.UDPlevel_4 MyIngress.CheckFeatureUDP 128 1 0 => 154 6 786
# table_add MyIngress.UDPlevel_5 MyIngress.CheckFeatureUDP 154 6 1 => 155 4 4
# table_add MyIngress.UDPlevel_6 MyIngress.CheckFeatureUDP 155 4 1 => 156 0 18796
# table_add MyIngress.UDPlevel_7 MyIngress.CheckFeatureUDP 156 0 1 => 157 6 54
# table_add MyIngress.UDPlevel_8 MyIngress.CheckFeatureUDP 157 6 1 => 158 2 81
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 158 2 1 => 159 1
# table_add MyIngress.UDPlevel_9 MyIngress.SetClassUDP 158 2 0 => 160 0
# table_add MyIngress.UDPlevel_8 MyIngress.SetClassUDP 157 6 0 => 161 0
# table_add MyIngress.UDPlevel_7 MyIngress.SetClassUDP 156 0 0 => 162 1
# table_add MyIngress.UDPlevel_6 MyIngress.CheckFeatureUDP 155 4 0 => 163 1 222
# table_add MyIngress.UDPlevel_7 MyIngress.CheckFeatureUDP 163 1 1 => 164 5 18
# table_add MyIngress.UDPlevel_8 MyIngress.SetClassUDP 164 5 1 => 165 0
# table_add MyIngress.UDPlevel_8 MyIngress.SetClassUDP 164 5 0 => 166 1
# table_add MyIngress.UDPlevel_7 MyIngress.SetClassUDP 163 1 0 => 167 1
# table_add MyIngress.UDPlevel_5 MyIngress.SetClassUDP 154 6 0 => 168 1
# table_add MyIngress.UDPlevel_3 MyIngress.SetClassUDP 127 4 0 => 169 0

# %% [markdown]
# # Now predicting about separatly processes data

# %%
current_path = os.getcwd()

file1='dataset/Benign_Test_1.csv'
benign = pd.read_csv(file1)
benign = benign[(benign['proto_type'] == 17)]

file2='dataset/UDPFlood_Test_2.csv'
udp = pd.read_csv(file2)
file3='dataset/UDPFrag_Test.csv'
udp_frag = pd.read_csv(file3)

benign['attack'] = 0
udp['attack'] = 1
udp_frag['attack'] = 1

# %%
data = pd.concat([benign])
print(data.columns)
# Out:
# Index(['ts', 'srcip', 'dstip', 'srcport', 'dstport', 'proto_type', 'sbytes',
#        'dbytes', 'flow_bytes', 'rate', 'srate', 'drate', 'spkts', 'dpkts',
#        'ttl', 'iat', 'max_iat', 'min_iat', 'total_duration',
#        'N_IN_Conn_P_Src_IP', 'N_IN_Conn_P_Dst_IP', 'avg_pkt_len', 'state_con',
#        'state_int', 'state_rst', 'fin_flag_number', 'syn_flag_number',
#        'psh_flag_number', 'ack_flag_number', 'urg_flag_number',
#        'ece_flag_number', 'cwr_flag_number', 'attack'],
#       dtype='object')

# %%
benign['sbytes'].head(10)
# Out:
# 31      214
# 53      230
# 61      218
# 92      230
# 95      336
# 97      300
# 98      609
# 99      999
# 100    1389
# 101     388
# Name: sbytes, dtype: int64

# %% [markdown]
# # Test Benign

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_fscore_support

data = pd.concat([benign])
best_features = data[features]
target_features = data[['attack']]
prediction = rf.predict(best_features)
print("Accuracy:", 1- sum(prediction)/len(prediction))
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(target_features, prediction)
# Print the results for each class
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", fscore)
print("Support: ", support)
# Out:
# Accuracy: 0.9851851851851852
# Precision:  [1. 0.]
# Recall:  [0.98518519 0.        ]
# F1-score:  [0.99253731 0.        ]
# Support:  [135   0]
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # Test UDP Flood

# %%
data = pd.concat([udp])
best_features = data[features]
target_features = data[['attack']]
prediction = rf.predict(best_features)
print("Accuracy:",  sum(prediction)/len(prediction))
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(target_features, prediction)
# Print the results for each class
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", fscore)
print("Support: ", support)
# Out:
# Accuracy: 0.9860792412421601
# Precision:  [0. 1.]
# Recall:  [0.         0.98607924]
# F1-score:  [0.         0.99299083]
# Support:  [    0 13074]
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # Test UDP Frag

# %%
data = pd.concat([udp_frag])
best_features = data[features]
target_features = data[['attack']]
prediction = rf.predict(best_features)
print("Accuracy:",  sum(prediction)/len(prediction))
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(target_features, prediction)
# Print the results for each class
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", fscore)
print("Support: ", support)
# Out:
# Accuracy: 0.9961977186311787
# Precision:  [0. 1.]
# Recall:  [0.         0.99619772]
# F1-score:  [0.         0.99809524]
# Support:  [  0 526]
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
