# %%
'''Main'''
import numpy as np
import pandas as pd
import os

'''Data Viz'''
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
import matplotlib as mpl

# %matplotlib inline

'''Data Prep'''
from sklearn import preprocessing as pp 
from sklearn.preprocessing import LabelEncoder, StandardScaler
from scipy.stats import pearsonr 
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold 
from sklearn.metrics import log_loss 
from sklearn.metrics import precision_recall_curve, average_precision_score 
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.metrics import confusion_matrix, classification_report 
from statistics import mean, stdev

from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB 
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# # Load TCP Benign and DDoS CIC2023 Flows

# %%
# Acquire Data
# Data here has all features
current_path = os.getcwd()

# BENIGN DATA FILES ***************************************
file1='dataset/Benign.csv'
benign = pd.read_csv(file1)
benign = benign[(benign['proto_type'] == 6)]
benign['attack'] = 0

# DDOS-VOLUMETRIC ATTACK ***********************************
file2='dataset/TCPFlood.csv'
tcp = pd.read_csv(file2)
tcp['attack'] = 1

# DDOS-TRANSPORT PROTOCOL VULNERABILITIES *******************
file3='dataset/ACKFrag.csv'
file4='dataset/SYN.csv'
file5='dataset/RSTFIN.csv'
file6='dataset/PUSHACK.csv'

ack = pd.read_csv(file3)
syn = pd.read_csv(file4)
rst = pd.read_csv(file5)
psh = pd.read_csv(file6)


ack['attack'] = 1
syn['attack'] = 1
rst['attack'] = 1
psh['attack'] = 1


# DDOS-APPLICATION PROTOCOL VULNERABILITIES *******************
file91='dataset/HTTPFlood.csv'
file92='dataset/Slowloris.csv'
http = pd.read_csv(file91)
slow = pd.read_csv(file92)
http['attack'] = 1
slow['attack'] = 1

## CONCATE ALL THE RECORDS ************************************
frames = [benign, 
          tcp,
          syn, rst, ack, psh, 
          http, slow]

data = pd.concat(frames)

# %%
# Size of the data
print("Shape of data: ", data.shape)
# Attack wise size
print("Attack and Benign Records: ", data["attack"].value_counts())
# Out:
# Shape of data:  (309107, 34)
# Attack and Benign Records:  attack
# 1    226482
# 0     82625
# Name: count, dtype: int64

# %%
tcp.shape
# Out:
# (43324, 34)

# %%
data.columns
# Out:
# Index(['ts', 'srcip', 'dstip', 'srcport', 'dstport', 'proto_type', 'sbytes',
#        'dbytes', 'flow_bytes', 'rate', 'srate', 'drate', 'spkts', 'dpkts',
#        'ttl', 'iat', 'max_iat', 'min_iat', 'total_duration',
#        'N_IN_Conn_P_Src_IP', 'N_IN_Conn_P_Dst_IP', 'avg_pkt_len', 'state_con',
#        'state_int', 'state_rst', 'fin_flag_number', 'syn_flag_number',
#        'psh_flag_number', 'ack_flag_number', 'urg_flag_number',
#        'ece_flag_number', 'cwr_flag_number', 'attack', 'x'],
#       dtype='object')

# %% [markdown]
# # Select parameters based on the model i.e. with or without time based features

# %%
# Features according to Importance
features =  [
             'flow_bytes', 'spkts','dpkts','ttl',
             'N_IN_Conn_P_Src_IP', 'N_IN_Conn_P_Dst_IP', 'avg_pkt_len',
             'state_con', 
             'state_rst',
             'fin_flag_number', 'syn_flag_number',
             'psh_flag_number', 'ack_flag_number', 
            ]
best_features = data[features] 
target_features = data[['attack']]

# %% [markdown]
# ## Descriptio of the parametes
#
# **(1) N_IN_Conn_P_Src_IP**: number of packets sent from a source ip address (note src_ip_bytes is similar to it)
# **(2) N_IN_Conn_P_Dst_IP**: number of incoming packets to a destination ip address
# **(3) spkts**: number of packets transmitted by a source in a flow till now
# **(4) dpkts**: number of packets transmitted by a destination in a flow till now
# **(5) srate**: spkts/duration of flow
# **(6) drate**: dpkts/duration of flow
# **(7) avg_packet_len**: mean packet length in bytes in either direction of the a flow
# **(8) state_con**: if this is a TCP packet and not first packet in the flow, with RESET flag not on
# **(9) state_int**: 1, if this is first packet in a UDP flow
# **(10) state_rst**: if this is a TCP packet and reset flag is on, this is the thir flag in tcp
# **(11-17) Flags of TCP**: FIN, SYN, PUSH, URG, ECE, CWR, ACK

# %% [markdown]
# # Split Dataset into X and Y

# %%
# Split of  predictors and response variable
X= best_features
y= target_features

# %% [markdown]
# # Use StratifiedKFold with K=10

# %%
# Create  classifier object.
rf = RandomForestClassifier(n_estimators = 1, n_jobs=2, random_state=0, max_depth=10)  
n_splits = 10
# Create StratifiedKFold object.
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=1)
accu_stratified = []
conf_matrices = []  # Store confusion matrices
per_class_accuracies = []

# %%
# Create model with StratifiedKFold   
for train_index, test_index in skf.split(X, y):
    x_train_fold, x_test_fold = X.iloc[train_index], X.iloc[test_index]
    y_train_fold, y_test_fold = y.iloc[train_index], y.iloc[test_index]
    rf.fit(x_train_fold, y_train_fold)
    #accu_stratified.append(rf.score(x_test_fold, y_test_fold))

    # Compute confusion matrix
    conf_matrix = confusion_matrix(y_test_fold,rf.predict(x_test_fold))
    conf_matrices.append(conf_matrix)
    
    # Compute per-class accuracies
    per_class_accuracy = conf_matrix.diagonal() / conf_matrix.sum(axis=1)
    per_class_accuracies.append(per_class_accuracy)

# Convert lists to numpy arrays for easier manipulation
conf_matrices = np.array(conf_matrices)
per_class_accuracies = np.array(per_class_accuracies)
# Out:
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
# Plotting per-class accuracies

plt.figure(figsize=(10, 6))
for i, class_accuracy in enumerate(per_class_accuracies.T, 1):
    if(i==1):
        plt.plot(range(1, n_splits + 1), class_accuracy, marker='o', label=f'Benign', color='green',  linestyle='dashed', markersize=10)
        print("Accuracy of Attack Records: ", class_accuracy)
        print('\nMedian Accuracy of Attack Records:', np.median(class_accuracy)*100, '%')
        print('\nStandard Deviation of Attack Records:', stdev(class_accuracy))
    else:
        plt.plot(range(1, n_splits + 1), class_accuracy, marker='*', label=f'Attack', color='red',  linestyle='dotted', markersize=10)  
        print("Accuracy of Benign Records: ", class_accuracy)
        print('\nMedian Accuracy of Benign Records:', np.median(class_accuracy)*100, '%')
        print('\nStandard Deviation of Benign Records:', stdev(class_accuracy))
    
plt.title('')
plt.xlabel('Fold', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)
plt.xticks(range(1, n_splits + 1))
plt.tick_params(axis='both', which='major', labelsize=16)
plt.tick_params(axis='both', which='minor', labelsize=16)
plt.legend()
plt.grid(True)
# Save the plot as a PNG file
plt.savefig('StratifiedKFold_5Tree.png', bbox_inches='tight')
plt.show()
# Out:
# Accuracy of Attack Records:  [0.96066804 0.98196781 0.9745855  0.98027351 0.96696115 0.97760833
#  0.95715323 0.96247882 0.97555071 0.92628903]
#
# Median Accuracy of Attack Records: 97.07733268788576 %
#
# Standard Deviation of Attack Records: 0.016512999013473927
# Accuracy of Benign Records:  [0.93217944 0.93156129 0.92312787 0.92524726 0.92414341 0.9249415
#  0.93297717 0.93120805 0.917432   0.94719181]
#
# Median Accuracy of Benign Records: 92.82276580713528 %
#
# Standard Deviation of Benign Records: 0.008101752844131333

# %% [markdown]
# # Training model on the whole dataset

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import SelectFromModel
rf = RandomForestClassifier(n_estimators = 1, n_jobs=2, random_state=0, max_depth=10)
rf.fit(X, y)
# Out:
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(max_depth=10, n_estimators=1, n_jobs=2, random_state=0)

# %% [markdown]
# # Mean Decrease of Accuracy of the Parameters

# %%
best_features.rename(columns={"N_IN_Conn_P_Src_IP": "N_IN_Conn_Src_IP", "N_IN_Conn_P_Dst_IP": "N_IN_Conn_Dst_IP"})
labels = best_features.columns

importances = list(rf.feature_importances_)
print(importances)
colors = (0.2, # redness
         0.4, # greenness
         0.2, # blueness
         0.6 # transparency
         ) 
# Sort feature importances in descending order
sorted_indices = np.argsort(importances)[::-1]
sorted_list =[importances[i] for i in sorted_indices]
# Plot feature importances
plt.figure(figsize=(10, 6))
plt.title('')
plt.barh(range(X.shape[1]), sorted_list, align="center",color=colors )
plt.yticks(range(X.shape[1]), labels[sorted_indices], fontsize=12)
plt.xlabel("Importance", fontsize=16)
plt.ylabel("Features", fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=12)
plt.tick_params(axis='both', which='minor', labelsize=12)
# Save the plot as a PNG file
plt.savefig('Importance.png', bbox_inches='tight')
plt.show()
# Out:
# [np.float64(0.06665006484262612), np.float64(0.011132073810281341), np.float64(0.013582981721068706), np.float64(0.017491398104308917), np.float64(0.8419054975009422), np.float64(0.03140712402079974), np.float64(0.016407638607259956), np.float64(3.601793861834623e-05), np.float64(2.151376987894238e-05), np.float64(0.0002899385651830332), np.float64(0.0), np.float64(0.0010045291948066848), np.float64(7.122192422613383e-05)]

# %% [markdown]
# # Generate Tree

# %%
from sklearn import tree
from sklearn.tree import export_text
i_tree = 0
for tree_in_forest in rf.estimators_:
    with open('tree_' + str(i_tree) + '.dot', 'w') as my_file:
        my_file = tree.export_graphviz(tree_in_forest, out_file = my_file)
        r = export_text(tree_in_forest)
        print("TREE ", i_tree)
        print(r)  
    i_tree = i_tree + 1
# Out:
# TREE  0
# |--- feature_4 <= 22.50
# |   |--- feature_0 <= 867821.00
# |   |   |--- feature_4 <= 14.50
# |   |   |   |--- feature_0 <= 1514.50
# |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |--- feature_0 <= 423.50
# |   |   |   |   |   |   |--- feature_6 <= 71.42
# |   |   |   |   |   |   |   |--- feature_6 <= 65.25
# |   |   |   |   |   |   |   |   |--- feature_3 <= 93.50
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_3 >  93.50
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_6 >  65.25
# |   |   |   |   |   |   |   |   |--- feature_0 <= 68.50
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  68.50
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_6 >  71.42
# |   |   |   |   |   |   |   |--- feature_4 <= 9.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 91.83
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 77.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  77.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  91.83
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_4 >  9.50
# |   |   |   |   |   |   |   |   |--- feature_12 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 185.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  185.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_12 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 91.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  91.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_0 >  423.50
# |   |   |   |   |   |   |--- feature_11 <= 0.50
# |   |   |   |   |   |   |   |--- feature_3 <= 58.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_3 >  58.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 1216.00
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  1216.00
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_11 >  0.50
# |   |   |   |   |   |   |   |--- feature_1 <= 1.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 1.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 686.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  686.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_5 >  1.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 680.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  680.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_1 >  1.50
# |   |   |   |   |   |   |   |   |--- feature_9 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_9 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |--- feature_5 <= 7.50
# |   |   |   |   |   |   |--- feature_4 <= 1.50
# |   |   |   |   |   |   |   |--- feature_9 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 4.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_2 >  4.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_9 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 558.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 442.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  442.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  558.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_4 >  1.50
# |   |   |   |   |   |   |   |--- feature_3 <= 251.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 13.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 9.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  9.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_4 >  13.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_3 >  251.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 1.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_1 >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_5 >  7.50
# |   |   |   |   |   |   |--- feature_3 <= 149.00
# |   |   |   |   |   |   |   |--- feature_0 <= 136.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_0 >  136.00
# |   |   |   |   |   |   |   |   |--- feature_6 <= 69.88
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 9.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  9.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  69.88
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 5.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  5.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_3 >  149.00
# |   |   |   |   |   |   |   |--- feature_2 <= 4.00
# |   |   |   |   |   |   |   |   |--- feature_12 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_12 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 235.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  235.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_2 >  4.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- feature_0 >  1514.50
# |   |   |   |   |--- feature_4 <= 1.50
# |   |   |   |   |   |--- feature_9 <= 0.50
# |   |   |   |   |   |   |--- feature_3 <= 232.50
# |   |   |   |   |   |   |   |--- feature_2 <= 274.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 66.85
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 43056.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  43056.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  66.85
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_2 >  274.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 266.73
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 401.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  401.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  266.73
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 143754.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  143754.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_3 >  232.50
# |   |   |   |   |   |   |   |--- feature_0 <= 10592.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 10.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 71.55
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  71.55
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_2 >  10.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 8371.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  8371.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_0 >  10592.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 2.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 16.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  16.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_5 >  2.50
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_9 >  0.50
# |   |   |   |   |   |   |--- feature_0 <= 667847.00
# |   |   |   |   |   |   |   |--- feature_2 <= 13.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 49.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 5720.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  5720.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_3 >  49.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 123.44
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  123.44
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_2 >  13.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 15.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_1 >  15.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 238.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  238.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_0 >  667847.00
# |   |   |   |   |   |   |   |--- feature_1 <= 346.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_1 >  346.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- feature_4 >  1.50
# |   |   |   |   |   |--- feature_4 <= 7.50
# |   |   |   |   |   |   |--- feature_1 <= 17.50
# |   |   |   |   |   |   |   |--- feature_2 <= 2.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 233.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 1533.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  1533.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_3 >  233.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 4350.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  4350.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_2 >  2.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 55.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 1277.17
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  1277.17
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_3 >  55.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 5.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  5.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_1 >  17.50
# |   |   |   |   |   |   |   |--- feature_1 <= 346.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 710302.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  710302.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_1 >  346.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 3.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 148.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  148.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_4 >  3.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 73.57
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  73.57
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_4 >  7.50
# |   |   |   |   |   |   |--- feature_3 <= 232.50
# |   |   |   |   |   |   |   |--- feature_6 <= 76.65
# |   |   |   |   |   |   |   |   |--- feature_1 <= 47.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_1 >  47.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_6 >  76.65
# |   |   |   |   |   |   |   |   |--- feature_11 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_11 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_3 >  232.50
# |   |   |   |   |   |   |   |--- feature_0 <= 6507.00
# |   |   |   |   |   |   |   |   |--- feature_3 <= 242.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 12.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  12.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_3 >  242.50
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_0 >  6507.00
# |   |   |   |   |   |   |   |   |--- feature_6 <= 148.41
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  148.41
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 235.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  235.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |--- feature_4 >  14.50
# |   |   |   |--- feature_5 <= 1.50
# |   |   |   |   |--- feature_1 <= 8.50
# |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |--- feature_9 <= 0.50
# |   |   |   |   |   |   |   |--- feature_12 <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_12 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 81.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  81.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 18.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  18.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_9 >  0.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |--- feature_9 <= 0.50
# |   |   |   |   |   |   |   |--- feature_3 <= 59.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_3 >  59.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_9 >  0.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- feature_1 >  8.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- feature_5 >  1.50
# |   |   |   |   |--- feature_3 <= 62.00
# |   |   |   |   |   |--- feature_2 <= 5.50
# |   |   |   |   |   |   |--- feature_4 <= 19.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_4 >  19.50
# |   |   |   |   |   |   |   |--- feature_3 <= 50.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_3 >  50.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_2 >  5.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- feature_3 >  62.00
# |   |   |   |   |   |--- feature_1 <= 29.50
# |   |   |   |   |   |   |--- feature_1 <= 4.50
# |   |   |   |   |   |   |   |--- feature_5 <= 4.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 2157.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 18.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  18.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  2157.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_5 >  4.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_1 >  4.50
# |   |   |   |   |   |   |   |--- feature_3 <= 234.00
# |   |   |   |   |   |   |   |   |--- feature_5 <= 8.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_5 >  8.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_3 >  234.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_1 >  29.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |--- feature_0 >  867821.00
# |   |   |--- feature_3 <= 237.00
# |   |   |   |--- feature_0 <= 1554066.00
# |   |   |   |   |--- feature_4 <= 11.00
# |   |   |   |   |   |--- feature_2 <= 375.50
# |   |   |   |   |   |   |--- feature_5 <= 1.50
# |   |   |   |   |   |   |   |--- feature_11 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 366.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_2 >  366.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 876084.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  876084.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_11 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_5 >  1.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_2 >  375.50
# |   |   |   |   |   |   |--- feature_5 <= 1.50
# |   |   |   |   |   |   |   |--- feature_3 <= 231.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 9.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 1809.69
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  1809.69
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_4 >  9.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 1935.97
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  1935.97
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_3 >  231.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 9.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 834.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  834.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_4 >  9.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 71.76
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  71.76
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_5 >  1.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- feature_4 >  11.00
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- feature_0 >  1554066.00
# |   |   |   |   |--- feature_1 <= 891.50
# |   |   |   |   |   |--- feature_1 <= 874.50
# |   |   |   |   |   |   |--- feature_3 <= 147.50
# |   |   |   |   |   |   |   |--- feature_6 <= 1831.17
# |   |   |   |   |   |   |   |   |--- feature_6 <= 1812.94
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  1812.94
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 1621361.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  1621361.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_6 >  1831.17
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_3 >  147.50
# |   |   |   |   |   |   |   |--- feature_1 <= 868.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_1 >  868.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 1651913.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  1651913.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_1 >  874.50
# |   |   |   |   |   |   |--- feature_1 <= 875.50
# |   |   |   |   |   |   |   |--- feature_6 <= 70.57
# |   |   |   |   |   |   |   |   |--- feature_3 <= 231.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_3 >  231.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_6 >  70.57
# |   |   |   |   |   |   |   |   |--- feature_0 <= 1647357.00
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 702.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  702.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  1647357.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_1 >  875.50
# |   |   |   |   |   |   |   |--- feature_4 <= 9.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_4 >  9.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 1896.44
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 11.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  11.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  1896.44
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- feature_1 >  891.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |--- feature_3 >  237.00
# |   |   |   |--- class: 1.0
# |--- feature_4 >  22.50
# |   |--- feature_0 <= 4354.00
# |   |   |--- feature_5 <= 1.50
# |   |   |   |--- feature_1 <= 4.50
# |   |   |   |   |--- feature_3 <= 177.50
# |   |   |   |   |   |--- feature_6 <= 208.50
# |   |   |   |   |   |   |--- feature_4 <= 33.50
# |   |   |   |   |   |   |   |--- feature_6 <= 81.42
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_6 >  81.42
# |   |   |   |   |   |   |   |   |--- feature_6 <= 82.75
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  82.75
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 112.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  112.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_4 >  33.50
# |   |   |   |   |   |   |   |--- feature_4 <= 40.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_4 >  40.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_6 >  208.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- feature_3 >  177.50
# |   |   |   |   |   |--- feature_6 <= 104.50
# |   |   |   |   |   |   |--- feature_0 <= 405.00
# |   |   |   |   |   |   |   |--- feature_3 <= 233.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_3 >  233.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_0 >  405.00
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_6 >  104.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- feature_1 >  4.50
# |   |   |   |   |--- class: 1.0
# |   |   |--- feature_5 >  1.50
# |   |   |   |--- class: 1.0
# |   |--- feature_0 >  4354.00
# |   |   |--- feature_4 <= 27.00
# |   |   |   |--- class: 0.0
# |   |   |--- feature_4 >  27.00
# |   |   |   |--- feature_4 <= 42.50
# |   |   |   |   |--- feature_5 <= 11.00
# |   |   |   |   |   |--- feature_1 <= 38.00
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_1 >  38.00
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- feature_5 >  11.00
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- feature_4 >  42.50
# |   |   |   |   |--- class: 1.0

# %% [markdown]
# # Save the RF Attack Detector

# %%
import pickle as pickle
filename = 'tcp_notime.sav'
pickle.dump(rf, open(filename, 'wb'))

# %% [markdown]
# # Display (Match-Action) Rules of the RF Tree, acceptable to P4

# %%
from io import StringIO
from numbers import Integral

import numpy as np
import pandas
import pickle 
import sklearn
from sklearn import tree 
from sklearn.tree import export_text

from sklearn.tree import _tree

from sklearn.tree import DecisionTreeClassifier

filename = 'tcp_notime.sav'
rf = pickle.load(open(filename, 'rb'))

i_tree = 0 

global_id = 0

def export_p4(decision_tree):
    tree_ = decision_tree.tree_
    class_names = decision_tree.classes_
    right_child_fmt = "{} {} <= {}\n"
    left_child_fmt = "{} {} >  {}\n"
    truncation_fmt = "{} {}\n"
    feature_names_ = ["{}".format(i) for i in tree_.feature]  
    export_text.report = ""
    max_depth=10
    spacing=3
    decimals=2
    show_weights=False

    if isinstance(decision_tree, DecisionTreeClassifier):
        value_fmt = "{}{} weights: {}\n"
        if not show_weights:
            value_fmt = "{}{}{}\n"
    else:
        value_fmt = "{}{} value: {}\n"

    def _add_leaf(value, class_name, indent, prevfeature, result, depth, previous_id):
        global global_id
        global i_tree 
        current_id = global_id

        val = ''
        is_classification = isinstance(decision_tree,
                                       DecisionTreeClassifier)
        if show_weights or not is_classification:
            val = ["{1:.{0}f}, ".format(decimals, v) for v in value]
            val = '['+''.join(val)[:-2]+']'
        if is_classification:
            val += ' class: ' + str(class_name)
        export_text.report += value_fmt.format(indent, '', val)
        #print("table_add MyIngress.level_", i_tree,"_", depth, " ", "MyIngress.SetClass",i_tree," ", previous_id," ",prevfeature," ", result," ", "=>"," ", current_id, " ", int(float(class_name)), sep="")
        print("table_add MyIngress.TCPlevel_", depth, " ", "MyIngress.SetClassTCP"," ", previous_id," ",prevfeature," ", result," ", "=>"," ", current_id, " ", int(float(class_name)), sep="")

    def print_tree_recurse(node, depth, prevfeature, result, previous_id):
        indent = ("|" + (" " * spacing)) * depth
        indent = indent[:-spacing] + "-" * spacing
        global global_id
        global i_tree 
        global_id = global_id + 1
        current_id = global_id

        value = None
        if tree_.n_outputs == 1:
            value = tree_.value[node][0]
        else:
            value = tree_.value[node].T[0]
        class_name = np.argmax(value)

        if (tree_.n_classes[0] != 1 and
                tree_.n_outputs == 1):
            class_name = class_names[class_name]

        if depth <= max_depth+1:
            info_fmt = ""
            info_fmt_left = info_fmt
            info_fmt_right = info_fmt

            if tree_.feature[node] != _tree.TREE_UNDEFINED:
                name = feature_names_[node]
                threshold = tree_.threshold[node]
                threshold = "{1:.{0}f}".format(decimals, threshold)
                export_text.report += right_child_fmt.format(indent,
                                                             name,
                                                             threshold)
                export_text.report += info_fmt_left
                #if int(name) == 9 or int(name) == 11:
                   #print("**********", name, threshold, float(threshold), 1000000.0*float(threshold))
                 #  print("table_add MyIngress.level_", i_tree,"_", depth, " MyIngress.CheckFeature ", previous_id, " ", prevfeature, " ", result, " ", "=>", " ", current_id, " ", name," ", int(1000000.0*float(threshold)), sep='')

                #else:
                #print("table_add MyIngress.level_", i_tree,"_", depth, " MyIngress.CheckFeatureTCP ", previous_id, " ", prevfeature, " ", result, " ", "=>", " ", current_id, " ", name," ", int(float(threshold)), sep='')
                print("table_add MyIngress.TCPlevel_", depth, " MyIngress.CheckFeatureTCP ", previous_id, " ", prevfeature, " ", result, " ", "=>", " ", current_id, " ", name," ", int(float(threshold)), sep='')

                print_tree_recurse(tree_.children_left[node], depth+1, name, 1, current_id)

                export_text.report += left_child_fmt.format(indent,
                                                            name,
                                                            threshold)
                export_text.report += info_fmt_right
           #     print("level", depth, "checkfeature", prevfeature, result, "=>", name, threshold)
 

                print_tree_recurse(tree_.children_right[node], depth+1, name, 0, current_id)
            else:  # leaf
                _add_leaf(value, class_name, indent, prevfeature, result, depth, previous_id)
        else:
            subtree_depth = _compute_depth(tree_, node)
            if subtree_depth == 1:
                _add_leaf(value, class_name, indent, prevfeature, result, depth, previous_id)
            else:
                trunc_report = 'truncated branch of depth %d' % subtree_depth
                export_text.report += truncation_fmt.format(indent,
                                                            trunc_report)

    print_tree_recurse(0, 1, 0, 1, global_id)


for tree_in_forest in rf.estimators_:
  #r = export_text(tree_in_forest)
  #print(r)
  global i_tree

  i_tree = i_tree + 1
  export_p4(tree_in_forest)
# Out:
# table_add MyIngress.TCPlevel_1 MyIngress.CheckFeatureTCP 0 0 1 => 1 4 22
# table_add MyIngress.TCPlevel_2 MyIngress.CheckFeatureTCP 1 4 1 => 2 0 867821
# table_add MyIngress.TCPlevel_3 MyIngress.CheckFeatureTCP 2 0 1 => 3 4 14
# table_add MyIngress.TCPlevel_4 MyIngress.CheckFeatureTCP 3 4 1 => 4 0 1514
# table_add MyIngress.TCPlevel_5 MyIngress.CheckFeatureTCP
# table_add MyIngress.TCPlevel_9 MyIngress.CheckFeatureTCP 314 4 0 => 316 6 1896
# table_add MyIngress.TCPlevel_10 MyIngress.CheckFeatureTCP 316 6 1 => 317 4 11
# table_add MyIngress.TCPlevel_11 MyIngress.SetClassTCP 317 4 1 => 318 1
# table_add MyIngress.TCPlevel_11 MyIngress.SetClassTCP 317 4 0 => 319 0
# table_add MyIngress.TCPlevel_10 MyIngress.SetClassTCP 316 6 0 => 320 0
# table_add MyIngress.TCPlevel_6 MyIngress.SetClassTCP 287 1 0 => 321 0
# table_add MyIngress.TCPlevel_4 MyIngress.SetClassTCP 256 3 0 => 322 1
# table_add MyIngress.TCPlevel_2 MyIngress.CheckFeatureTCP 1 4 0 => 323 0 4354
# table_add MyIngress.TCPlevel_3 MyIngress.CheckFeatureTCP 323 0 1 => 324 5 1
# table_add MyIngress.TCPlevel_4 MyIngress.CheckFeatureTCP 324 5 1 => 325 1 4
# table_add MyIngress.TCPlevel_5 MyIngress.CheckFeatureTCP 325 1 1 => 326 3 177
# table_add MyIngress.TCPlevel_6 MyIngress.CheckFeatureTCP 326 3 1 => 327 6 208
# table_add MyIngress.TCPlevel_7 MyIngress.CheckFeatureTCP 327 6 1 => 328 4 33
# table_add MyIngress.TCPlevel_8 MyIngress.CheckFeatureTCP 328 4 1 => 329 6 81
# table_add MyIngress.TCPlevel_9 MyIngress.SetClassTCP 329 6 1 => 330 1
# table_add MyIngress.TCPlevel_9 MyIngress.CheckFeatureTCP 329 6 0 => 331 6 82
# table_add MyIngress.TCPlevel_10 MyIngress.SetClassTCP 331 6 1 => 332 0
# table_add MyIngress.TCPlevel_10 MyIngress.CheckFeatureTCP 331 6 0 => 333 0 112
# table_add MyIngress.TCPlevel_11 MyIngress.SetClassTCP 333 0 1 => 334 0
# table_add MyIngress.TCPlevel_11 MyIngress.SetClassTCP 333 0 0 => 335 1
# table_add MyIngress.TCPlevel_8 MyIngress.CheckFeatureTCP 328 4 0 => 336 4 40
# table_add MyIngress.TCPlevel_9 MyIngress.SetClassTCP 336 4 1 => 337 0
# table_add MyIngress.TCPlevel_9 MyIngress.SetClassTCP 336 4 0 => 338 1
# table_add MyIngress.TCPlevel_7 MyIngress.SetClassTCP 327 6 0 => 339 0
# table_add MyIngress.TCPlevel_6 MyIngress.CheckFeatureTCP 326 3 0 => 340 6 104
# table_add MyIngress.TCPlevel_7 MyIngress.CheckFeatureTCP 340 6 1 => 341 0 405
# table_add MyIngress.TCPlevel_8 MyIngress.CheckFeatureTCP 341 0 1 => 342 3 233
# table_add MyIngress.TCPlevel_9 MyIngress.SetClassTCP 342 3 1 => 343 0
# table_add MyIngress.TCPlevel_9 MyIngress.SetClassTCP 342 3 0 => 344 1
# table_add MyIngress.TCPlevel_8 MyIngress.SetClassTCP 341 0 0 => 345 0
# table_add MyIngress.TCPlevel_7 MyIngress.SetClassTCP 340 6 0 => 346 1
# table_add MyIngress.TCPlevel_5 MyIngress.SetClassTCP 325 1 0 => 347 1
# table_add MyIngress.TCPlevel_4 MyIngress.SetClassTCP 324 5 0 => 348 1
# table_add MyIngress.TCPlevel_3 MyIngress.CheckFeatureTCP 323 0 0 => 349 4 27
# table_add MyIngress.TCPlevel_4 MyIngress.SetClassTCP 349 4 1 => 350 0
# table_add MyIngress.TCPlevel_4 MyIngress.CheckFeatureTCP 349 4 0 => 351 4 42
# table_add MyIngress.TCPlevel_5 MyIngress.CheckFeatureTCP 351 4 1 => 352 5 11
# table_add MyIngress.TCPlevel_6 MyIngress.CheckFeatureTCP 352 5 1 => 353 1 38
# table_add MyIngress.TCPlevel_7 MyIngress.SetClassTCP 353 1 1 => 354 0
# table_add MyIngress.TCPlevel_7 MyIngress.SetClassTCP 353 1 0 => 355 1
# table_add MyIngress.TCPlevel_6 MyIngress.SetClassTCP 352 5 0 => 356 1
# table_add MyIngress.TCPlevel_5 MyIngress.SetClassTCP 351 4 0 => 357 1

# %% [markdown]
# # Now predicting about separatly processes data

# %%
current_path = os.getcwd()

file1='dataset/Benign_Test_1.csv'
benign = pd.read_csv(file1)
file2='dataset/RSTFIN_Test.csv'
rst = pd.read_csv(file2)
file3='dataset/TCPFlood.csv'
tcp = pd.read_csv(file3)
file4='dataset/SYN_Test.csv'
file5='dataset/HTTPFlood_Test.csv'
http = pd.read_csv(file5)
file6='dataset/SlowLoris_Test.csv'
slow = pd.read_csv(file6)
file7='dataset/PUSHACK_Test.csv'
psh = pd.read_csv(file7)
file8='dataset/ACKFrag_Test.csv'
ack = pd.read_csv(file8)

benign = benign[(benign['proto_type'] == 6)]
benign['attack'] = 0
rst['attack'] = 1
tcp['attack'] = 1
syn['attack'] = 1
ack['attack'] = 1
psh['attack'] = 1
http['attack'] = 1
slow['attack'] = 1

# %%
data = pd.concat([benign])
print(data.columns)
# Out:
# Index(['ts', 'srcip', 'dstip', 'srcport', 'dstport', 'proto_type', 'sbytes',
#        'dbytes', 'flow_bytes', 'rate', 'srate', 'drate', 'spkts', 'dpkts',
#        'ttl', 'iat', 'max_iat', 'min_iat', 'total_duration',
#        'N_IN_Conn_P_Src_IP', 'N_IN_Conn_P_Dst_IP', 'avg_pkt_len', 'state_con',
#        'state_int', 'state_rst', 'fin_flag_number', 'syn_flag_number',
#        'psh_flag_number', 'ack_flag_number', 'urg_flag_number',
#        'ece_flag_number', 'cwr_flag_number', 'attack'],
#       dtype='object')

# %% [markdown]
# # Test Benign

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_fscore_support

data = pd.concat([benign])
best_features = data[features]
target_features = data[['attack']]
prediction = rf.predict(best_features)
print("Accuracy:", 1- sum(prediction)/len(prediction))
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(target_features, prediction)
# Print the results for each class
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", fscore)
print("Support: ", support)
# Out:
# Accuracy: 0.993993993993994
# Precision:  [1. 0.]
# Recall:  [0.99399399 0.        ]
# F1-score:  [0.99698795 0.        ]
# Support:  [999   0]
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # Test SYN Flood

# %%
data = pd.concat([syn])
best_features = data[features]
target_features = data[['attack']]
prediction = rf.predict(best_features)
print("Accuracy: ", sum(prediction)/len(prediction))
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(target_features, prediction)
# Print the results for each class
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", fscore)
print("Support: ", support)
# Out:
# Accuracy:  0.9778725494574197
# Precision:  [0. 1.]
# Recall:  [0.         0.97787255]
# F1-score:  [0.        0.9888125]
# Support:  [    0 44786]
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # TCP PUSH ACK

# %%
data = pd.concat([psh])
best_features = data[features]
target_features = data[['attack']]
prediction = rf.predict(best_features)
print("Accuracy: ", sum(prediction)/len(prediction))
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(target_features, prediction)
# Print the results for each class
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", fscore)
print("Support: ", support)
# Out:
# Accuracy:  0.9995048562178632
# Precision:  [0. 1.]
# Recall:  [0.         0.99950486]
# F1-score:  [0.         0.99975237]
# Support:  [    0 26255]
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # TCP ACK Fragmentation

# %%
data = pd.concat([ack])
best_features = data[features]
target_features = data[['attack']]
prediction = rf.predict(best_features)
print("Accuracy: ", sum(prediction)/len(prediction))
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(target_features, prediction)
# Print the results for each class
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", fscore)
print("Support: ", support)
# Out:
# Accuracy:  0.9771729587357331
# Precision:  [0. 1.]
# Recall:  [0.         0.97717296]
# F1-score:  [0.         0.98845471]
# Support:  [   0 1139]
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # Test TCP DoS

# %%
data = pd.concat([tcp])
best_features = data[features]
target_features = data[['attack']]
prediction = rf.predict(best_features)
print("Accuracy:", sum(prediction)/len(prediction))
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(target_features, prediction)
# Print the results for each class
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", fscore)
print("Support: ", support)
# Out:
# Accuracy: 0.9981534484350475
# Precision:  [0. 1.]
# Recall:  [0.         0.99815345]
# F1-score:  [0.         0.99907587]
# Support:  [    0 43324]
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # Test RST FIN Flood

# %%
data = pd.concat([rst])
best_features = data[features]
target_features = data[['attack']]
prediction = rf.predict(best_features)
print("Accuracy: ", sum(prediction)/len(prediction))
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(target_features, prediction)
# Print the results for each class
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", fscore)
print("Support: ", support)
# Out:
# Accuracy:  0.9980753138075313
# Precision:  [0. 1.]
# Recall:  [0.         0.99807531]
# F1-score:  [0.         0.99903673]
# Support:  [    0 11950]
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # Test HTTP Flood

# %%
data = pd.concat([http])
best_features = data[features]
target_features = data[['attack']]
prediction = rf.predict(best_features)
print("Accuracy:",  sum(prediction)/len(prediction))
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(target_features, prediction)
# Print the results for each class
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", fscore)
print("Support: ", support)
# Out:
# Accuracy: 0.9090513489991296
# Precision:  [0. 1.]
# Recall:  [0.         0.90905135]
# F1-score:  [0.         0.95235924]
# Support:  [   0 2298]
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # Test Slowloris

# %%
data = pd.concat([slow])
best_features = data[features]
target_features = data[['attack']]
prediction = rf.predict(best_features)
print("Accuracy:",  sum(prediction)/len(prediction))
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(target_features, prediction)
# Print the results for each class
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", fscore)
print("Support: ", support)
# Out:
# Accuracy: 0.8692699490662139
# Precision:  [0. 1.]
# Recall:  [0.         0.86926995]
# F1-score:  [0.         0.93006358]
# Support:  [   0 4712]
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
