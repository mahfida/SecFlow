# %%
'''Main'''
import numpy as np
import pandas as pd
import os

'''Data Viz'''
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
import matplotlib as mpl

# %matplotlib inline

'''Data Prep'''
from sklearn import preprocessing as pp 
from sklearn.preprocessing import LabelEncoder, StandardScaler
from scipy.stats import pearsonr 
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold 
from sklearn.metrics import log_loss 
from sklearn.metrics import precision_recall_curve, average_precision_score 
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.metrics import confusion_matrix, classification_report 
from statistics import mean, stdev

from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB 
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# # Load TCP/UDP Benign and Malicious CIC2023 Flows

# %%
# Acquire Data
# Data here has all features
current_path = os.getcwd()

# BENIGN DATA FILES ***************************************
file1='dataset/Benign.csv'
benign = pd.read_csv(file1)
benign['attack'] = 0

# DDOS-VOLUMETRIC ATTACK ***********************************
file2='dataset/TCPFlood.csv'
file3='dataset/UDPFlood.csv'
udp = pd.read_csv(file2)
tcp = pd.read_csv(file3)
udp['attack'] = 1
tcp['attack'] = 1

# DDOS-TRANSPORT PROTOCOL VULNERABILITIES *******************
file4='dataset/ACKFrag.csv'
file5='dataset/SYN.csv'
file6='dataset/RSTFIN.csv'
file7='dataset/PUSHACK.csv'
file8='dataset/UDPFrag.csv'

ack = pd.read_csv(file4)
syn = pd.read_csv(file5)
rst = pd.read_csv(file6)
psh = pd.read_csv(file7)
udp_frag = pd.read_csv(file8)

ack['attack'] = 1
syn['attack'] = 1
rst['attack'] = 1
psh['attack'] = 1
udp_frag['attack'] = 1

# DDOS-APPLICATION PROTOCOL VULNERABILITIES *******************
file91='dataset/HTTPFlood.csv'
file92='dataset/Slowloris.csv'
http = pd.read_csv(file91)
slow = pd.read_csv(file92)
http['attack'] = 1
slow['attack'] = 1
## CONCATE ALL THE RECORDS ************************************
frames = [benign, 
          tcp, udp,
          syn, rst, ack, psh, 
          udp_frag,
          http, slow]

data = pd.concat(frames)
data['type'] = data['proto_type'].apply(lambda x: 0 if x > 6 else 1)

# %%
# Size of the data
print("Shape of data: ", data.shape)
# Attack wise size
print("Attack and Benign Records: ", data["attack"].value_counts())
# Out:
# Shape of data:  (388251, 35)
# Attack and Benign Records:  attack
# 1    292282
# 0     95969
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['ts', 'srcip', 'dstip', 'srcport', 'dstport', 'proto_type', 'sbytes',
#        'dbytes', 'flow_bytes', 'rate', 'srate', 'drate', 'spkts', 'dpkts',
#        'ttl', 'iat', 'max_iat', 'min_iat', 'total_duration',
#        'N_IN_Conn_P_Src_IP', 'N_IN_Conn_P_Dst_IP', 'avg_pkt_len', 'state_con',
#        'state_int', 'state_rst', 'fin_flag_number', 'syn_flag_number',
#        'psh_flag_number', 'ack_flag_number', 'urg_flag_number',
#        'ece_flag_number', 'cwr_flag_number', 'attack', 'x', 'type'],
#       dtype='object')

# %% [markdown]
# # Select parameters based on the model i.e. with or without time based features

# %%
# Features according to Importance
features =['flow_bytes','spkts','dpkts', 'type',
        'ttl','N_IN_Conn_P_Src_IP', 'N_IN_Conn_P_Dst_IP','avg_pkt_len',
        'state_con','state_int', 'state_rst', 
        'fin_flag_number', 'syn_flag_number',
        'psh_flag_number', 'ack_flag_number', 
        #'urg_flag_number','ece_flag_number', 
        #'cwr_flag_number'
          ]
best_features = data[features] 
target_features = data[['attack']]

# %% [markdown]
# # Split Dataset into X and Y

# %%
# Split of  predictors and response variable
X= best_features
y= target_features

# %% [markdown]
# # Use StratifiedKFold with K=10

# %%
# Create  classifier object.
rf = RandomForestClassifier(n_estimators = 1, n_jobs=2, random_state=0, max_depth=10)  
n_splits = 10
# Create StratifiedKFold object.
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=1)
accu_stratified = []
conf_matrices = []  # Store confusion matrices
per_class_accuracies = []

# %%
# Create model with StratifiedKFold   
for train_index, test_index in skf.split(X, y):
    x_train_fold, x_test_fold = X.iloc[train_index], X.iloc[test_index]
    y_train_fold, y_test_fold = y.iloc[train_index], y.iloc[test_index]
    rf.fit(x_train_fold, y_train_fold)
    #accu_stratified.append(rf.score(x_test_fold, y_test_fold))

    # Compute confusion matrix
    conf_matrix = confusion_matrix(y_test_fold,rf.predict(x_test_fold))
    conf_matrices.append(conf_matrix)
    
    # Compute per-class accuracies
    per_class_accuracy = conf_matrix.diagonal() / conf_matrix.sum(axis=1)
    per_class_accuracies.append(per_class_accuracy)

# Convert lists to numpy arrays for easier manipulation
conf_matrices = np.array(conf_matrices)
per_class_accuracies = np.array(per_class_accuracies)
# Out:
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
# Plotting per-class accuracies

plt.figure(figsize=(10, 6))
for i, class_accuracy in enumerate(per_class_accuracies.T, 1):
    if(i==1):
        plt.plot(range(1, n_splits + 1), class_accuracy, marker='o', label=f'Benign', color='green',  linestyle='dashed', markersize=10)
        print("Accuracy of Attack Records: ", class_accuracy)
        print('\nMedian Accuracy of Attack Records:', np.median(class_accuracy)*100, '%')
        print('\nStandard Deviation of Attack Records:', stdev(class_accuracy))
    else:
        plt.plot(range(1, n_splits + 1), class_accuracy, marker='*', label=f'Attack', color='red',  linestyle='dotted', markersize=10)  
        print("Accuracy of Benign Records: ", class_accuracy)
        print('\nMedian Accuracy of Benign Records:', np.median(class_accuracy)*100, '%')
        print('\nStandard Deviation of Benign Records:', stdev(class_accuracy))
    
plt.title('')
plt.xlabel('Fold', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)
plt.xticks(range(1, n_splits + 1))
plt.tick_params(axis='both', which='major', labelsize=16)
plt.tick_params(axis='both', which='minor', labelsize=16)
plt.legend()
plt.grid(True)
# Save the plot as a PNG file
plt.savefig('StratifiedKFold_5Tree.png', bbox_inches='tight')
plt.show()
# Out:
# Accuracy of Attack Records:  [0.9732208  0.95654892 0.96311347 0.97718037 0.94779619 0.98843389
#  0.97707617 0.97634678 0.97582578 0.97165486]
#
# Median Accuracy of Attack Records: 97.45232885276648 %
#
# Standard Deviation of Attack Records: 0.011761313587268323
# Accuracy of Benign Records:  [0.93598823 0.94378678 0.94341043 0.92657725 0.94744765 0.94450527
#  0.93509648 0.92931436 0.93636239 0.94043587]
#
# Median Accuracy of Benign Records: 93.83991303567043 %
#
# Standard Deviation of Benign Records: 0.006835310212399724

# %% [markdown]
# # Training model on the whole dataset

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import SelectFromModel
rf = RandomForestClassifier(n_estimators = 1, n_jobs=2, random_state=0, max_depth=10)
rf.fit(X, y)
# Out:
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(max_depth=10, n_estimators=1, n_jobs=2, random_state=0)

# %% [markdown]
# # Mean Decrease of Accuracy of the Parameters

# %%
best_features.rename(columns={"N_IN_Conn_P_Src_IP": "N_IN_Conn_Src_IP", "N_IN_Conn_P_Dst_IP": "N_IN_Conn_Dst_IP"})
labels = best_features.columns

importances = list(rf.feature_importances_)
print(importances)
colors = (0.2, # redness
         0.4, # greenness
         0.2, # blueness
         0.6 # transparency
         ) 
# Sort feature importances in descending order
sorted_indices = np.argsort(importances)[::-1]
sorted_list =[importances[i] for i in sorted_indices]
# Plot feature importances
plt.figure(figsize=(10, 6))
plt.title('')
plt.barh(range(X.shape[1]), sorted_list, align="center",color=colors )
plt.yticks(range(X.shape[1]), labels[sorted_indices], fontsize=12)
plt.xlabel("Importance", fontsize=16)
plt.ylabel("Features", fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=12)
plt.tick_params(axis='both', which='minor', labelsize=12)
# Save the plot as a PNG file
plt.savefig('Importance.png', bbox_inches='tight')
plt.show()
# Out:
# [np.float64(0.013734404474637045), np.float64(0.05142120085381104), np.float64(0.06347284311487512), np.float64(0.021031190107518444), np.float64(0.05894645815940734), np.float64(0.1665393332746587), np.float64(0.3005554776844313), np.float64(0.03262725520001453), np.float64(0.0005929873689823928), np.float64(0.0002131008542608148), np.float64(6.851178155649596e-06), np.float64(0.00031039320423916866), np.float64(5.968110952333505e-05), np.float64(0.09047684629323025), np.float64(0.2000119771222548)]

# %% [markdown]
# # Save RF Detector

# %%
import pickle as pickle
filename = 'combined_notime.sav'
pickle.dump(rf, open(filename, 'wb'))

# %% [markdown]
# # Generate Tree

# %%
from sklearn import tree
from sklearn.tree import export_text
i_tree = 0
for tree_in_forest in rf.estimators_:
    with open('tree_' + str(i_tree) + '.dot', 'w') as my_file:
        my_file = tree.export_graphviz(tree_in_forest, out_file = my_file)
        r = export_text(tree_in_forest)
        print("TREE ", i_tree)
        print(r)  
    i_tree = i_tree + 1
# Out:
# TREE  0
# |--- feature_14 <= 0.50
# |   |--- feature_3 <= 0.50
# |   |   |--- feature_4 <= 85.50
# |   |   |   |--- feature_5 <= 9.50
# |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |--- feature_5 <= 1.50
# |   |   |   |   |   |   |--- feature_1 <= 10.50
# |   |   |   |   |   |   |   |--- feature_4 <= 21.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 85.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  85.00
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 160.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  160.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_4 >  21.00
# |   |   |   |   |   |   |   |   |--- feature_7 <= 401.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 6.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  6.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_7 >  401.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_1 >  10.50
# |   |   |   |   |   |   |   |--- feature_6 <= 20.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_6 >  20.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_5 >  1.50
# |   |   |   |   |   |   |--- feature_6 <= 2.50
# |   |   |   |   |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 3.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 128.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  128.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_5 >  3.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 24.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_1 >  24.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_6 >  2.50
# |   |   |   |   |   |   |   |--- feature_1 <= 23.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 27.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 8452.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  8452.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  27.50
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_1 >  23.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 6.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 927.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  927.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  6.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 8180.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  8180.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |--- feature_0 <= 5296.00
# |   |   |   |   |   |   |--- feature_2 <= 48.50
# |   |   |   |   |   |   |   |--- feature_6 <= 1.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 23.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 50.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  50.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_2 >  23.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 25.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  25.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_6 >  1.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 6.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  6.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_2 >  48.50
# |   |   |   |   |   |   |   |--- feature_6 <= 3.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_6 >  3.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_0 >  5296.00
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- feature_5 >  9.50
# |   |   |   |   |--- feature_0 <= 338.50
# |   |   |   |   |   |--- feature_4 <= 59.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_4 >  59.50
# |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |--- feature_6 <= 28.50
# |   |   |   |   |   |   |   |   |--- feature_7 <= 72.00
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 5.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  5.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_7 >  72.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_6 >  28.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- feature_0 >  338.50
# |   |   |   |   |   |--- feature_1 <= 2.50
# |   |   |   |   |   |   |--- feature_7 <= 89.00
# |   |   |   |   |   |   |   |--- feature_0 <= 417.00
# |   |   |   |   |   |   |   |   |--- feature_5 <= 42.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_5 >  42.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 393.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  393.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_0 >  417.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 1.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 432.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  432.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_1 >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_7 >  89.00
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_1 >  2.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |--- feature_4 >  85.50
# |   |   |   |--- feature_1 <= 6.50
# |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |--- feature_5 <= 1.50
# |   |   |   |   |   |   |--- feature_9 <= 0.50
# |   |   |   |   |   |   |   |--- feature_0 <= 302.00
# |   |   |   |   |   |   |   |   |--- feature_7 <= 99.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 83.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  83.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_7 >  99.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_0 >  302.00
# |   |   |   |   |   |   |   |   |--- feature_6 <= 22.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 105.40
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  105.40
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  22.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 148.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  148.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_9 >  0.50
# |   |   |   |   |   |   |   |--- feature_7 <= 147.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 2.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 92.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  92.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  2.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_7 >  147.50
# |   |   |   |   |   |   |   |   |--- feature_7 <= 179.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_7 >  179.00
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 13.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  13.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_5 >  1.50
# |   |   |   |   |   |   |--- feature_7 <= 89.25
# |   |   |   |   |   |   |   |--- feature_9 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 2.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  2.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_9 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 9.00
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 191.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  191.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  9.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 84.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  84.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_7 >  89.25
# |   |   |   |   |   |   |   |--- feature_0 <= 426.00
# |   |   |   |   |   |   |   |   |--- feature_5 <= 4.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 376.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  376.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_5 >  4.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 144.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  144.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_0 >  426.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |--- feature_6 <= 2.50
# |   |   |   |   |   |   |--- feature_7 <= 129.00
# |   |   |   |   |   |   |   |--- feature_7 <= 65.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_7 >  65.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 1.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 88.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  88.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  1.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_7 >  129.00
# |   |   |   |   |   |   |   |--- feature_4 <= 125.00
# |   |   |   |   |   |   |   |   |--- feature_6 <= 1.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 166.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  166.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_4 >  125.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 269.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  269.00
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 156.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  156.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_6 >  2.50
# |   |   |   |   |   |   |--- feature_6 <= 5.50
# |   |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |   |--- feature_7 <= 74.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_7 >  74.00
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_6 >  5.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- feature_1 >  6.50
# |   |   |   |   |--- feature_6 <= 6.50
# |   |   |   |   |   |--- feature_4 <= 191.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_4 >  191.50
# |   |   |   |   |   |   |--- feature_7 <= 481.81
# |   |   |   |   |   |   |   |--- feature_1 <= 7.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 772.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 5.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  5.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  772.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_1 >  7.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_7 >  481.81
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- feature_6 >  6.50
# |   |   |   |   |   |--- feature_5 <= 1.50
# |   |   |   |   |   |   |--- feature_6 <= 23.50
# |   |   |   |   |   |   |   |--- feature_7 <= 222.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_7 >  222.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 1725.00
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 22.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  22.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  1725.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_6 >  23.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_5 >  1.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |--- feature_3 >  0.50
# |   |   |--- feature_5 <= 9.50
# |   |   |   |--- feature_6 <= 3.50
# |   |   |   |   |--- feature_1 <= 4.50
# |   |   |   |   |   |--- feature_11 <= 0.50
# |   |   |   |   |   |   |--- feature_7 <= 55.20
# |   |   |   |   |   |   |   |--- feature_5 <= 1.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_5 >  1.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 1.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  1.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_7 >  55.20
# |   |   |   |   |   |   |   |--- feature_4 <= 182.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 3.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_5 >  3.50
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_4 >  182.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_11 >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- feature_1 >  4.50
# |   |   |   |   |   |--- feature_0 <= 341786.50
# |   |   |   |   |   |   |--- feature_2 <= 10.50
# |   |   |   |   |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 6.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_1 >  6.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 12.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  12.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_2 >  10.50
# |   |   |   |   |   |   |   |--- feature_7 <= 158.65
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_7 >  158.65
# |   |   |   |   |   |   |   |   |--- feature_0 <= 6428.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  6428.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_0 >  341786.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- feature_6 >  3.50
# |   |   |   |   |--- feature_11 <= 0.50
# |   |   |   |   |   |--- feature_1 <= 1.50
# |   |   |   |   |   |   |--- feature_0 <= 70.00
# |   |   |   |   |   |   |   |--- feature_12 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_10 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_10 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 12.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  12.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_12 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_0 >  70.00
# |   |   |   |   |   |   |   |--- feature_6 <= 4.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 5.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_5 >  5.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_6 >  4.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 22.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 10.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  10.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  22.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 8.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  8.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_1 >  1.50
# |   |   |   |   |   |   |--- feature_6 <= 16.50
# |   |   |   |   |   |   |   |--- feature_6 <= 6.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 2202.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 173.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  173.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  2202.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 2229.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  2229.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_6 >  6.50
# |   |   |   |   |   |   |   |   |--- feature_7 <= 307.33
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_7 >  307.33
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_6 >  16.50
# |   |   |   |   |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 2.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 5.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  5.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_1 >  2.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- feature_11 >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |--- feature_5 >  9.50
# |   |   |   |--- feature_12 <= 0.50
# |   |   |   |   |--- feature_11 <= 0.50
# |   |   |   |   |   |--- feature_6 <= 17.50
# |   |   |   |   |   |   |--- feature_2 <= 14.50
# |   |   |   |   |   |   |   |--- feature_0 <= 157.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 81.00
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 16.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  16.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  81.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_0 >  157.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_2 >  14.50
# |   |   |   |   |   |   |   |--- feature_6 <= 2.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_6 >  2.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_6 >  17.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- feature_11 >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- feature_12 >  0.50
# |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |--- feature_5 <= 13.50
# |   |   |   |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |   |   |   |--- feature_6 <= 7.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 3.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 76.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  76.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  3.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 10.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  10.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_6 >  7.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |   |   |   |--- feature_1 <= 2.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 40.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  40.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_1 >  2.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 12.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 55.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  55.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_5 >  12.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 149.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  149.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_5 >  13.50
# |   |   |   |   |   |   |--- feature_0 <= 64.00
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_0 >  64.00
# |   |   |   |   |   |   |   |--- feature_5 <= 21.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 1.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 15.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  15.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_1 >  1.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_5 >  21.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 1.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 3.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  3.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_1 >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |--- feature_5 <= 201.00
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_5 >  201.00
# |   |   |   |   |   |   |--- class: 1.0
# |--- feature_14 >  0.50
# |   |--- feature_13 <= 0.50
# |   |   |--- feature_6 <= 2.50
# |   |   |   |--- feature_1 <= 341.50
# |   |   |   |   |--- feature_5 <= 7.50
# |   |   |   |   |   |--- feature_2 <= 68.50
# |   |   |   |   |   |   |--- feature_1 <= 69.50
# |   |   |   |   |   |   |   |--- feature_5 <= 2.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 245.50
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_4 >  245.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 215.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  215.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_5 >  2.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 16.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 5.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  5.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_1 >  16.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 31810.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  31810.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_1 >  69.50
# |   |   |   |   |   |   |   |--- feature_7 <= 1723.71
# |   |   |   |   |   |   |   |   |--- feature_2 <= 38.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_2 >  38.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 67.74
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  67.74
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_7 >  1723.71
# |   |   |   |   |   |   |   |   |--- feature_5 <= 3.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 126118.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  126118.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_5 >  3.00
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 1960.88
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  1960.88
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_2 >  68.50
# |   |   |   |   |   |   |--- feature_7 <= 67.32
# |   |   |   |   |   |   |   |--- feature_7 <= 66.11
# |   |   |   |   |   |   |   |   |--- feature_4 <= 145.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 127.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  127.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_4 >  145.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_7 >  66.11
# |   |   |   |   |   |   |   |   |--- feature_2 <= 247.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 223.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  223.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_2 >  247.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 335.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  335.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_7 >  67.32
# |   |   |   |   |   |   |   |--- feature_5 <= 1.50
# |   |   |   |   |   |   |   |   |--- feature_7 <= 205.04
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 170.26
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  170.26
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_7 >  205.04
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 661636.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  661636.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_5 >  1.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 702848.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 235.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  235.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  702848.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- feature_5 >  7.50
# |   |   |   |   |   |--- feature_7 <= 78.01
# |   |   |   |   |   |   |--- feature_6 <= 1.50
# |   |   |   |   |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 12.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 60.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  60.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_5 >  12.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 76.17
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  76.17
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_6 >  1.50
# |   |   |   |   |   |   |   |--- feature_1 <= 42.00
# |   |   |   |   |   |   |   |   |--- feature_7 <= 57.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_7 >  57.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 144.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  144.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_1 >  42.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_7 >  78.01
# |   |   |   |   |   |   |--- feature_7 <= 2132.71
# |   |   |   |   |   |   |   |--- feature_0 <= 17322.00
# |   |   |   |   |   |   |   |   |--- feature_4 <= 242.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 16.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  16.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_4 >  242.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 17.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  17.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_0 >  17322.00
# |   |   |   |   |   |   |   |   |--- feature_6 <= 1.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 25.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  25.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  1.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 11.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  11.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_7 >  2132.71
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- feature_1 >  341.50
# |   |   |   |   |--- feature_5 <= 11.00
# |   |   |   |   |   |--- feature_7 <= 1868.21
# |   |   |   |   |   |   |--- feature_5 <= 9.50
# |   |   |   |   |   |   |   |--- feature_1 <= 711.50
# |   |   |   |   |   |   |   |   |--- feature_7 <= 69.19
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_7 >  69.19
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 1314504.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  1314504.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_1 >  711.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 692.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 1726.47
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  1726.47
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_2 >  692.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_5 >  9.50
# |   |   |   |   |   |   |   |--- feature_7 <= 938.46
# |   |   |   |   |   |   |   |   |--- feature_7 <= 70.30
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 231.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  231.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_7 >  70.30
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 1686366.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  1686366.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_7 >  938.46
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_7 >  1868.21
# |   |   |   |   |   |   |--- feature_0 <= 1056036.50
# |   |   |   |   |   |   |   |--- feature_6 <= 1.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 9.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_5 >  9.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 934446.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  934446.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_6 >  1.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_0 >  1056036.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- feature_5 >  11.00
# |   |   |   |   |   |--- class: 0.0
# |   |   |--- feature_6 >  2.50
# |   |   |   |--- feature_2 <= 4.50
# |   |   |   |   |--- feature_4 <= 228.50
# |   |   |   |   |   |--- feature_2 <= 3.50
# |   |   |   |   |   |   |--- feature_7 <= 428.55
# |   |   |   |   |   |   |   |--- feature_5 <= 5.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 4.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 62.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  62.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  4.50
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_5 >  5.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 12.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 738.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  738.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_5 >  12.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 57.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  57.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_7 >  428.55
# |   |   |   |   |   |   |   |--- feature_2 <= 2.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_2 >  2.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 59.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_4 >  59.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_2 >  3.50
# |   |   |   |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |   |   |   |--- feature_7 <= 71.88
# |   |   |   |   |   |   |   |   |--- feature_6 <= 4.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 6.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  6.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  4.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_7 >  71.88
# |   |   |   |   |   |   |   |   |--- feature_7 <= 136.00
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 56.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  56.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_7 >  136.00
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 6.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  6.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- feature_4 >  228.50
# |   |   |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |   |   |--- feature_6 <= 6.50
# |   |   |   |   |   |   |   |--- feature_10 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 234.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_4 >  234.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 2.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  2.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_10 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_6 >  6.50
# |   |   |   |   |   |   |   |--- feature_11 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_7 <= 72.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_7 >  72.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_11 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |   |   |--- feature_7 <= 76.92
# |   |   |   |   |   |   |   |--- feature_0 <= 558.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 2.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_1 >  2.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 233.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  233.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_0 >  558.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 234.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 11.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  11.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_4 >  234.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_7 >  76.92
# |   |   |   |   |   |   |   |--- feature_0 <= 1509.00
# |   |   |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 87.65
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  87.65
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_0 >  1509.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 2637.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  2637.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 4090.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  4090.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- feature_2 >  4.50
# |   |   |   |   |--- feature_0 <= 8167.00
# |   |   |   |   |   |--- feature_7 <= 70.29
# |   |   |   |   |   |   |--- feature_5 <= 3.00
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_5 >  3.00
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_7 >  70.29
# |   |   |   |   |   |   |--- feature_6 <= 24.00
# |   |   |   |   |   |   |   |--- feature_4 <= 51.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_4 >  51.00
# |   |   |   |   |   |   |   |   |--- feature_2 <= 7.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 96.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  96.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_2 >  7.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 355.89
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  355.89
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_6 >  24.00
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- feature_0 >  8167.00
# |   |   |   |   |   |--- feature_2 <= 48.50
# |   |   |   |   |   |   |--- feature_6 <= 5.50
# |   |   |   |   |   |   |   |--- feature_1 <= 36.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 3.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 14088.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  14088.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  3.50
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_1 >  36.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 148.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_4 >  148.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 49413.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  49413.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_6 >  5.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_2 >  48.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |--- feature_13 >  0.50
# |   |   |--- feature_5 <= 14.50
# |   |   |   |--- feature_1 <= 340.50
# |   |   |   |   |--- feature_7 <= 1927.16
# |   |   |   |   |   |--- feature_6 <= 7.50
# |   |   |   |   |   |   |--- feature_7 <= 556.20
# |   |   |   |   |   |   |   |--- feature_4 <= 85.00
# |   |   |   |   |   |   |   |   |--- feature_4 <= 41.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_4 >  41.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 59.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  59.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_4 >  85.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 20.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 293.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  293.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_1 >  20.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 76.47
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  76.47
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_7 >  556.20
# |   |   |   |   |   |   |   |--- feature_1 <= 137.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 7341.00
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  7341.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 99591.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  99591.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_1 >  137.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 634707.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 315.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  315.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  634707.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_6 >  7.50
# |   |   |   |   |   |   |--- feature_2 <= 3.50
# |   |   |   |   |   |   |   |--- feature_4 <= 149.00
# |   |   |   |   |   |   |   |   |--- feature_6 <= 19.00
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 501.17
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  501.17
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  19.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_4 >  149.00
# |   |   |   |   |   |   |   |   |--- feature_4 <= 236.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_4 >  236.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_2 >  3.50
# |   |   |   |   |   |   |   |--- feature_0 <= 7055.00
# |   |   |   |   |   |   |   |   |--- feature_7 <= 210.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 134.68
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  134.68
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_7 >  210.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 6015.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  6015.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_0 >  7055.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- feature_7 >  1927.16
# |   |   |   |   |   |--- feature_2 <= 116.50
# |   |   |   |   |   |   |--- feature_2 <= 17.00
# |   |   |   |   |   |   |   |--- feature_0 <= 8053.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_0 >  8053.00
# |   |   |   |   |   |   |   |   |--- feature_6 <= 3.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  3.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_2 >  17.00
# |   |   |   |   |   |   |   |--- feature_5 <= 6.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 3.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 2656.80
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  2656.80
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_5 >  3.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_5 >  6.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 12.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 2049.40
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  2049.40
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_5 >  12.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_2 >  116.50
# |   |   |   |   |   |   |--- feature_5 <= 13.50
# |   |   |   |   |   |   |   |--- feature_0 <= 241872.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_0 >  241872.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 153.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 550295.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  550295.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_4 >  153.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_5 >  13.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- feature_1 >  340.50
# |   |   |   |   |--- feature_7 <= 214.34
# |   |   |   |   |   |--- feature_0 <= 107088.00
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_0 >  107088.00
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- feature_7 >  214.34
# |   |   |   |   |   |--- feature_4 <= 155.50
# |   |   |   |   |   |   |--- feature_7 <= 271.08
# |   |   |   |   |   |   |   |--- feature_2 <= 343.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 337.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_2 >  337.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 108302.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  108302.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_2 >  343.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 110459.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 350.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  350.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  110459.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_7 >  271.08
# |   |   |   |   |   |   |   |--- feature_1 <= 428.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 143754.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 407.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  407.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  143754.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_1 >  428.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 1.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 875.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  875.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_4 >  155.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |--- feature_5 >  14.50
# |   |   |   |--- feature_2 <= 349.00
# |   |   |   |   |--- feature_6 <= 1.50
# |   |   |   |   |   |--- feature_1 <= 17.50
# |   |   |   |   |   |   |--- feature_11 <= 0.50
# |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 20.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_5 >  20.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 98.17
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  98.17
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_7 <= 180.25
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 103.64
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  103.64
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_7 >  180.25
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 59.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  59.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_11 >  0.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_1 >  17.50
# |   |   |   |   |   |   |--- feature_5 <= 25.00
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_5 >  25.00
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- feature_6 >  1.50
# |   |   |   |   |   |--- feature_5 <= 20.50
# |   |   |   |   |   |   |--- feature_0 <= 6147.50
# |   |   |   |   |   |   |   |--- feature_7 <= 112.79
# |   |   |   |   |   |   |   |   |--- feature_6 <= 7.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  7.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_7 >  112.79
# |   |   |   |   |   |   |   |   |--- feature_1 <= 4.00
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 7.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  7.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_1 >  4.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_0 >  6147.50
# |   |   |   |   |   |   |   |--- feature_6 <= 3.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_6 >  3.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 12.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 155.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  155.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_2 >  12.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_5 >  20.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- feature_2 >  349.00
# |   |   |   |   |--- class: 0.0

# %% [markdown]
# # Convert tree into match action table

# %%
from io import StringIO
from numbers import Integral

import numpy as np
import pandas
import pickle 
import sklearn
from sklearn import tree 
from sklearn.tree import export_text

from sklearn.tree import _tree

from sklearn.tree import DecisionTreeClassifier

filename = 'combined_notime.sav'
rf = pickle.load(open(filename, 'rb'))

i_tree = 0 

global_id = 0

def export_p4(decision_tree):
    tree_ = decision_tree.tree_
    class_names = decision_tree.classes_
    right_child_fmt = "{} {} <= {}\n"
    left_child_fmt = "{} {} >  {}\n"
    truncation_fmt = "{} {}\n"
    feature_names_ = ["{}".format(i) for i in tree_.feature]  
    export_text.report = ""
    max_depth=10
    spacing=3
    decimals=2
    show_weights=False

    if isinstance(decision_tree, DecisionTreeClassifier):
        value_fmt = "{}{} weights: {}\n"
        if not show_weights:
            value_fmt = "{}{}{}\n"
    else:
        value_fmt = "{}{} value: {}\n"

    def _add_leaf(value, class_name, indent, prevfeature, result, depth, previous_id):
        global global_id
        global i_tree 
        current_id = global_id

        val = ''
        is_classification = isinstance(decision_tree,
                                       DecisionTreeClassifier)
        if show_weights or not is_classification:
            val = ["{1:.{0}f}, ".format(decimals, v) for v in value]
            val = '['+''.join(val)[:-2]+']'
        if is_classification:
            val += ' class: ' + str(class_name)
        export_text.report += value_fmt.format(indent, '', val)
        print("table_add MyIngress.level_", depth, " ", "MyIngress.SetClass"," ", previous_id," ",prevfeature," ", result," ", "=>"," ", current_id, " ", int(float(class_name)), sep="")

    def print_tree_recurse(node, depth, prevfeature, result, previous_id):
        indent = ("|" + (" " * spacing)) * depth
        indent = indent[:-spacing] + "-" * spacing
        global global_id
        global i_tree 
        global_id = global_id + 1
        current_id = global_id

        value = None
        if tree_.n_outputs == 1:
            value = tree_.value[node][0]
        else:
            value = tree_.value[node].T[0]
        class_name = np.argmax(value)

        if (tree_.n_classes[0] != 1 and
                tree_.n_outputs == 1):
            class_name = class_names[class_name]

        if depth <= max_depth+1:
            info_fmt = ""
            info_fmt_left = info_fmt
            info_fmt_right = info_fmt

            if tree_.feature[node] != _tree.TREE_UNDEFINED:
                name = feature_names_[node]
                threshold = tree_.threshold[node]
                threshold = "{1:.{0}f}".format(decimals, threshold)
                export_text.report += right_child_fmt.format(indent,
                                                             name,
                                                             threshold)
                export_text.report += info_fmt_left
                print("table_add MyIngress.level_", depth, " MyIngress.CheckFeature ", previous_id, " ", prevfeature, " ", result, " ", "=>", " ", current_id, " ", name," ", int(float(threshold)), sep='')

                print_tree_recurse(tree_.children_left[node], depth+1, name, 1, current_id)

                export_text.report += left_child_fmt.format(indent,
                                                            name,
                                                            threshold)
                export_text.report += info_fmt_right
           #     print("level", depth, "checkfeature", prevfeature, result, "=>", name, threshold)
 

                print_tree_recurse(tree_.children_right[node], depth+1, name, 0, current_id)
            else:  # leaf
                _add_leaf(value, class_name, indent, prevfeature, result, depth, previous_id)
        else:
            subtree_depth = _compute_depth(tree_, node)
            if subtree_depth == 1:
                _add_leaf(value, class_name, indent, prevfeature, result, depth, previous_id)
            else:
                trunc_report = 'truncated branch of depth %d' % subtree_depth
                export_text.report += truncation_fmt.format(indent,
                                                            trunc_report)

    print_tree_recurse(0, 1, 0, 1, global_id)


for tree_in_forest in rf.estimators_:
  #r = export_text(tree_in_forest)
  #print(r)
  global i_tree

  i_tree = i_tree + 1
  export_p4(tree_in_forest)
# Out:
# table_add MyIngress.level_1 MyIngress.CheckFeature 0 0 1 => 1 14 0
# table_add MyIngress.level_2 MyIngress.CheckFeature 1 14 1 => 2 3 0
# table_add MyIngress.level_3 MyIngress.CheckFeature 2 3 1 => 3 4 85
# table_add MyIngress.level_4 MyIngress.CheckFeature 3 4 1 => 4 5 9
# table_add MyIngress.level_5 MyIngress.CheckFeature 4 5 1 => 5 2 0
# table_add MyIngress.level_6 MyIngress.CheckFeature 5 2 1 => 6 5 1
# table_add MyIngress.level_7 MyIngress.CheckFeature 6 5 1 => 7 1 10
# table_add MyIngress.level_8 MyIngress.CheckFeature 7 1 1 => 8 4 21
# table_add MyIngress.level_9 MyIngress.CheckFeature 8 4 1 => 9 0 85
# table_add MyIngress.level_10 MyIngress.SetClass 9 0 1 => 10 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 9 0 0 => 11 7 160
# table_add MyIngress.level_11 MyIngress.SetClass 11 7 1 => 12 0
# table_add MyIngress.level_11 MyIngress.SetClass 11 7 0 => 13 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 8 4 0 => 14 7 401
# table_add MyIngress.level_10 MyIngress.CheckFeature 14 7 1 => 15 1 6
# table_add MyIngress.level_11 MyIngress.SetClass 15 1 1 => 16 0
# table_add MyIngress.level_11 MyIngress.SetClass 15 1 0 => 17 0
# table_add MyIngress.level_10 MyIngress.SetClass 14 7 0 => 18 1
# table_add MyIngress.level_8 MyIngress.CheckFeature 7 1 0 => 19 6 20
# table_add MyIngress.level_9 MyIngress.SetClass 19 6 1 => 20 1
# table_add MyIngress.level_9 MyIngress.SetClass 19 6 0 => 21 0
# table_add MyIngress.level_7 MyIngress.CheckFeature 6 5 0 => 22 6 2
# table_add MyIngress.level_8 MyIngress.CheckFeature 22 6 1 => 23 8 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 23 8 1 => 24 5 3
# table_add MyIngress.level_10 MyIngress.CheckFeature 24 5 1 => 25 0 128
# table_add MyIngress.level_11 MyIngress.SetClass 25 0 1 => 26 0
# table_add MyIngress.level_11 MyIngress.SetClass 25 0 0 => 27 0
# table_add MyIngress.level_10 MyIngress.CheckFeature 24 5 0 => 28 5 4
# table_add MyIngress.level_11 MyIngress.SetClass 28 5 1 => 29 0
# table_add MyIngress.level_11 MyIngress.SetClass 28 5 0 => 30 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 23 8 0 => 31 1 24
# table_add MyIngress.level_10 MyIngress.CheckFeature 31 1 1 => 32 5 3
# table_add MyIngress.level_11 MyIngress.SetClass 32 5 1 => 33 0
# table_add MyIngress.level_11 MyIngress.SetClass 32 5 0 => 34 0
# table_add MyIngress.level_10 MyIngress.SetClass 31 1 0 => 35 1
# table_add MyIngress.level_8 MyIngress.CheckFeature 22 6 0 => 36 1 23
# table_add MyIngress.level_9 MyIngress.CheckFeature 36 1 1 => 37 6 27
# table_add MyIngress.level_10 MyIngress.CheckFeature 37 6 1 => 38 0 8452
# table_add MyIngress.level_11 MyIngress.SetClass 38 0 1 => 39 0
# table_add MyIngress.level_11 MyIngress.SetClass 38 0 0 => 40 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 37 6 0 => 41 8 0
# table_add MyIngress.level_11 MyIngress.SetClass 41 8 1 => 42 1
# table_add MyIngress.level_11 MyIngress.SetClass 41 8 0 => 43 1
# table_add MyIngress.level_9 MyIngress.CheckFeature 36 1 0 => 44 6 6
# table_add MyIngress.level_10 MyIngress.CheckFeature 44 6 1 => 45 7 927
# table_add MyIngress.level_11 MyIngress.SetClass 45 7 1 => 46 0
# table_add MyIngress.level_11 MyIngress.SetClass 45 7 0 => 47 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 44 6 0 => 48 0 8180
# table_add MyIngress.level_11 MyIngress.SetClass 48 0 1 => 49 1
# table_add MyIngress.level_11 MyIngress.SetClass 48 0 0 => 50 1
# table_add MyIngress.level_6 MyIngress.CheckFeature 5 2 0 => 51 0 5296
# table_add MyIngress.level_7 MyIngress.CheckFeature 51 0 1 => 52 2 48
# table_add MyIngress.level_8 MyIngress.CheckFeature 52 2 1 => 53 6 1
# table_add MyIngress.level_9 MyIngress.CheckFeature 53 6 1 => 54 2 23
# table_add MyIngress.level_10 MyIngress.CheckFeature 54 2 1 => 55 4 50
# table_add MyIngress.level_11 MyIngress.SetClass 55 4 1 => 56 0
# table_add MyIngress.level_11 MyIngress.SetClass 55 4 0 => 57 0
# table_add MyIngress.level_10 MyIngress.CheckFeature 54 2 0 => 58 2 25
# table_add MyIngress.level_11 MyIngress.SetClass 58 2 1 => 59 1
# table_add MyIngress.level_11 MyIngress.SetClass 58 2 0 => 60 1
# table_add MyIngress.level_9 MyIngress.CheckFeature 53 6 0 => 61 6 6
# table_add MyIngress.level_10 MyIngress.CheckFeature 61 6 1 => 62 6 2
# table_add MyIngress.level_11 MyIngress.SetClass 62 6 1 => 63 0
# table_add MyIngress.level_11 MyIngress.SetClass 62 6 0 => 64 0
# table_add MyIngress.level_10 MyIngress.SetClass 61 6 0 => 65 1
# table_add MyIngress.level_8 MyIngress.CheckFeature 52 2 0 => 66 6 3
# table_add MyIngress.level_9 MyIngress.SetClass 66 6 1 => 67 1
# table_add MyIngress.level_9 MyIngress.SetClass 66 6 0 => 68 0
# table_add MyIngress.level_7 MyIngress.SetClass 51 0 0 => 69 0
# table_add MyIngress.level_5 MyIngress.CheckFeature 4 5 0 => 70 0 338
# table_add MyIngress.level_6 MyIngress.CheckFeature 70 0 1 => 71 4 59
# table_add MyIngress.level_7 MyIngress.SetClass 71 4 1 => 72 0
# table_add MyIngress.level_7 MyIngress.CheckFeature 71 4 0 => 73 2 0
# table_add MyIngress.level_8 MyIngress.SetClass 73 2 1 => 74 0
# table_add MyIngress.level_8 MyIngress.CheckFeature 73 2 0 => 75 6 28
# table_add MyIngress.level_9 MyIngress.CheckFeature 75 6 1 => 76 7 72
# table_add MyIngress.level_10 MyIngress.CheckFeature 76 7 1 => 77 6 5
# table_add MyIngress.level_11 MyIngress.SetClass 77 6 1 => 78 0
# table_add MyIngress.level_11 MyIngress.SetClass 77 6 0 => 79 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 76 7 0 => 80 1 1
# table_add MyIngress.level_11 MyIngress.SetClass 80 1 1 => 81 0
# table_add MyIngress.level_11 MyIngress.SetClass 80 1 0 => 82 0
# table_add MyIngress.level_9 MyIngress.SetClass 75 6 0 => 83 1
# table_add MyIngress.level_6 MyIngress.CheckFeature 70 0 0 => 84 1 2
# table_add MyIngress.level_7 MyIngress.CheckFeature 84 1 1 => 85 7 89
# table_add MyIngress.level_8 MyIngress.CheckFeature 85 7 1 => 86 0 417
# table_add MyIngress.level_9 MyIngress.CheckFeature 86 0 1 => 87 5 42
# table_add MyIngress.level_10 MyIngress.SetClass 87 5 1 => 88 0
# table_add MyIngress.level_10 MyIngress.CheckFeature 87 5 0 => 89 0 393
# table_add MyIngress.level_11 MyIngress.SetClass 89 0 1 => 90 0
# table_add MyIngress.level_11 MyIngress.SetClass 89 0 0 => 91 1
# table_add MyIngress.level_9 MyIngress.CheckFeature 86 0 0 => 92 1 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 92 1 1 => 93 0 432
# table_add MyIngress.level_11 MyIngress.SetClass 93 0 1 => 94 0
# table_add MyIngress.level_11 MyIngress.SetClass 93 0 0 => 95 0
# table_add MyIngress.level_10 MyIngress.SetClass 92 1 0 => 96 0
# table_add MyIngress.level_8 MyIngress.SetClass 85 7 0 => 97 0
# table_add MyIngress.level_7 MyIngress.SetClass 84 1 0 => 98 0
# table_add MyIngress.level_4 MyIngress.CheckFeature 3 4 0 => 99 1 6
# table_add MyIngress.level_5 MyIngress.CheckFeature 99 1 1 => 100 2 0
# table_add MyIngress.level_6 MyIngress.CheckFeature 100 2 1 => 101 5 1
# table_add MyIngress.level_7 MyIngress.CheckFeature 101 5 1 => 102 9 0
# table_add MyIngress.level_8 MyIngress.CheckFeature 102 9 1 => 103 0 302
# table_add MyIngress.level_9 MyIngress.CheckFeature 103 0 1 => 104 7 99
# table_add MyIngress.level_10 MyIngress.CheckFeature 104 7 1 => 105 7 83
# table_add MyIngress.level_11 MyIngress.SetClass 105 7 1 => 106 0
# table_add MyIngress.level_11 MyIngress.SetClass 105 7 0 => 107 1
# table_add MyIngress.level_10 MyIngress.SetClass 104 7 0 => 108 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 103 0 0 => 109 6 22
# table_add MyIngress.level_10 MyIngress.CheckFeature 109 6 1 => 110 7 105
# table_add MyIngress.level_11 MyIngress.SetClass 110 7 1 => 111 1
# table_add MyIngress.level_11 MyIngress.SetClass 110 7 0 => 112 0
# table_add MyIngress.level_10 MyIngress.CheckFeature 109 6 0 => 113 7 148
# table_add MyIngress.level_11 MyIngress.SetClass 113 7 1 => 114 0
# table_add MyIngress.level_11 MyIngress.SetClass 113 7 0 => 115 1
# table_add MyIngress.level_8 MyIngress.CheckFeature 102 9 0 => 116 7 147
# table_add MyIngress.level_9 MyIngress.CheckFeature 116 7 1 => 117 6 2
# table_add MyIngress.level_10 MyIngress.CheckFeature 117 6 1 => 118 7 92
# table_add MyIngress.level_11 MyIngress.SetClass 118 7 1 => 119 1
# table_add MyIngress.level_11 MyIngress.SetClass 118 7 0 => 120 0
# table_add MyIngress.level_10 MyIngress.SetClass 117 6 0 => 121 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 116 7 0 => 122 7 179
# table_add MyIngress.level_10 MyIngress.SetClass 122 7 1 => 123 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 122 7 0 => 124 6 13
# table_add MyIngress.level_11 MyIngress.SetClass 124 6 1 => 125 0
# table_add MyIngress.level_11 MyIngress.SetClass 124 6 0 => 126 0
# table_add MyIngress.level_7 MyIngress.CheckFeature 101 5 0 => 127 7 89
# table_add MyIngress.level_8 MyIngress.CheckFeature 127 7 1 => 128 9 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 128 9 1 => 129 6 2
# table_add MyIngress.level_10 MyIngress.CheckFeature 129 6 1 => 130 6 1
# table_add MyIngress.level_11 MyIngress.SetClass 130 6 1 => 131 0
# table_add MyIngress.level_11 MyIngress.SetClass 130 6 0 => 132 1
# table_add MyIngress.level_10 MyIngress.SetClass 129 6 0 => 133 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 128 9 0 => 134 6 9
# table_add MyIngress.level_10 MyIngress.CheckFeature 134 6 1 => 135 4 191
# table_add MyIngress.level_11 MyIngress.SetClass 135 4 1 => 136 1
# table_add MyIngress.level_11 MyIngress.SetClass 135 4 0 => 137 0
# table_add MyIngress.level_10 MyIngress.CheckFeature 134 6 0 => 138 0 84
# table_add MyIngress.level_11 MyIngress.SetClass 138 0 1 => 139 0
# table_add MyIngress.level_11 MyIngress.SetClass 138 0 0 => 140 1
# table_add MyIngress.level_8 MyIngress.CheckFeature 127 7 0 => 141 0 426
# table_add MyIngress.level_9 MyIngress.CheckFeature 141 0 1 => 142 5 4
# table_add MyIngress.level_10 MyIngress.CheckFeature 142 5 1 => 143 0 376
# table_add MyIngress.level_11 MyIngress.SetClass 143 0 1 => 144 0
# table_add MyIngress.level_11 MyIngress.SetClass 143 0 0 => 145 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 142 5 0 => 146 7 144
# table_add MyIngress.level_11 MyIngress.SetClass 146 7 1 => 147 0
# table_add MyIngress.level_11 MyIngress.SetClass 146 7 0 => 148 0
# table_add MyIngress.level_9 MyIngress.SetClass 141 0 0 => 149 0
# table_add MyIngress.level_6 MyIngress.CheckFeature 100 2 0 => 150 6 2
# table_add MyIngress.level_7 MyIngress.CheckFeature 150 6 1 => 151 7 129
# table_add MyIngress.level_8 MyIngress.CheckFeature 151 7 1 => 152 7 65
# table_add MyIngress.level_9 MyIngress.SetClass 152 7 1 => 153 1
# table_add MyIngress.level_9 MyIngress.CheckFeature 152 7 0 => 154 6 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 154 6 1 => 155 7 88
# table_add MyIngress.level_11 MyIngress.SetClass 155 7 1 => 156 0
# table_add MyIngress.level_11 MyIngress.SetClass 155 7 0 => 157 0
# table_add MyIngress.level_10 MyIngress.CheckFeature 154 6 0 => 158 2 1
# table_add MyIngress.level_11 MyIngress.SetClass 158 2 1 => 159 0
# table_add MyIngress.level_11 MyIngress.SetClass 158 2 0 => 160 0
# table_add MyIngress.level_8 MyIngress.CheckFeature 151 7 0 => 161 4 125
# table_add MyIngress.level_9 MyIngress.CheckFeature 161 4 1 => 162 6 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 162 6 1 => 163 7 166
# table_add MyIngress.level_11 MyIngress.SetClass 163 7 1 => 164 1
# table_add MyIngress.level_11 MyIngress.SetClass 163 7 0 => 165 0
# table_add MyIngress.level_10 MyIngress.SetClass 162 6 0 => 166 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 161 4 0 => 167 0 269
# table_add MyIngress.level_10 MyIngress.SetClass 167 0 1 => 168 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 167 0 0 => 169 7 156
# table_add MyIngress.level_11 MyIngress.SetClass 169 7 1 => 170 1
# table_add MyIngress.level_11 MyIngress.SetClass 169 7 0 => 171 0
# table_add MyIngress.level_7 MyIngress.CheckFeature 150 6 0 => 172 6 5
# table_add MyIngress.level_8 MyIngress.CheckFeature 172 6 1 => 173 2 1
# table_add MyIngress.level_9 MyIngress.CheckFeature 173 2 1 => 174 7 74
# table_add MyIngress.level_10 MyIngress.SetClass 174 7 1 => 175 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 174 7 0 => 176 6 3
# table_add MyIngress.level_11 MyIngress.SetClass 176 6 1 => 177 0
# table_add MyIngress.level_11 MyIngress.SetClass 176 6 0 => 178 0
# table_add MyIngress.level_9 MyIngress.SetClass 173 2 0 => 179 0
# table_add MyIngress.level_8 MyIngress.SetClass 172 6 0 => 180 0
# table_add MyIngress.level_5 MyIngress.CheckFeature 99 1 0 => 181 6 6
# table_add MyIngress.level_6 MyIngress.CheckFeature 181 6 1 => 182 4 191
# table_add MyIngress.level_7 MyIngress.SetClass 182 4 1 => 183 0
# table_add MyIngress.level_7 MyIngress.CheckFeature 182 4 0 => 184 7 481
# table_add MyIngress.level_8 MyIngress.CheckFeature 184 7 1 => 185 1 7
# table_add MyIngress.level_9 MyIngress.CheckFeature 185 1 1 => 186 0 772
# table_add MyIngress.level_10 MyIngress.CheckFeature 186 0 1 => 187 5 5
# table_add MyIngress.level_11 MyIngress.SetClass 187 5 1 => 188 1
# table_add MyIngress.level_11 MyIngress.SetClass 187 5 0 => 189 0
# table_add MyIngress.level_10 MyIngress.SetClass 186 0 0 => 190 0
# table_add MyIngress.level_9 MyIngress.SetClass 185 1 0 => 191 0
# table_add MyIngress.level_8 MyIngress.SetClass 184 7 0 => 192 1
# table_add MyIngress.level_6 MyIngress.CheckFeature 181 6 0 => 193 5 1
# table_add MyIngress.level_7 MyIngress.CheckFeature 193 5 1 => 194 6 23
# table_add MyIngress.level_8 MyIngress.CheckFeature 194 6 1 => 195 7 222
# table_add MyIngress.level_9 MyIngress.SetClass 195 7 1 => 196 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 195 7 0 => 197 0 1725
# table_add MyIngress.level_10 MyIngress.CheckFeature 197 0 1 => 198 6 22
# table_add MyIngress.level_11 MyIngress.SetClass 198 6 1 => 199 0
# table_add MyIngress.level_11 MyIngress.SetClass 198 6 0 => 200 1
# table_add MyIngress.level_10 MyIngress.SetClass 197 0 0 => 201 0
# table_add MyIngress.level_8 MyIngress.SetClass 194 6 0 => 202 0
# table_add MyIngress.level_7 MyIngress.SetClass 193 5 0 => 203 0
# table_add MyIngress.level_3 MyIngress.CheckFeature 2 3 0 => 204 5 9
# table_add MyIngress.level_4 MyIngress.CheckFeature 204 5 1 => 205 6 3
# table_add MyIngress.level_5 MyIngress.CheckFeature 205 6 1 => 206 1 4
# table_add MyIngress.level_6 MyIngress.CheckFeature 206 1 1 => 207 11 0
# table_add MyIngress.level_7 MyIngress.CheckFeature 207 11 1 => 208 7 55
# table_add MyIngress.level_8 MyIngress.CheckFeature 208 7 1 => 209 5 1
# table_add MyIngress.level_9 MyIngress.SetClass 209 5 1 => 210 1
# table_add MyIngress.level_9 MyIngress.CheckFeature 209 5 0 => 211 6 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 211 6 1 => 212 5 2
# table_add MyIngress.level_11 MyIngress.SetClass 212 5 1 => 213 1
# table_add MyIngress.level_11 MyIngress.SetClass 212 5 0 => 214 0
# table_add MyIngress.level_10 MyIngress.CheckFeature 211 6 0 => 215 2 0
# table_add MyIngress.level_11 MyIngress.SetClass 215 2 1 => 216 1
# table_add MyIngress.level_11 MyIngress.SetClass 215 2 0 => 217 0
# table_add MyIngress.level_8 MyIngress.CheckFeature 208 7 0 => 218 4 182
# table_add MyIngress.level_9 MyIngress.CheckFeature 218 4 1 => 219 5 3
# table_add MyIngress.level_10 MyIngress.CheckFeature 219 5 1 => 220 2 2
# table_add MyIngress.level_11 MyIngress.SetClass 220 2 1 => 221 1
# table_add MyIngress.level_11 MyIngress.SetClass 220 2 0 => 222 0
# table_add MyIngress.level_10 MyIngress.CheckFeature 219 5 0 => 223 12 0
# table_add MyIngress.level_11 MyIngress.SetClass 223 12 1 => 224 1
# table_add MyIngress.level_11 MyIngress.SetClass 223 12 0 => 225 0
# table_add MyIngress.level_9 MyIngress.SetClass 218 4 0 => 226 0
# table_add MyIngress.level_7 MyIngress.SetClass 207 11 0 => 227 1
# table_add MyIngress.level_6 MyIngress.CheckFeature 206 1 0 => 228 0 341786
# table_add MyIngress.level_7 MyIngress.CheckFeature 228 0 1 => 229 2 10
# table_add MyIngress.level_8 MyIngress.CheckFeature 229 2 1 => 230 8 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 230 8 1 => 231 1 6
# table_add MyIngress.level_10 MyIngress.SetClass 231 1 1 => 232 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 231 1 0 => 233 1 12
# table_add MyIngress.level_11 MyIngress.SetClass 233 1 1 => 234 0
# table_add MyIngress.level_11 MyIngress.SetClass 233 1 0 => 235 0
# table_add MyIngress.level_9 MyIngress.SetClass 230 8 0 => 236 0
# table_add MyIngress.level_8 MyIngress.CheckFeature 229 2 0 => 237 7 158
# table_add MyIngress.level_9 MyIngress.SetClass 237 7 1 => 238 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 237 7 0 => 239 0 6428
# table_add MyIngress.level_10 MyIngress.SetClass 239 0 1 => 240 0
# table_add MyIngress.level_10 MyIngress.SetClass 239 0 0 => 241 1
# table_add MyIngress.level_7 MyIngress.SetClass 228 0 0 => 242 1
# table_add MyIngress.level_5 MyIngress.CheckFeature 205 6 0 => 243 11 0
# table_add MyIngress.level_6 MyIngress.CheckFeature 243 11 1 => 244 1 1
# table_add MyIngress.level_7 MyIngress.CheckFeature 244 1 1 => 245 0 70
# table_add MyIngress.level_8 MyIngress.CheckFeature 245 0 1 => 246 12 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 246 12 1 => 247 10 0
# table_add MyIngress.level_10 MyIngress.SetClass 247 10 1 => 248 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 247 10 0 => 249 6 12
# table_add MyIngress.level_11 MyIngress.SetClass 249 6 1 => 250 1
# table_add MyIngress.level_11 MyIngress.SetClass 249 6 0 => 251 0
# table_add MyIngress.level_9 MyIngress.SetClass 246 12 0 => 252 1
# table_add MyIngress.level_8 MyIngress.CheckFeature 245 0 0 => 253 6 4
# table_add MyIngress.level_9 MyIngress.CheckFeature 253 6 1 => 254 5 5
# table_add MyIngress.level_10 MyIngress.SetClass 254 5 1 => 255 1
# table_add MyIngress.level_10 MyIngress.SetClass 254 5 0 => 256 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 253 6 0 => 257 6 22
# table_add MyIngress.level_10 MyIngress.CheckFeature 257 6 1 => 258 6 10
# table_add MyIngress.level_11 MyIngress.SetClass 258 6 1 => 259 1
# table_add MyIngress.level_11 MyIngress.SetClass 258 6 0 => 260 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 257 6 0 => 261 5 8
# table_add MyIngress.level_11 MyIngress.SetClass 261 5 1 => 262 1
# table_add MyIngress.level_11 MyIngress.SetClass 261 5 0 => 263 1
# table_add MyIngress.level_7 MyIngress.CheckFeature 244 1 0 => 264 6 16
# table_add MyIngress.level_8 MyIngress.CheckFeature 264 6 1 => 265 6 6
# table_add MyIngress.level_9 MyIngress.CheckFeature 265 6 1 => 266 0 2202
# table_add MyIngress.level_10 MyIngress.CheckFeature 266 0 1 => 267 0 173
# table_add MyIngress.level_11 MyIngress.SetClass 267 0 1 => 268 1
# table_add MyIngress.level_11 MyIngress.SetClass 267 0 0 => 269 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 266 0 0 => 270 0 2229
# table_add MyIngress.level_11 MyIngress.SetClass 270 0 1 => 271 0
# table_add MyIngress.level_11 MyIngress.SetClass 270 0 0 => 272 1
# table_add MyIngress.level_9 MyIngress.CheckFeature 265 6 0 => 273 7 307
# table_add MyIngress.level_10 MyIngress.SetClass 273 7 1 => 274 0
# table_add MyIngress.level_10 MyIngress.SetClass 273 7 0 => 275 1
# table_add MyIngress.level_8 MyIngress.CheckFeature 264 6 0 => 276 8 0
# table_add MyIngress.level_9 MyIngress.SetClass 276 8 1 => 277 1
# table_add MyIngress.level_9 MyIngress.CheckFeature 276 8 0 => 278 1 2
# table_add MyIngress.level_10 MyIngress.CheckFeature 278 1 1 => 279 5 5
# table_add MyIngress.level_11 MyIngress.SetClass 279 5 1 => 280 1
# table_add MyIngress.level_11 MyIngress.SetClass 279 5 0 => 281 1
# table_add MyIngress.level_10 MyIngress.SetClass 278 1 0 => 282 0
# table_add MyIngress.level_6 MyIngress.SetClass 243 11 0 => 283 1
# table_add MyIngress.level_4 MyIngress.CheckFeature 204 5 0 => 284 12 0
# table_add MyIngress.level_5 MyIngress.CheckFeature 284 12 1 => 285 11 0
# table_add MyIngress.level_6 MyIngress.CheckFeature 285 11 1 => 286 6 17
# table_add MyIngress.level_7 MyIngress.CheckFeature 286 6 1 => 287 2 14
# table_add MyIngress.level_8 MyIngress.CheckFeature 287 2 1 => 288 0 157
# table_add MyIngress.level_9 MyIngress.CheckFeature 288 0 1 => 289 0 81
# table_add MyIngress.level_10 MyIngress.CheckFeature 289 0 1 => 290 6 16
# table_add MyIngress.level_11 MyIngress.SetClass 290 6 1 => 291 1
# table_add MyIngress.level_11 MyIngress.SetClass 290 6 0 => 292 0
# table_add MyIngress.level_10 MyIngress.SetClass 289 0 0 => 293 0
# table_add MyIngress.level_9 MyIngress.SetClass 288 0 0 => 294 1
# table_add MyIngress.level_8 MyIngress.CheckFeature 287 2 0 => 295 6 2
# table_add MyIngress.level_9 MyIngress.SetClass 295 6 1 => 296 1
# table_add MyIngress.level_9 MyIngress.SetClass 295 6 0 => 297 0
# table_add MyIngress.level_7 MyIngress.SetClass 286 6 0 => 298 1
# table_add MyIngress.level_6 MyIngress.SetClass 285 11 0 => 299 1
# table_add MyIngress.level_5 MyIngress.CheckFeature 284 12 0 => 300 2 0
# table_add MyIngress.level_6 MyIngress.CheckFeature 300 2 1 => 301 5 13
# table_add MyIngress.level_7 MyIngress.CheckFeature 301 5 1 => 302 8 0
# table_add MyIngress.level_8 MyIngress.CheckFeature 302 8 1 => 303 6 7
# table_add MyIngress.level_9 MyIngress.CheckFeature 303 6 1 => 304 6 3
# table_add MyIngress.level_10 MyIngress.CheckFeature 304 6 1 => 305 0 76
# table_add MyIngress.level_11 MyIngress.SetClass 305 0 1 => 306 0
# table_add MyIngress.level_11 MyIngress.SetClass 305 0 0 => 307 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 304 6 0 => 308 5 10
# table_add MyIngress.level_11 MyIngress.SetClass 308 5 1 => 309 1
# table_add MyIngress.level_11 MyIngress.SetClass 308 5 0 => 310 0
# table_add MyIngress.level_9 MyIngress.SetClass 303 6 0 => 311 1
# table_add MyIngress.level_8 MyIngress.CheckFeature 302 8 0 => 312 1 2
# table_add MyIngress.level_9 MyIngress.CheckFeature 312 1 1 => 313 6 40
# table_add MyIngress.level_10 MyIngress.SetClass 313 6 1 => 314 0
# table_add MyIngress.level_10 MyIngress.SetClass 313 6 0 => 315 1
# table_add MyIngress.level_9 MyIngress.CheckFeature 312 1 0 => 316 5 12
# table_add MyIngress.level_10 MyIngress.CheckFeature 316 5 1 => 317 6 55
# table_add MyIngress.level_11 MyIngress.SetClass 317 6 1 => 318 0
# table_add MyIngress.level_11 MyIngress.SetClass 317 6 0 => 319 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 316 5 0 => 320 6 149
# table_add MyIngress.level_11 MyIngress.SetClass 320 6 1 => 321 0
# table_add MyIngress.level_11 MyIngress.SetClass 320 6 0 => 322 1
# table_add MyIngress.level_7 MyIngress.CheckFeature 301 5 0 => 323 0 64
# table_add MyIngress.level_8 MyIngress.SetClass 323 0 1 => 324 1
# table_add MyIngress.level_8 MyIngress.CheckFeature 323 0 0 => 325 5 21
# table_add MyIngress.level_9 MyIngress.CheckFeature 325 5 1 => 326 1 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 326 1 1 => 327 5 15
# table_add MyIngress.level_11 MyIngress.SetClass 327 5 1 => 328 1
# table_add MyIngress.level_11 MyIngress.SetClass 327 5 0 => 329 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 326 1 0 => 330 1 2
# table_add MyIngress.level_11 MyIngress.SetClass 330 1 1 => 331 1
# table_add MyIngress.level_11 MyIngress.SetClass 330 1 0 => 332 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 325 5 0 => 333 1 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 333 1 1 => 334 6 3
# table_add MyIngress.level_11 MyIngress.SetClass 334 6 1 => 335 0
# table_add MyIngress.level_11 MyIngress.SetClass 334 6 0 => 336 1
# table_add MyIngress.level_10 MyIngress.SetClass 333 1 0 => 337 1
# table_add MyIngress.level_6 MyIngress.CheckFeature 300 2 0 => 338 5 201
# table_add MyIngress.level_7 MyIngress.SetClass 338 5 1 => 339 0
# table_add MyIngress.level_7 MyIngress.SetClass 338 5 0 => 340 1
# table_add MyIngress.level_2 MyIngress.CheckFeature 1 14 0 => 341 13 0
# table_add MyIngress.level_3 MyIngress.CheckFeature 341 13 1 => 342 6 2
# table_add MyIngress.level_4 MyIngress.CheckFeature 342 6 1 => 343 1 341
# table_add MyIngress.level_5 MyIngress.CheckFeature 343 1 1 => 344 5 7
# table_add MyIngress.level_6 MyIngress.CheckFeature 344 5 1 => 345 2 68
# table_add MyIngress.level_7 MyIngress.CheckFeature 345 2 1 => 346 1 69
# table_add MyIngress.level_8 MyIngress.CheckFeature 346 1 1 => 347 5 2
# table_add MyIngress.level_9 MyIngress.CheckFeature 347 5 1 => 348 4 245
# table_add MyIngress.level_10 MyIngress.CheckFeature 348 4 1 => 349 11 0
# table_add MyIngress.level_11 MyIngress.SetClass 349 11 1 => 350 0
# table_add MyIngress.level_11 MyIngress.SetClass 349 11 0 => 351 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 348 4 0 => 352 0 215
# table_add MyIngress.level_11 MyIngress.SetClass 352 0 1 => 353 0
# table_add MyIngress.level_11 MyIngress.SetClass 352 0 0 => 354 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 347 5 0 => 355 1 16
# table_add MyIngress.level_10 MyIngress.CheckFeature 355 1 1 => 356 5 5
# table_add MyIngress.level_11 MyIngress.SetClass 356 5 1 => 357 0
# table_add MyIngress.level_11 MyIngress.SetClass 356 5 0 => 358 0
# table_add MyIngress.level_10 MyIngress.CheckFeature 355 1 0 => 359 0 31810
# table_add MyIngress.level_11 MyIngress.SetClass 359 0 1 => 360 1
# table_add MyIngress.level_11 MyIngress.SetClass 359 0 0 => 361 0
# table_add MyIngress.level_8 MyIngress.CheckFeature 346 1 0 => 362 7 1723
# table_add MyIngress.level_9 MyIngress.CheckFeature 362 7 1 => 363 2 38
# table_add MyIngress.level_10 MyIngress.SetClass 363 2 1 => 364 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 363 2 0 => 365 7 67
# table_add MyIngress.level_11 MyIngress.SetClass 365 7 1 => 366 0
# table_add MyIngress.level_11 MyIngress.SetClass 365 7 0 => 367 1
# table_add MyIngress.level_9 MyIngress.CheckFeature 362 7 0 => 368 5 3
# table_add MyIngress.level_10 MyIngress.CheckFeature 368 5 1 => 369 0 126118
# table_add MyIngress.level_11 MyIngress.SetClass 369 0 1 => 370 1
# table_add MyIngress.level_11 MyIngress.SetClass 369 0 0 => 371 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 368 5 0 => 372 7 1960
# table_add MyIngress.level_11 MyIngress.SetClass 372 7 1 => 373 0
# table_add MyIngress.level_11 MyIngress.SetClass 372 7 0 => 374 1
# table_add MyIngress.level_7 MyIngress.CheckFeature 345 2 0 => 375 7 67
# table_add MyIngress.level_8 MyIngress.CheckFeature 375 7 1 => 376 7 66
# table_add MyIngress.level_9 MyIngress.CheckFeature 376 7 1 => 377 4 145
# table_add MyIngress.level_10 MyIngress.CheckFeature 377 4 1 => 378 1 127
# table_add MyIngress.level_11 MyIngress.SetClass 378 1 1 => 379 0
# table_add MyIngress.level_11 MyIngress.SetClass 378 1 0 => 380 1
# table_add MyIngress.level_10 MyIngress.SetClass 377 4 0 => 381 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 376 7 0 => 382 2 247
# table_add MyIngress.level_10 MyIngress.CheckFeature 382 2 1 => 383 2 223
# table_add MyIngress.level_11 MyIngress.SetClass 383 2 1 => 384 0
# table_add MyIngress.level_11 MyIngress.SetClass 383 2 0 => 385 0
# table_add MyIngress.level_10 MyIngress.CheckFeature 382 2 0 => 386 2 335
# table_add MyIngress.level_11 MyIngress.SetClass 386 2 1 => 387 0
# table_add MyIngress.level_11 MyIngress.SetClass 386 2 0 => 388 0
# table_add MyIngress.level_8 MyIngress.CheckFeature 375 7 0 => 389 5 1
# table_add MyIngress.level_9 MyIngress.CheckFeature 389 5 1 => 390 7 205
# table_add MyIngress.level_10 MyIngress.CheckFeature 390 7 1 => 391 7 170
# table_add MyIngress.level_11 MyIngress.SetClass 391 7 1 => 392 1
# table_add MyIngress.level_11 MyIngress.SetClass 391 7 0 => 393 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 390 7 0 => 394 0 661636
# table_add MyIngress.level_11 MyIngress.SetClass 394 0 1 => 395 0
# table_add MyIngress.level_11 MyIngress.SetClass 394 0 0 => 396 1
# table_add MyIngress.level_9 MyIngress.CheckFeature 389 5 0 => 397 0 702848
# table_add MyIngress.level_10 MyIngress.CheckFeature 397 0 1 => 398 4 235
# table_add MyIngress.level_11 MyIngress.SetClass 398 4 1 => 399 0
# table_add MyIngress.level_11 MyIngress.SetClass 398 4 0 => 400 1
# table_add MyIngress.level_10 MyIngress.SetClass 397 0 0 => 401 1
# table_add MyIngress.level_6 MyIngress.CheckFeature 344 5 0 => 402 7 78
# table_add MyIngress.level_7 MyIngress.CheckFeature 402 7 1 => 403 6 1
# table_add MyIngress.level_8 MyIngress.CheckFeature 403 6 1 => 404 8 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 404 8 1 => 405 5 12
# table_add MyIngress.level_10 MyIngress.CheckFeature 405 5 1 => 406 0 60
# table_add MyIngress.level_11 MyIngress.SetClass 406 0 1 => 407 1
# table_add MyIngress.level_11 MyIngress.SetClass 406 0 0 => 408 0
# table_add MyIngress.level_10 MyIngress.SetClass 405 5 0 => 409 1
# table_add MyIngress.level_9 MyIngress.CheckFeature 404 8 0 => 410 2 0
# table_add MyIngress.level_10 MyIngress.CheckFeature 410 2 1 => 411 11 0
# table_add MyIngress.level_11 MyIngress.SetClass 411 11 1 => 412 1
# table_add MyIngress.level_11 MyIngress.SetClass 411 11 0 => 413 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 410 2 0 => 414 7 76
# table_add MyIngress.level_11 MyIngress.SetClass 414 7 1 => 415 0
# table_add MyIngress.level_11 MyIngress.SetClass 414 7 0 => 416 0
# table_add MyIngress.level_8 MyIngress.CheckFeature 403 6 0 => 417 1 42
# table_add MyIngress.level_9 MyIngress.CheckFeature 417 1 1 => 418 7 57
# table_add MyIngress.level_10 MyIngress.SetClass 418 7 1 => 419 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 418 7 0 => 420 0 144
# table_add MyIngress.level_11 MyIngress.SetClass 420 0 1 => 421 1
# table_add MyIngress.level_11 MyIngress.SetClass 420 0 0 => 422 0
# table_add MyIngress.level_9 MyIngress.SetClass 417 1 0 => 423 1
# table_add MyIngress.level_7 MyIngress.CheckFeature 402 7 0 => 424 7 2132
# table_add MyIngress.level_8 MyIngress.CheckFeature 424 7 1 => 425 0 17322
# table_add MyIngress.level_9 MyIngress.CheckFeature 425 0 1 => 426 4 242
# table_add MyIngress.level_10 MyIngress.CheckFeature 426 4 1 => 427 1 16
# table_add MyIngress.level_11 MyIngress.SetClass 427 1 1 => 428 0
# table_add MyIngress.level_11 MyIngress.SetClass 427 1 0 => 429 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 426 4 0 => 430 5 17
# table_add MyIngress.level_11 MyIngress.SetClass 430 5 1 => 431 1
# table_add MyIngress.level_11 MyIngress.SetClass 430 5 0 => 432 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 425 0 0 => 433 6 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 433 6 1 => 434 5 25
# table_add MyIngress.level_11 MyIngress.SetClass 434 5 1 => 435 0
# table_add MyIngress.level_11 MyIngress.SetClass 434 5 0 => 436 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 433 6 0 => 437 5 11
# table_add MyIngress.level_11 MyIngress.SetClass 437 5 1 => 438 0
# table_add MyIngress.level_11 MyIngress.SetClass 437 5 0 => 439 1
# table_add MyIngress.level_8 MyIngress.SetClass 424 7 0 => 440 1
# table_add MyIngress.level_5 MyIngress.CheckFeature 343 1 0 => 441 5 11
# table_add MyIngress.level_6 MyIngress.CheckFeature 441 5 1 => 442 7 1868
# table_add MyIngress.level_7 MyIngress.CheckFeature 442 7 1 => 443 5 9
# table_add MyIngress.level_8 MyIngress.CheckFeature 443 5 1 => 444 1 711
# table_add MyIngress.level_9 MyIngress.CheckFeature 444 1 1 => 445 7 69
# table_add MyIngress.level_10 MyIngress.CheckFeature 445 7 1 => 446 5 1
# table_add MyIngress.level_11 MyIngress.SetClass 446 5 1 => 447 0
# table_add MyIngress.level_11 MyIngress.SetClass 446 5 0 => 448 0
# table_add MyIngress.level_10 MyIngress.CheckFeature 445 7 0 => 449 0 1314504
# table_add MyIngress.level_11 MyIngress.SetClass 449 0 1 => 450 0
# table_add MyIngress.level_11 MyIngress.SetClass 449 0 0 => 451 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 444 1 0 => 452 2 692
# table_add MyIngress.level_10 MyIngress.CheckFeature 452 2 1 => 453 7 1726
# table_add MyIngress.level_11 MyIngress.SetClass 453 7 1 => 454 0
# table_add MyIngress.level_11 MyIngress.SetClass 453 7 0 => 455 0
# table_add MyIngress.level_10 MyIngress.SetClass 452 2 0 => 456 0
# table_add MyIngress.level_8 MyIngress.CheckFeature 443 5 0 => 457 7 938
# table_add MyIngress.level_9 MyIngress.CheckFeature 457 7 1 => 458 7 70
# table_add MyIngress.level_10 MyIngress.CheckFeature 458 7 1 => 459 4 231
# table_add MyIngress.level_11 MyIngress.SetClass 459 4 1 => 460 1
# table_add MyIngress.level_11 MyIngress.SetClass 459 4 0 => 461 0
# table_add MyIngress.level_10 MyIngress.CheckFeature 458 7 0 => 462 0 1686366
# table_add MyIngress.level_11 MyIngress.SetClass 462 0 1 => 463 1
# table_add MyIngress.level_11 MyIngress.SetClass 462 0 0 => 464 0
# table_add MyIngress.level_9 MyIngress.SetClass 457 7 0 => 465 1
# table_add MyIngress.level_7 MyIngress.CheckFeature 442 7 0 => 466 0 1056036
# table_add MyIngress.level_8 MyIngress.CheckFeature 466 0 1 => 467 6 1
# table_add MyIngress.level_9 MyIngress.CheckFeature 467 6 1 => 468 5 9
# table_add MyIngress.level_10 MyIngress.SetClass 468 5 1 => 469 0
# table_add MyIngress.level_10 MyIngress.CheckFeature 468 5 0 => 470 0 934446
# table_add MyIngress.level_11 MyIngress.SetClass 470 0 1 => 471 0
# table_add MyIngress.level_11 MyIngress.SetClass 470 0 0 => 472 0
# table_add MyIngress.level_9 MyIngress.SetClass 467 6 0 => 473 1
# table_add MyIngress.level_8 MyIngress.SetClass 466 0 0 => 474 0
# table_add MyIngress.level_6 MyIngress.SetClass 441 5 0 => 475 0
# table_add MyIngress.level_4 MyIngress.CheckFeature 342 6 0 => 476 2 4
# table_add MyIngress.level_5 MyIngress.CheckFeature 476 2 1 => 477 4 228
# table_add MyIngress.level_6 MyIngress.CheckFeature 477 4 1 => 478 2 3
# table_add MyIngress.level_7 MyIngress.CheckFeature 478 2 1 => 479 7 428
# table_add MyIngress.level_8 MyIngress.CheckFeature 479 7 1 => 480 5 5
# table_add MyIngress.level_9 MyIngress.CheckFeature 480 5 1 => 481 6 4
# table_add MyIngress.level_10 MyIngress.CheckFeature 481 6 1 => 482 7 62
# table_add MyIngress.level_11 MyIngress.SetClass 482 7 1 => 483 1
# table_add MyIngress.level_11 MyIngress.SetClass 482 7 0 => 484 0
# table_add MyIngress.level_10 MyIngress.CheckFeature 481 6 0 => 485 11 0
# table_add MyIngress.level_11 MyIngress.SetClass 485 11 1 => 486 1
# table_add MyIngress.level_11 MyIngress.SetClass 485 11 0 => 487 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 480 5 0 => 488 5 12
# table_add MyIngress.level_10 MyIngress.CheckFeature 488 5 1 => 489 0 738
# table_add MyIngress.level_11 MyIngress.SetClass 489 0 1 => 490 1
# table_add MyIngress.level_11 MyIngress.SetClass 489 0 0 => 491 0
# table_add MyIngress.level_10 MyIngress.CheckFeature 488 5 0 => 492 4 57
# table_add MyIngress.level_11 MyIngress.SetClass 492 4 1 => 493 1
# table_add MyIngress.level_11 MyIngress.SetClass 492 4 0 => 494 1
# table_add MyIngress.level_8 MyIngress.CheckFeature 479 7 0 => 495 2 2
# table_add MyIngress.level_9 MyIngress.SetClass 495 2 1 => 496 1
# table_add MyIngress.level_9 MyIngress.CheckFeature 495 2 0 => 497 4 59
# table_add MyIngress.level_10 MyIngress.SetClass 497 4 1 => 498 0
# table_add MyIngress.level_10 MyIngress.SetClass 497 4 0 => 499 1
# table_add MyIngress.level_7 MyIngress.CheckFeature 478 2 0 => 500 8 0
# table_add MyIngress.level_8 MyIngress.SetClass 500 8 1 => 501 1
# table_add MyIngress.level_8 MyIngress.CheckFeature 500 8 0 => 502 7 71
# table_add MyIngress.level_9 MyIngress.CheckFeature 502 7 1 => 503 6 4
# table_add MyIngress.level_10 MyIngress.CheckFeature 503 6 1 => 504 1 6
# table_add MyIngress.level_11 MyIngress.SetClass 504 1 1 => 505 0
# table_add MyIngress.level_11 MyIngress.SetClass 504 1 0 => 506 0
# table_add MyIngress.level_10 MyIngress.SetClass 503 6 0 => 507 1
# table_add MyIngress.level_9 MyIngress.CheckFeature 502 7 0 => 508 7 136
# table_add MyIngress.level_10 MyIngress.CheckFeature 508 7 1 => 509 4 56
# table_add MyIngress.level_11 MyIngress.SetClass 509 4 1 => 510 0
# table_add MyIngress.level_11 MyIngress.SetClass 509 4 0 => 511 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 508 7 0 => 512 6 6
# table_add MyIngress.level_11 MyIngress.SetClass 512 6 1 => 513 0
# table_add MyIngress.level_11 MyIngress.SetClass 512 6 0 => 514 1
# table_add MyIngress.level_6 MyIngress.CheckFeature 477 4 0 => 515 8 0
# table_add MyIngress.level_7 MyIngress.CheckFeature 515 8 1 => 516 6 6
# table_add MyIngress.level_8 MyIngress.CheckFeature 516 6 1 => 517 10 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 517 10 1 => 518 4 234
# table_add MyIngress.level_10 MyIngress.SetClass 518 4 1 => 519 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 518 4 0 => 520 5 2
# table_add MyIngress.level_11 MyIngress.SetClass 520 5 1 => 521 0
# table_add MyIngress.level_11 MyIngress.SetClass 520 5 0 => 522 1
# table_add MyIngress.level_9 MyIngress.SetClass 517 10 0 => 523 0
# table_add MyIngress.level_8 MyIngress.CheckFeature 516 6 0 => 524 11 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 524 11 1 => 525 7 72
# table_add MyIngress.level_10 MyIngress.CheckFeature 525 7 1 => 526 5 3
# table_add MyIngress.level_11 MyIngress.SetClass 526 5 1 => 527 1
# table_add MyIngress.level_11 MyIngress.SetClass 526 5 0 => 528 1
# table_add MyIngress.level_10 MyIngress.SetClass 525 7 0 => 529 1
# table_add MyIngress.level_9 MyIngress.SetClass 524 11 0 => 530 1
# table_add MyIngress.level_7 MyIngress.CheckFeature 515 8 0 => 531 7 76
# table_add MyIngress.level_8 MyIngress.CheckFeature 531 7 1 => 532 0 558
# table_add MyIngress.level_9 MyIngress.CheckFeature 532 0 1 => 533 1 2
# table_add MyIngress.level_10 MyIngress.CheckFeature 533 1 1 => 534 2 1
# table_add MyIngress.level_11 MyIngress.SetClass 534 2 1 => 535 1
# table_add MyIngress.level_11 MyIngress.SetClass 534 2 0 => 536 0
# table_add MyIngress.level_10 MyIngress.CheckFeature 533 1 0 => 537 4 233
# table_add MyIngress.level_11 MyIngress.SetClass 537 4 1 => 538 1
# table_add MyIngress.level_11 MyIngress.SetClass 537 4 0 => 539 1
# table_add MyIngress.level_9 MyIngress.CheckFeature 532 0 0 => 540 4 234
# table_add MyIngress.level_10 MyIngress.CheckFeature 540 4 1 => 541 5 11
# table_add MyIngress.level_11 MyIngress.SetClass 541 5 1 => 542 1
# table_add MyIngress.level_11 MyIngress.SetClass 541 5 0 => 543 0
# table_add MyIngress.level_10 MyIngress.SetClass 540 4 0 => 544 1
# table_add MyIngress.level_8 MyIngress.CheckFeature 531 7 0 => 545 0 1509
# table_add MyIngress.level_9 MyIngress.CheckFeature 545 0 1 => 546 2 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 546 2 1 => 547 5 1
# table_add MyIngress.level_11 MyIngress.SetClass 547 5 1 => 548 1
# table_add MyIngress.level_11 MyIngress.SetClass 547 5 0 => 549 0
# table_add MyIngress.level_10 MyIngress.CheckFeature 546 2 0 => 550 7 87
# table_add MyIngress.level_11 MyIngress.SetClass 550 7 1 => 551 1
# table_add MyIngress.level_11 MyIngress.SetClass 550 7 0 => 552 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 545 0 0 => 553 0 2637
# table_add MyIngress.level_10 MyIngress.SetClass 553 0 1 => 554 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 553 0 0 => 555 0 4090
# table_add MyIngress.level_11 MyIngress.SetClass 555 0 1 => 556 0
# table_add MyIngress.level_11 MyIngress.SetClass 555 0 0 => 557 1
# table_add MyIngress.level_5 MyIngress.CheckFeature 476 2 0 => 558 0 8167
# table_add MyIngress.level_6 MyIngress.CheckFeature 558 0 1 => 559 7 70
# table_add MyIngress.level_7 MyIngress.CheckFeature 559 7 1 => 560 5 3
# table_add MyIngress.level_8 MyIngress.SetClass 560 5 1 => 561 0
# table_add MyIngress.level_8 MyIngress.SetClass 560 5 0 => 562 1
# table_add MyIngress.level_7 MyIngress.CheckFeature 559 7 0 => 563 6 24
# table_add MyIngress.level_8 MyIngress.CheckFeature 563 6 1 => 564 4 51
# table_add MyIngress.level_9 MyIngress.SetClass 564 4 1 => 565 1
# table_add MyIngress.level_9 MyIngress.CheckFeature 564 4 0 => 566 2 7
# table_add MyIngress.level_10 MyIngress.CheckFeature 566 2 1 => 567 4 96
# table_add MyIngress.level_11 MyIngress.SetClass 567 4 1 => 568 0
# table_add MyIngress.level_11 MyIngress.SetClass 567 4 0 => 569 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 566 2 0 => 570 7 355
# table_add MyIngress.level_11 MyIngress.SetClass 570 7 1 => 571 0
# table_add MyIngress.level_11 MyIngress.SetClass 570 7 0 => 572 1
# table_add MyIngress.level_8 MyIngress.SetClass 563 6 0 => 573 1
# table_add MyIngress.level_6 MyIngress.CheckFeature 558 0 0 => 574 2 48
# table_add MyIngress.level_7 MyIngress.CheckFeature 574 2 1 => 575 6 5
# table_add MyIngress.level_8 MyIngress.CheckFeature 575 6 1 => 576 1 36
# table_add MyIngress.level_9 MyIngress.CheckFeature 576 1 1 => 577 6 3
# table_add MyIngress.level_10 MyIngress.CheckFeature 577 6 1 => 578 0 14088
# table_add MyIngress.level_11 MyIngress.SetClass 578 0 1 => 579 0
# table_add MyIngress.level_11 MyIngress.SetClass 578 0 0 => 580 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 577 6 0 => 581 11 0
# table_add MyIngress.level_11 MyIngress.SetClass 581 11 1 => 582 1
# table_add MyIngress.level_11 MyIngress.SetClass 581 11 0 => 583 1
# table_add MyIngress.level_9 MyIngress.CheckFeature 576 1 0 => 584 4 148
# table_add MyIngress.level_10 MyIngress.SetClass 584 4 1 => 585 0
# table_add MyIngress.level_10 MyIngress.CheckFeature 584 4 0 => 586 0 49413
# table_add MyIngress.level_11 MyIngress.SetClass 586 0 1 => 587 1
# table_add MyIngress.level_11 MyIngress.SetClass 586 0 0 => 588 0
# table_add MyIngress.level_8 MyIngress.SetClass 575 6 0 => 589 1
# table_add MyIngress.level_7 MyIngress.SetClass 574 2 0 => 590 1
# table_add MyIngress.level_3 MyIngress.CheckFeature 341 13 0 => 591 5 14
# table_add MyIngress.level_4 MyIngress.CheckFeature 591 5 1 => 592 1 340
# table_add MyIngress.level_5 MyIngress.CheckFeature 592 1 1 => 593 7 1927
# table_add MyIngress.level_6 MyIngress.CheckFeature 593 7 1 => 594 6 7
# table_add MyIngress.level_7 MyIngress.CheckFeature 594 6 1 => 595 7 556
# table_add MyIngress.level_8 MyIngress.CheckFeature 595 7 1 => 596 4 85
# table_add MyIngress.level_9 MyIngress.CheckFeature 596 4 1 => 597 4 41
# table_add MyIngress.level_10 MyIngress.CheckFeature 597 4 1 => 598 5 1
# table_add MyIngress.level_11 MyIngress.SetClass 598 5 1 => 599 1
# table_add MyIngress.level_11 MyIngress.SetClass 598 5 0 => 600 0
# table_add MyIngress.level_10 MyIngress.CheckFeature 597 4 0 => 601 4 59
# table_add MyIngress.level_11 MyIngress.SetClass 601 4 1 => 602 0
# table_add MyIngress.level_11 MyIngress.SetClass 601 4 0 => 603 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 596 4 0 => 604 1 20
# table_add MyIngress.level_10 MyIngress.CheckFeature 604 1 1 => 605 0 293
# table_add MyIngress.level_11 MyIngress.SetClass 605 0 1 => 606 0
# table_add MyIngress.level_11 MyIngress.SetClass 605 0 0 => 607 0
# table_add MyIngress.level_10 MyIngress.CheckFeature 604 1 0 => 608 7 76
# table_add MyIngress.level_11 MyIngress.SetClass 608 7 1 => 609 0
# table_add MyIngress.level_11 MyIngress.SetClass 608 7 0 => 610 1
# table_add MyIngress.level_8 MyIngress.CheckFeature 595 7 0 => 611 1 137
# table_add MyIngress.level_9 MyIngress.CheckFeature 611 1 1 => 612 0 7341
# table_add MyIngress.level_10 MyIngress.CheckFeature 612 0 1 => 613 6 4
# table_add MyIngress.level_11 MyIngress.SetClass 613 6 1 => 614 0
# table_add MyIngress.level_11 MyIngress.SetClass 613 6 0 => 615 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 612 0 0 => 616 0 99591
# table_add MyIngress.level_11 MyIngress.SetClass 616 0 1 => 617 1
# table_add MyIngress.level_11 MyIngress.SetClass 616 0 0 => 618 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 611 1 0 => 619 0 634707
# table_add MyIngress.level_10 MyIngress.CheckFeature 619 0 1 => 620 1 315
# table_add MyIngress.level_11 MyIngress.SetClass 620 1 1 => 621 0
# table_add MyIngress.level_11 MyIngress.SetClass 620 1 0 => 622 1
# table_add MyIngress.level_10 MyIngress.SetClass 619 0 0 => 623 0
# table_add MyIngress.level_7 MyIngress.CheckFeature 594 6 0 => 624 2 3
# table_add MyIngress.level_8 MyIngress.CheckFeature 624 2 1 => 625 4 149
# table_add MyIngress.level_9 MyIngress.CheckFeature 625 4 1 => 626 6 19
# table_add MyIngress.level_10 MyIngress.CheckFeature 626 6 1 => 627 7 501
# table_add MyIngress.level_11 MyIngress.SetClass 627 7 1 => 628 1
# table_add MyIngress.level_11 MyIngress.SetClass 627 7 0 => 629 0
# table_add MyIngress.level_10 MyIngress.SetClass 626 6 0 => 630 1
# table_add MyIngress.level_9 MyIngress.CheckFeature 625 4 0 => 631 4 236
# table_add MyIngress.level_10 MyIngress.SetClass 631 4 1 => 632 0
# table_add MyIngress.level_10 MyIngress.SetClass 631 4 0 => 633 1
# table_add MyIngress.level_8 MyIngress.CheckFeature 624 2 0 => 634 0 7055
# table_add MyIngress.level_9 MyIngress.CheckFeature 634 0 1 => 635 7 210
# table_add MyIngress.level_10 MyIngress.CheckFeature 635 7 1 => 636 7 134
# table_add MyIngress.level_11 MyIngress.SetClass 636 7 1 => 637 0
# table_add MyIngress.level_11 MyIngress.SetClass 636 7 0 => 638 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 635 7 0 => 639 0 6015
# table_add MyIngress.level_11 MyIngress.SetClass 639 0 1 => 640 0
# table_add MyIngress.level_11 MyIngress.SetClass 639 0 0 => 641 0
# table_add MyIngress.level_9 MyIngress.SetClass 634 0 0 => 642 1
# table_add MyIngress.level_6 MyIngress.CheckFeature 593 7 0 => 643 2 116
# table_add MyIngress.level_7 MyIngress.CheckFeature 643 2 1 => 644 2 17
# table_add MyIngress.level_8 MyIngress.CheckFeature 644 2 1 => 645 0 8053
# table_add MyIngress.level_9 MyIngress.SetClass 645 0 1 => 646 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 645 0 0 => 647 6 3
# table_add MyIngress.level_10 MyIngress.SetClass 647 6 1 => 648 1
# table_add MyIngress.level_10 MyIngress.SetClass 647 6 0 => 649 0
# table_add MyIngress.level_8 MyIngress.CheckFeature 644 2 0 => 650 5 6
# table_add MyIngress.level_9 MyIngress.CheckFeature 650 5 1 => 651 5 3
# table_add MyIngress.level_10 MyIngress.CheckFeature 651 5 1 => 652 7 2656
# table_add MyIngress.level_11 MyIngress.SetClass 652 7 1 => 653 1
# table_add MyIngress.level_11 MyIngress.SetClass 652 7 0 => 654 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 651 5 0 => 655 6 1
# table_add MyIngress.level_11 MyIngress.SetClass 655 6 1 => 656 0
# table_add MyIngress.level_11 MyIngress.SetClass 655 6 0 => 657 1
# table_add MyIngress.level_9 MyIngress.CheckFeature 650 5 0 => 658 5 12
# table_add MyIngress.level_10 MyIngress.CheckFeature 658 5 1 => 659 7 2049
# table_add MyIngress.level_11 MyIngress.SetClass 659 7 1 => 660 0
# table_add MyIngress.level_11 MyIngress.SetClass 659 7 0 => 661 1
# table_add MyIngress.level_10 MyIngress.SetClass 658 5 0 => 662 1
# table_add MyIngress.level_7 MyIngress.CheckFeature 643 2 0 => 663 5 13
# table_add MyIngress.level_8 MyIngress.CheckFeature 663 5 1 => 664 0 241872
# table_add MyIngress.level_9 MyIngress.SetClass 664 0 1 => 665 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 664 0 0 => 666 4 153
# table_add MyIngress.level_10 MyIngress.CheckFeature 666 4 1 => 667 0 550295
# table_add MyIngress.level_11 MyIngress.SetClass 667 0 1 => 668 1
# table_add MyIngress.level_11 MyIngress.SetClass 667 0 0 => 669 1
# table_add MyIngress.level_10 MyIngress.SetClass 666 4 0 => 670 1
# table_add MyIngress.level_8 MyIngress.SetClass 663 5 0 => 671 0
# table_add MyIngress.level_5 MyIngress.CheckFeature 592 1 0 => 672 7 214
# table_add MyIngress.level_6 MyIngress.CheckFeature 672 7 1 => 673 0 107088
# table_add MyIngress.level_7 MyIngress.SetClass 673 0 1 => 674 1
# table_add MyIngress.level_7 MyIngress.SetClass 673 0 0 => 675 0
# table_add MyIngress.level_6 MyIngress.CheckFeature 672 7 0 => 676 4 155
# table_add MyIngress.level_7 MyIngress.CheckFeature 676 4 1 => 677 7 271
# table_add MyIngress.level_8 MyIngress.CheckFeature 677 7 1 => 678 2 343
# table_add MyIngress.level_9 MyIngress.CheckFeature 678 2 1 => 679 2 337
# table_add MyIngress.level_10 MyIngress.SetClass 679 2 1 => 680 0
# table_add MyIngress.level_10 MyIngress.CheckFeature 679 2 0 => 681 0 108302
# table_add MyIngress.level_11 MyIngress.SetClass 681 0 1 => 682 0
# table_add MyIngress.level_11 MyIngress.SetClass 681 0 0 => 683 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 678 2 0 => 684 0 110459
# table_add MyIngress.level_10 MyIngress.CheckFeature 684 0 1 => 685 1 350
# table_add MyIngress.level_11 MyIngress.SetClass 685 1 1 => 686 0
# table_add MyIngress.level_11 MyIngress.SetClass 685 1 0 => 687 0
# table_add MyIngress.level_10 MyIngress.SetClass 684 0 0 => 688 0
# table_add MyIngress.level_8 MyIngress.CheckFeature 677 7 0 => 689 1 428
# table_add MyIngress.level_9 MyIngress.CheckFeature 689 1 1 => 690 0 143754
# table_add MyIngress.level_10 MyIngress.CheckFeature 690 0 1 => 691 1 407
# table_add MyIngress.level_11 MyIngress.SetClass 691 1 1 => 692 0
# table_add MyIngress.level_11 MyIngress.SetClass 691 1 0 => 693 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 690 0 0 => 694 5 1
# table_add MyIngress.level_11 MyIngress.SetClass 694 5 1 => 695 0
# table_add MyIngress.level_11 MyIngress.SetClass 694 5 0 => 696 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 689 1 0 => 697 6 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 697 6 1 => 698 1 875
# table_add MyIngress.level_11 MyIngress.SetClass 698 1 1 => 699 0
# table_add MyIngress.level_11 MyIngress.SetClass 698 1 0 => 700 0
# table_add MyIngress.level_10 MyIngress.SetClass 697 6 0 => 701 0
# table_add MyIngress.level_7 MyIngress.SetClass 676 4 0 => 702 1
# table_add MyIngress.level_4 MyIngress.CheckFeature 591 5 0 => 703 2 349
# table_add MyIngress.level_5 MyIngress.CheckFeature 703 2 1 => 704 6 1
# table_add MyIngress.level_6 MyIngress.CheckFeature 704 6 1 => 705 1 17
# table_add MyIngress.level_7 MyIngress.CheckFeature 705 1 1 => 706 11 0
# table_add MyIngress.level_8 MyIngress.CheckFeature 706 11 1 => 707 2 0
# table_add MyIngress.level_9 MyIngress.CheckFeature 707 2 1 => 708 5 20
# table_add MyIngress.level_10 MyIngress.SetClass 708 5 1 => 709 0
# table_add MyIngress.level_10 MyIngress.CheckFeature 708 5 0 => 710 7 98
# table_add MyIngress.level_11 MyIngress.SetClass 710 7 1 => 711 1
# table_add MyIngress.level_11 MyIngress.SetClass 710 7 0 => 712 1
# table_add MyIngress.level_9 MyIngress.CheckFeature 707 2 0 => 713 7 180
# table_add MyIngress.level_10 MyIngress.CheckFeature 713 7 1 => 714 7 103
# table_add MyIngress.level_11 MyIngress.SetClass 714 7 1 => 715 0
# table_add MyIngress.level_11 MyIngress.SetClass 714 7 0 => 716 1
# table_add MyIngress.level_10 MyIngress.CheckFeature 713 7 0 => 717 4 59
# table_add MyIngress.level_11 MyIngress.SetClass 717 4 1 => 718 1
# table_add MyIngress.level_11 MyIngress.SetClass 717 4 0 => 719 0
# table_add MyIngress.level_8 MyIngress.SetClass 706 11 0 => 720 1
# table_add MyIngress.level_7 MyIngress.CheckFeature 705 1 0 => 721 5 25
# table_add MyIngress.level_8 MyIngress.SetClass 721 5 1 => 722 0
# table_add MyIngress.level_8 MyIngress.SetClass 721 5 0 => 723 1
# table_add MyIngress.level_6 MyIngress.CheckFeature 704 6 0 => 724 5 20
# table_add MyIngress.level_7 MyIngress.CheckFeature 724 5 1 => 725 0 6147
# table_add MyIngress.level_8 MyIngress.CheckFeature 725 0 1 => 726 7 112
# table_add MyIngress.level_9 MyIngress.CheckFeature 726 7 1 => 727 6 7
# table_add MyIngress.level_10 MyIngress.CheckFeature 727 6 1 => 728 6 3
# table_add MyIngress.level_11 MyIngress.SetClass 728 6 1 => 729 1
# table_add MyIngress.level_11 MyIngress.SetClass 728 6 0 => 730 0
# table_add MyIngress.level_10 MyIngress.SetClass 727 6 0 => 731 1
# table_add MyIngress.level_9 MyIngress.CheckFeature 726 7 0 => 732 1 4
# table_add MyIngress.level_10 MyIngress.CheckFeature 732 1 1 => 733 6 7
# table_add MyIngress.level_11 MyIngress.SetClass 733 6 1 => 734 1
# table_add MyIngress.level_11 MyIngress.SetClass 733 6 0 => 735 1
# table_add MyIngress.level_10 MyIngress.SetClass 732 1 0 => 736 0
# table_add MyIngress.level_8 MyIngress.CheckFeature 725 0 0 => 737 6 3
# table_add MyIngress.level_9 MyIngress.SetClass 737 6 1 => 738 1
# table_add MyIngress.level_9 MyIngress.CheckFeature 737 6 0 => 739 2 12
# table_add MyIngress.level_10 MyIngress.CheckFeature 739 2 1 => 740 4 155
# table_add MyIngress.level_11 MyIngress.SetClass 740 4 1 => 741 1
# table_add MyIngress.level_11 MyIngress.SetClass 740 4 0 => 742 1
# table_add MyIngress.level_10 MyIngress.SetClass 739 2 0 => 743 1
# table_add MyIngress.level_7 MyIngress.SetClass 724 5 0 => 744 1
# table_add MyIngress.level_5 MyIngress.SetClass 703 2 0 => 745 0

# %% [markdown]
# # Now predicting about separatly processes data

# %%
current_path = os.getcwd()

file1='dataset/Benign_Test_1.csv'
benign = pd.read_csv(file1)
file2='dataset/RSTFIN_Test.csv'
rst = pd.read_csv(file2)
file3='dataset/TCPFlood.csv'
tcp = pd.read_csv(file3)
file4='dataset/SYN_Test.csv'
syn = pd.read_csv(file4)
file5='dataset/UDPFlood_Test.csv'
udp = pd.read_csv(file5)
file6='dataset/UDPFrag_Test.csv'
udp_frag = pd.read_csv(file6)
file7='dataset/HTTPFlood_Test.csv'
http = pd.read_csv(file7)
file8='dataset/SlowLoris_Test.csv'
slow = pd.read_csv(file8)
file9='dataset/PUSHACK_Test.csv'
psh = pd.read_csv(file9)
file10='dataset/ACKFrag_Test.csv'
ack = pd.read_csv(file10)

benign['attack'] = 0
rst['attack'] = 1
tcp['attack'] = 1
syn['attack'] = 1
udp['attack'] = 1
ack['attack'] = 1
psh['attack'] = 1
udp_frag['attack'] = 1
http['attack'] = 1
slow['attack'] = 1

# %% [markdown]
# # Test Benign

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_fscore_support

data = pd.concat([benign])
data['type'] = data['proto_type'].apply(lambda x: 0 if x > 6 else 1)
best_features = data[features]
target_features = data[['attack']]
prediction = rf.predict(best_features)
print("Accuracy:", 1- sum(prediction)/len(prediction))
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(target_features, prediction)
# Print the results for each class
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", fscore)
print("Support: ", support)
# Out:
# Accuracy: 0.9594356261022927
# Precision:  [1. 0.]
# Recall:  [0.95943563 0.        ]
# F1-score:  [0.97929793 0.        ]
# Support:  [1134    0]
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # Test SYN Flood

# %%
data = pd.concat([syn])
data['type'] = data['proto_type'].apply(lambda x: 0 if x > 6 else 1)
best_features = data[features]
target_features = data[['attack']]
prediction = rf.predict(best_features)
print("Accuracy: ", sum(prediction)/len(prediction))
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(target_features, prediction)
# Print the results for each class
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", fscore)
print("Support: ", support)
# Out:
# Accuracy:  0.9972968675465098
# Precision:  [0. 1.]
# Recall:  [0.         0.99729687]
# F1-score:  [0.        0.9986466]
# Support:  [    0 12578]
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # TCP PUSH ACK

# %%
data = pd.concat([psh])
data['type'] = data['proto_type'].apply(lambda x: 0 if x > 6 else 1)
best_features = data[features]
target_features = data[['attack']]
prediction = rf.predict(best_features)
print("Accuracy: ", sum(prediction)/len(prediction))
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(target_features, prediction)
# Print the results for each class
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", fscore)
print("Support: ", support)
# Out:
# Accuracy:  0.9991620643686917
# Precision:  [0. 1.]
# Recall:  [0.         0.99916206]
# F1-score:  [0.         0.99958086]
# Support:  [    0 26255]
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # TCP ACK Fragmentation

# %%
data = pd.concat([ack])
data['type'] = data['proto_type'].apply(lambda x: 0 if x > 6 else 1)
best_features = data[features]
target_features = data[['attack']]
prediction = rf.predict(best_features)
print("Accuracy: ", sum(prediction)/len(prediction))
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(target_features, prediction)
# Print the results for each class
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", fscore)
print("Support: ", support)
# Out:
# Accuracy:  0.9683933274802459
# Precision:  [0. 1.]
# Recall:  [0.         0.96839333]
# F1-score:  [0.         0.98394291]
# Support:  [   0 1139]
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # Test TCP DoS

# %%
data = pd.concat([tcp])
data['type'] = data['proto_type'].apply(lambda x: 0 if x > 6 else 1)
best_features = data[features]
target_features = data[['attack']]
prediction = rf.predict(best_features)
print("Accuracy:", sum(prediction)/len(prediction))
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(target_features, prediction)
# Print the results for each class
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", fscore)
print("Support: ", support)
# Out:
# Accuracy: 0.9981534484350475
# Precision:  [0. 1.]
# Recall:  [0.         0.99815345]
# F1-score:  [0.         0.99907587]
# Support:  [    0 43324]
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # Test RST FIN Flood

# %%
data = pd.concat([rst])
data['type'] = data['proto_type'].apply(lambda x: 0 if x > 6 else 1)
best_features = data[features]
target_features = data[['attack']]
prediction = rf.predict(best_features)
print("Accuracy: ", sum(prediction)/len(prediction))
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(target_features, prediction)
# Print the results for each class
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", fscore)
print("Support: ", support)
# Out:
# Accuracy:  0.9965690376569037
# Precision:  [0. 1.]
# Recall:  [0.         0.99656904]
# F1-score:  [0.         0.99828157]
# Support:  [    0 11950]
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # Test UDP Flood

# %%
data = pd.concat([udp])
data['type'] = data['proto_type'].apply(lambda x: 0 if x > 6 else 1)
best_features = data[features]
target_features = data[['attack']]
prediction = rf.predict(best_features)
print("Accuracy:",  sum(prediction)/len(prediction))
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(target_features, prediction)
# Print the results for each class
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", fscore)
print("Support: ", support)
# Out:
# Accuracy: 0.9518839689970071
# Precision:  [0. 1.]
# Recall:  [0.         0.95188397]
# F1-score:  [0.         0.97534893]
# Support:  [    0 13031]
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # Test HTTP Flood

# %%
data = pd.concat([http])
data['type'] = data['proto_type'].apply(lambda x: 0 if x > 6 else 1)
best_features = data[features]
target_features = data[['attack']]
prediction = rf.predict(best_features)
print("Accuracy:",  sum(prediction)/len(prediction))
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(target_features, prediction)
# Print the results for each class
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", fscore)
print("Support: ", support)
# Out:
# Accuracy: 0.9251523063533508
# Precision:  [0. 1.]
# Recall:  [0.         0.92515231]
# F1-score:  [0.         0.96112116]
# Support:  [   0 2298]
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # Test UDP Frag

# %%
data = pd.concat([udp_frag])
data['type'] = data['proto_type'].apply(lambda x: 0 if x > 6 else 1)
best_features = data[features]
target_features = data[['attack']]
prediction = rf.predict(best_features)
print("Accuracy:",  sum(prediction)/len(prediction))
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(target_features, prediction)
# Print the results for each class
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", fscore)
print("Support: ", support)
# Out:
# Accuracy: 0.9961977186311787
# Precision:  [0. 1.]
# Recall:  [0.         0.99619772]
# F1-score:  [0.         0.99809524]
# Support:  [  0 526]
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # Test Slowloris

# %%
data = pd.concat([slow])
data['type'] = data['proto_type'].apply(lambda x: 0 if x > 6 else 1)
best_features = data[features]
target_features = data[['attack']]
prediction = rf.predict(best_features)
print("Accuracy:",  sum(prediction)/len(prediction))
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(target_features, prediction)
# Print the results for each class
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", fscore)
print("Support: ", support)
# Out:
# Accuracy: 0.8353140916808149
# Precision:  [0. 1.]
# Recall:  [0.         0.83531409]
# F1-score:  [0.         0.91026827]
# Support:  [   0 4712]
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
