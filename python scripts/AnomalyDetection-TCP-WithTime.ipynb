# %%
'''Main'''
import numpy as np
import pandas as pd
import os

'''Data Viz'''
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
import matplotlib as mpl

# %matplotlib inline

'''Data Prep'''
from sklearn import preprocessing as pp 
from sklearn.preprocessing import LabelEncoder, StandardScaler
from scipy.stats import pearsonr 
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold 
from sklearn.metrics import log_loss 
from sklearn.metrics import precision_recall_curve, average_precision_score 
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.metrics import confusion_matrix, classification_report 
from statistics import mean, stdev

from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB 
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# # Load TCP Benign and DDoS CIC2023 Flows

# %%
# Acquire Data
# Data here has all features
current_path = os.getcwd()

# BENIGN DATA FILES ***************************************
file1='dataset/Benign.csv'
benign = pd.read_csv(file1)
benign = benign[(benign['proto_type'] == 6)]
benign['attack'] = 0

# DDOS-VOLUMETRIC ATTACK ***********************************
file2='dataset/TCPFlood.csv'
tcp = pd.read_csv(file2)
tcp['attack'] = 1

# DDOS-TRANSPORT PROTOCOL VULNERABILITIES *******************
file3='dataset/ACKFrag.csv'
file4='dataset/SYN.csv'
file5='dataset/RSTFIN.csv'
file6='dataset/PUSHACK.csv'

ack = pd.read_csv(file3)
syn = pd.read_csv(file4)
rst = pd.read_csv(file5)
psh = pd.read_csv(file6)


ack['attack'] = 1
syn['attack'] = 1
rst['attack'] = 1
psh['attack'] = 1


# DDOS-APPLICATION PROTOCOL VULNERABILITIES *******************
file91='dataset/HTTPFlood.csv'
file92='dataset/Slowloris.csv'
http = pd.read_csv(file91)
slow = pd.read_csv(file92)
http['attack'] = 1
slow['attack'] = 1

## CONCATE ALL THE RECORDS ************************************
frames = [benign, 
          tcp,
          syn, rst, ack, psh, 
          http, slow]

data = pd.concat(frames)

# %%
# Size of the data
print("Shape of data: ", data.shape)
# Attack wise size
print("Attack and Benign Records: ", data["attack"].value_counts())
# Out:
# Shape of data:  (309107, 34)
# Attack and Benign Records:  attack
# 1    226482
# 0     82625
# Name: count, dtype: int64

# %%
tcp.shape
# Out:
# (43324, 34)

# %%
data.columns
# Out:
# Index(['ts', 'srcip', 'dstip', 'srcport', 'dstport', 'proto_type', 'sbytes',
#        'dbytes', 'flow_bytes', 'rate', 'srate', 'drate', 'spkts', 'dpkts',
#        'ttl', 'iat', 'max_iat', 'min_iat', 'total_duration',
#        'N_IN_Conn_P_Src_IP', 'N_IN_Conn_P_Dst_IP', 'avg_pkt_len', 'state_con',
#        'state_int', 'state_rst', 'fin_flag_number', 'syn_flag_number',
#        'psh_flag_number', 'ack_flag_number', 'urg_flag_number',
#        'ece_flag_number', 'cwr_flag_number', 'attack', 'x'],
#       dtype='object')

# %% [markdown]
# # Select parameters based on the model i.e. with or without time based features

# %%
# Features according to Importance
features =  [
             'flow_bytes', 'spkts','dpkts','ttl','min_iat',
             'N_IN_Conn_P_Src_IP', 'N_IN_Conn_P_Dst_IP', 'avg_pkt_len',
             #'state_con', 
             'state_rst',
             'fin_flag_number', 'syn_flag_number',
             'psh_flag_number', 'ack_flag_number', 
            ]
best_features = data[features] 
target_features = data[['attack']]

# %% [markdown]
# ## Descriptio of the parametes
#
# **(1) N_IN_Conn_P_Src_IP**: number of packets sent from a source ip address (note src_ip_bytes is similar to it)
# **(2) N_IN_Conn_P_Dst_IP**: number of incoming packets to a destination ip address
# **(3) spkts**: number of packets transmitted by a source in a flow till now
# **(4) dpkts**: number of packets transmitted by a destination in a flow till now
# **(5) srate**: spkts/duration of flow
# **(6) drate**: dpkts/duration of flow
# **(7) avg_packet_len**: mean packet length in bytes in either direction of the a flow
# **(8) state_con**: if this is a TCP packet and not first packet in the flow, with RESET flag not on
# **(9) state_int**: 1, if this is first packet in a UDP flow
# **(10) state_rst**: if this is a TCP packet and reset flag is on, this is the thir flag in tcp
# **(11-17) Flags of TCP**: FIN, SYN, PUSH, URG, ECE, CWR, ACK

# %% [markdown]
# # Split Dataset into X and Y

# %%
# Split of  predictors and response variable
X= best_features
y= target_features

# %% [markdown]
# # Use StratifiedKFold with K=10

# %%
# Create  classifier object.
rf = RandomForestClassifier(n_estimators = 1, n_jobs=2, random_state=0, max_depth=10)  
n_splits = 10
# Create StratifiedKFold object.
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=1)
accu_stratified = []
conf_matrices = []  # Store confusion matrices
per_class_accuracies = []

# %%
# Create model with StratifiedKFold   
for train_index, test_index in skf.split(X, y):
    x_train_fold, x_test_fold = X.iloc[train_index], X.iloc[test_index]
    y_train_fold, y_test_fold = y.iloc[train_index], y.iloc[test_index]
    rf.fit(x_train_fold, y_train_fold)
    #accu_stratified.append(rf.score(x_test_fold, y_test_fold))

    # Compute confusion matrix
    conf_matrix = confusion_matrix(y_test_fold,rf.predict(x_test_fold))
    conf_matrices.append(conf_matrix)
    
    # Compute per-class accuracies
    per_class_accuracy = conf_matrix.diagonal() / conf_matrix.sum(axis=1)
    per_class_accuracies.append(per_class_accuracy)

# Convert lists to numpy arrays for easier manipulation
conf_matrices = np.array(conf_matrices)
per_class_accuracies = np.array(per_class_accuracies)
# Out:
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
# Plotting per-class accuracies

plt.figure(figsize=(10, 6))
for i, class_accuracy in enumerate(per_class_accuracies.T, 1):
    if(i==1):
        plt.plot(range(1, n_splits + 1), class_accuracy, marker='o', label=f'Benign', color='green',  linestyle='dashed', markersize=10)
        print("Accuracy of Attack Records: ", class_accuracy)
        print('\nMedian Accuracy of Attack Records:', np.median(class_accuracy)*100, '%')
        print('\nStandard Deviation of Attack Records:', stdev(class_accuracy))
    else:
        plt.plot(range(1, n_splits + 1), class_accuracy, marker='*', label=f'Attack', color='red',  linestyle='dotted', markersize=10)  
        print("Accuracy of Benign Records: ", class_accuracy)
        print('\nMedian Accuracy of Benign Records:', np.median(class_accuracy)*100, '%')
        print('\nStandard Deviation of Benign Records:', stdev(class_accuracy))
    
plt.title('')
plt.xlabel('Fold', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)
plt.xticks(range(1, n_splits + 1))
plt.tick_params(axis='both', which='major', labelsize=16)
plt.tick_params(axis='both', which='minor', labelsize=16)
plt.legend()
plt.grid(True)
# Save the plot as a PNG file
plt.savefig('StratifiedKFold_5Tree.png', bbox_inches='tight')
plt.show()
# Out:
# Accuracy of Attack Records:  [0.92242527 0.96671911 0.98414619 0.9864456  0.95631127 0.9721617
#  0.98547567 0.96526265 0.97906076 0.976519  ]
#
# Median Accuracy of Attack Records: 97.43403534253207 %
#
# Standard Deviation of Attack Records: 0.01920730408924386
# Accuracy of Benign Records:  [0.95173967 0.93032497 0.92414341 0.91566584 0.9322236  0.92794384
#  0.91805378 0.93120805 0.916284   0.92935359]
#
# Median Accuracy of Benign Records: 92.86487119428077 %
#
# Standard Deviation of Benign Records: 0.01054726873273037

# %% [markdown]
# # Training model on the whole dataset

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import SelectFromModel
rf = RandomForestClassifier(n_estimators = 1, n_jobs=2, random_state=0, max_depth=10)
rf.fit(X, y)
# Out:
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(max_depth=10, n_estimators=1, n_jobs=2, random_state=0)

# %% [markdown]
# # Mean Decrease of Accuracy of the Parameters

# %%
best_features.rename(columns={"N_IN_Conn_P_Src_IP": "N_IN_Conn_Src_IP", "N_IN_Conn_P_Dst_IP": "N_IN_Conn_Dst_IP"})
labels = best_features.columns

importances = list(rf.feature_importances_)
print(importances)
colors = (0.2, # redness
         0.4, # greenness
         0.2, # blueness
         0.6 # transparency
         ) 
# Sort feature importances in descending order
sorted_indices = np.argsort(importances)[::-1]
sorted_list =[importances[i] for i in sorted_indices]
# Plot feature importances
plt.figure(figsize=(10, 6))
plt.title('')
plt.barh(range(X.shape[1]), sorted_list, align="center",color=colors )
plt.yticks(range(X.shape[1]), labels[sorted_indices], fontsize=12)
plt.xlabel("Importance", fontsize=16)
plt.ylabel("Features", fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=12)
plt.tick_params(axis='both', which='minor', labelsize=12)
# Save the plot as a PNG file
plt.savefig('Importance.png', bbox_inches='tight')
plt.show()
# Out:
# [np.float64(0.01851903186634751), np.float64(0.04937117713652238), np.float64(0.009369783226247612), np.float64(0.009741126067737393), np.float64(0.0), np.float64(0.03580289477614595), np.float64(0.44219382005229974), np.float64(0.4314519410062687), np.float64(0.0002649589804052171), np.float64(8.710593221253003e-05), np.float64(0.0), np.float64(0.0030224232112378187), np.float64(0.00017573774457521342)]

# %% [markdown]
# # Generate Tree

# %%
from sklearn import tree
from sklearn.tree import export_text
i_tree = 0
for tree_in_forest in rf.estimators_:
    with open('tree_' + str(i_tree) + '.dot', 'w') as my_file:
        my_file = tree.export_graphviz(tree_in_forest, out_file = my_file)
        r = export_text(tree_in_forest)
        print("TREE ", i_tree)
        print(r)  
    i_tree = i_tree + 1
# Out:
# TREE  0
# |--- feature_7 <= 64.29
# |   |--- feature_7 <= 54.45
# |   |   |--- feature_9 <= 0.50
# |   |   |   |--- feature_3 <= 122.50
# |   |   |   |   |--- feature_6 <= 1.50
# |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |--- feature_1 <= 1.50
# |   |   |   |   |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 44.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_3 >  44.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 128.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  128.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 61.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_3 >  61.50
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_1 >  1.50
# |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 2.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_5 >  2.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_12 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_12 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |--- feature_2 <= 4.50
# |   |   |   |   |   |   |   |--- feature_5 <= 3.00
# |   |   |   |   |   |   |   |   |--- feature_2 <= 2.50
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_2 >  2.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_5 >  3.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_2 >  4.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- feature_6 >  1.50
# |   |   |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |   |   |--- feature_6 <= 17.50
# |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 81.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  81.00
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_6 >  17.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- feature_3 >  122.50
# |   |   |   |   |--- feature_5 <= 2.50
# |   |   |   |   |   |--- feature_1 <= 2.50
# |   |   |   |   |   |   |--- feature_0 <= 273.50
# |   |   |   |   |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 125.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  125.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 1.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_5 >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_0 >  273.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_1 >  2.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- feature_5 >  2.50
# |   |   |   |   |   |--- class: 0.0
# |   |   |--- feature_9 >  0.50
# |   |   |   |--- class: 1.0
# |   |--- feature_7 >  54.45
# |   |   |--- feature_1 <= 6.50
# |   |   |   |--- feature_6 <= 4.50
# |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |--- feature_5 <= 3.50
# |   |   |   |   |   |   |--- feature_7 <= 56.50
# |   |   |   |   |   |   |   |--- feature_3 <= 150.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_3 >  150.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_7 >  56.50
# |   |   |   |   |   |   |   |--- feature_0 <= 89.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_0 >  89.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_5 >  3.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |--- feature_5 <= 1.50
# |   |   |   |   |   |   |--- feature_0 <= 382.00
# |   |   |   |   |   |   |   |--- feature_12 <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_12 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 2.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_1 >  2.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_0 >  382.00
# |   |   |   |   |   |   |   |--- feature_7 <= 57.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 3.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_1 >  3.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 150.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  150.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_7 >  57.00
# |   |   |   |   |   |   |   |   |--- feature_11 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_11 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_5 >  1.50
# |   |   |   |   |   |   |--- feature_5 <= 9.00
# |   |   |   |   |   |   |   |--- feature_3 <= 93.50
# |   |   |   |   |   |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_3 >  93.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_5 >  9.00
# |   |   |   |   |   |   |   |--- feature_6 <= 1.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 220.50
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_3 >  220.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_6 >  1.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- feature_6 >  4.50
# |   |   |   |   |--- feature_2 <= 2.50
# |   |   |   |   |   |--- feature_5 <= 12.50
# |   |   |   |   |   |   |--- feature_1 <= 4.50
# |   |   |   |   |   |   |   |--- feature_6 <= 6.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 11.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 161.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  161.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_5 >  11.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_6 >  6.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_1 >  4.50
# |   |   |   |   |   |   |   |--- feature_5 <= 10.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_5 >  10.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 617.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  617.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_5 >  12.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- feature_2 >  2.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |--- feature_1 >  6.50
# |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |--- feature_3 <= 45.50
# |   |   |   |   |   |--- feature_1 <= 7.50
# |   |   |   |   |   |   |--- feature_0 <= 877.00
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_0 >  877.00
# |   |   |   |   |   |   |   |--- feature_11 <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_11 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 933.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  933.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_1 >  7.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- feature_3 >  45.50
# |   |   |   |   |   |--- feature_0 <= 664.00
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_0 >  664.00
# |   |   |   |   |   |   |--- feature_5 <= 76.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_5 >  76.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |--- class: 1.0
# |--- feature_7 >  64.29
# |   |--- feature_6 <= 7.50
# |   |   |--- feature_1 <= 341.50
# |   |   |   |--- feature_5 <= 14.50
# |   |   |   |   |--- feature_5 <= 7.50
# |   |   |   |   |   |--- feature_2 <= 277.50
# |   |   |   |   |   |   |--- feature_5 <= 1.50
# |   |   |   |   |   |   |   |--- feature_2 <= 5.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 9463.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 49.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  49.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  9463.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 36242.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  36242.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_2 >  5.50
# |   |   |   |   |   |   |   |   |--- feature_11 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_11 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_5 >  1.50
# |   |   |   |   |   |   |   |--- feature_3 <= 251.50
# |   |   |   |   |   |   |   |   |--- feature_7 <= 2437.45
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 9614.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  9614.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_7 >  2437.45
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 240600.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  240600.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_3 >  251.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 1.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 3.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  3.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_1 >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_2 >  277.50
# |   |   |   |   |   |   |--- feature_0 <= 711789.50
# |   |   |   |   |   |   |   |--- feature_2 <= 335.50
# |   |   |   |   |   |   |   |   |--- feature_7 <= 272.32
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 67.01
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  67.01
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_7 >  272.32
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 313.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  313.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_2 >  335.50
# |   |   |   |   |   |   |   |   |--- feature_7 <= 259.69
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 110624.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  110624.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_7 >  259.69
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_0 >  711789.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- feature_5 >  7.50
# |   |   |   |   |   |--- feature_7 <= 2112.55
# |   |   |   |   |   |   |--- feature_5 <= 10.50
# |   |   |   |   |   |   |   |--- feature_0 <= 12244.00
# |   |   |   |   |   |   |   |   |--- feature_3 <= 59.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 9.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  9.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_3 >  59.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 9.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  9.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_0 >  12244.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 18309.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 17.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  17.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  18309.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_5 >  10.50
# |   |   |   |   |   |   |   |--- feature_6 <= 1.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 17.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 11.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  11.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_2 >  17.50
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_6 >  1.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 12.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 12.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  12.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_5 >  12.50
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_7 >  2112.55
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- feature_5 >  14.50
# |   |   |   |   |--- feature_11 <= 0.50
# |   |   |   |   |   |--- feature_1 <= 251.50
# |   |   |   |   |   |   |--- feature_6 <= 1.50
# |   |   |   |   |   |   |   |--- feature_9 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 25.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 68.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  68.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_5 >  25.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 523.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  523.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_9 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 774.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 71.17
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  71.17
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  774.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_6 >  1.50
# |   |   |   |   |   |   |   |--- feature_6 <= 3.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 11.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 293.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  293.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_2 >  11.50
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_6 >  3.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 15.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_5 >  15.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 22.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  22.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_1 >  251.50
# |   |   |   |   |   |   |--- feature_5 <= 17.00
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_5 >  17.00
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- feature_11 >  0.50
# |   |   |   |   |   |--- feature_3 <= 246.50
# |   |   |   |   |   |   |--- feature_3 <= 142.00
# |   |   |   |   |   |   |   |--- feature_2 <= 47.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 16.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 3985.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  3985.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_1 >  16.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 62.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  62.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_2 >  47.00
# |   |   |   |   |   |   |   |   |--- feature_6 <= 2.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  2.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_3 >  142.00
# |   |   |   |   |   |   |   |--- feature_2 <= 15.00
# |   |   |   |   |   |   |   |   |--- feature_7 <= 470.79
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 232.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  232.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_7 >  470.79
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_2 >  15.00
# |   |   |   |   |   |   |   |   |--- feature_6 <= 1.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_3 >  246.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |--- feature_1 >  341.50
# |   |   |   |--- feature_0 <= 1554066.00
# |   |   |   |   |--- feature_5 <= 1.50
# |   |   |   |   |   |--- feature_0 <= 106344.00
# |   |   |   |   |   |   |--- feature_1 <= 357.50
# |   |   |   |   |   |   |   |--- feature_1 <= 344.50
# |   |   |   |   |   |   |   |   |--- feature_11 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_11 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_1 >  344.50
# |   |   |   |   |   |   |   |   |--- feature_7 <= 66.36
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_7 >  66.36
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 99812.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  99812.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_1 >  357.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_0 >  106344.00
# |   |   |   |   |   |   |--- feature_0 <= 143787.00
# |   |   |   |   |   |   |   |--- feature_11 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 129154.00
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 66.31
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  66.31
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  129154.00
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 420.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  420.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_11 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 129487.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 110862.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  110862.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  129487.00
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 376.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  376.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_0 >  143787.00
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- feature_5 >  1.50
# |   |   |   |   |   |--- feature_5 <= 3.50
# |   |   |   |   |   |   |--- feature_7 <= 68.66
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_7 >  68.66
# |   |   |   |   |   |   |   |--- feature_5 <= 2.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 1182657.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 148.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  148.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  1182657.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_5 >  2.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_5 >  3.50
# |   |   |   |   |   |   |--- feature_1 <= 779.50
# |   |   |   |   |   |   |   |--- feature_7 <= 1871.28
# |   |   |   |   |   |   |   |   |--- feature_2 <= 620.50
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_2 >  620.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 148.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  148.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_7 >  1871.28
# |   |   |   |   |   |   |   |   |--- feature_1 <= 385.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 155.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  155.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_1 >  385.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 964638.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  964638.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_1 >  779.50
# |   |   |   |   |   |   |   |--- feature_11 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 628.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_2 >  628.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 1518230.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  1518230.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_11 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 9.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 1525803.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  1525803.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_5 >  9.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- feature_0 >  1554066.00
# |   |   |   |   |--- feature_2 <= 817.50
# |   |   |   |   |   |--- feature_0 <= 1685121.00
# |   |   |   |   |   |   |--- feature_7 <= 70.58
# |   |   |   |   |   |   |   |--- feature_5 <= 5.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_5 >  5.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 1632574.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  1632574.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 231.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  231.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_7 >  70.58
# |   |   |   |   |   |   |   |--- feature_5 <= 9.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_5 >  9.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 1668324.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 763.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  763.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  1668324.50
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_0 >  1685121.00
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- feature_2 >  817.50
# |   |   |   |   |   |--- class: 0.0
# |   |--- feature_6 >  7.50
# |   |   |--- feature_2 <= 4.50
# |   |   |   |--- feature_3 <= 60.50
# |   |   |   |   |--- feature_6 <= 9.50
# |   |   |   |   |   |--- feature_5 <= 5.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_5 >  5.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- feature_6 >  9.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- feature_3 >  60.50
# |   |   |   |   |--- feature_0 <= 1053.50
# |   |   |   |   |   |--- feature_6 <= 24.50
# |   |   |   |   |   |   |--- feature_12 <= 0.50
# |   |   |   |   |   |   |   |--- feature_2 <= 1.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 111.00
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 8.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  8.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_0 >  111.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_2 >  1.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_12 >  0.50
# |   |   |   |   |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 18.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 235.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  235.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  18.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_6 >  24.50
# |   |   |   |   |   |   |--- feature_1 <= 1.50
# |   |   |   |   |   |   |   |--- feature_0 <= 76.00
# |   |   |   |   |   |   |   |   |--- feature_12 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 9.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  9.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_12 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_0 >  76.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_1 >  1.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- feature_0 >  1053.50
# |   |   |   |   |   |--- feature_0 <= 1921.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_0 >  1921.50
# |   |   |   |   |   |   |--- feature_0 <= 1925.00
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_0 >  1925.00
# |   |   |   |   |   |   |   |--- feature_5 <= 5.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 11.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  11.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_5 >  5.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 18.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 380.62
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  380.62
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- feature_6 >  18.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |--- feature_2 >  4.50
# |   |   |   |--- feature_11 <= 0.50
# |   |   |   |   |--- feature_6 <= 19.50
# |   |   |   |   |   |--- feature_7 <= 192.75
# |   |   |   |   |   |   |--- feature_1 <= 5.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_1 >  5.50
# |   |   |   |   |   |   |   |--- feature_5 <= 7.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- feature_5 >  7.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_7 >  192.75
# |   |   |   |   |   |   |--- feature_0 <= 6311.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_0 >  6311.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- feature_6 >  19.50
# |   |   |   |   |   |--- feature_5 <= 17.00
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- feature_5 >  17.00
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- feature_11 >  0.50
# |   |   |   |   |--- feature_2 <= 5.50
# |   |   |   |   |   |--- feature_1 <= 5.50
# |   |   |   |   |   |   |--- feature_5 <= 13.00
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_5 >  13.00
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_1 >  5.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- feature_2 >  5.50
# |   |   |   |   |   |--- feature_6 <= 19.50
# |   |   |   |   |   |   |--- feature_1 <= 13.50
# |   |   |   |   |   |   |   |--- feature_3 <= 149.00
# |   |   |   |   |   |   |   |   |--- feature_7 <= 781.27
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_7 >  781.27
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_3 >  149.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- feature_1 >  13.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_6 >  19.50
# |   |   |   |   |   |   |--- feature_6 <= 42.00
# |   |   |   |   |   |   |   |--- feature_1 <= 13.50
# |   |   |   |   |   |   |   |   |--- feature_7 <= 411.63
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_7 >  411.63
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- feature_1 >  13.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 13.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- feature_2 >  13.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- feature_6 >  42.00
# |   |   |   |   |   |   |   |--- class: 1.0

# %% [markdown]
# # Save the RF Attack Detector

# %%
import pickle as pickle
filename = 'tcp_time.sav'
pickle.dump(rf, open(filename, 'wb'))

# %% [markdown]
# # Display (Match-Action) Rules of the RF Tree, acceptable to P4

# %%
from io import StringIO
from numbers import Integral

import numpy as np
import pandas
import pickle 
import sklearn
from sklearn import tree 
from sklearn.tree import export_text

from sklearn.tree import _tree

from sklearn.tree import DecisionTreeClassifier

filename = 'tcp_time.sav'
rf = pickle.load(open(filename, 'rb'))

i_tree = 0 

global_id = 0

def export_p4(decision_tree):
    tree_ = decision_tree.tree_
    class_names = decision_tree.classes_
    right_child_fmt = "{} {} <= {}\n"
    left_child_fmt = "{} {} >  {}\n"
    truncation_fmt = "{} {}\n"
    feature_names_ = ["{}".format(i) for i in tree_.feature]  
    export_text.report = ""
    max_depth=10
    spacing=3
    decimals=2
    show_weights=False

    if isinstance(decision_tree, DecisionTreeClassifier):
        value_fmt = "{}{} weights: {}\n"
        if not show_weights:
            value_fmt = "{}{}{}\n"
    else:
        value_fmt = "{}{} value: {}\n"

    def _add_leaf(value, class_name, indent, prevfeature, result, depth, previous_id):
        global global_id
        global i_tree 
        current_id = global_id

        val = ''
        is_classification = isinstance(decision_tree,
                                       DecisionTreeClassifier)
        if show_weights or not is_classification:
            val = ["{1:.{0}f}, ".format(decimals, v) for v in value]
            val = '['+''.join(val)[:-2]+']'
        if is_classification:
            val += ' class: ' + str(class_name)
        export_text.report += value_fmt.format(indent, '', val)
        #print("table_add MyIngress.level_", i_tree,"_", depth, " ", "MyIngress.SetClass",i_tree," ", previous_id," ",prevfeature," ", result," ", "=>"," ", current_id, " ", int(float(class_name)), sep="")
        print("table_add MyIngress.TCPlevel_", depth, " ", "MyIngress.SetClassTCP"," ", previous_id," ",prevfeature," ", result," ", "=>"," ", current_id, " ", int(float(class_name)), sep="")

    def print_tree_recurse(node, depth, prevfeature, result, previous_id):
        indent = ("|" + (" " * spacing)) * depth
        indent = indent[:-spacing] + "-" * spacing
        global global_id
        global i_tree 
        global_id = global_id + 1
        current_id = global_id

        value = None
        if tree_.n_outputs == 1:
            value = tree_.value[node][0]
        else:
            value = tree_.value[node].T[0]
        class_name = np.argmax(value)

        if (tree_.n_classes[0] != 1 and
                tree_.n_outputs == 1):
            class_name = class_names[class_name]

        if depth <= max_depth+1:
            info_fmt = ""
            info_fmt_left = info_fmt
            info_fmt_right = info_fmt

            if tree_.feature[node] != _tree.TREE_UNDEFINED:
                name = feature_names_[node]
                threshold = tree_.threshold[node]
                threshold = "{1:.{0}f}".format(decimals, threshold)
                export_text.report += right_child_fmt.format(indent,
                                                             name,
                                                             threshold)
                export_text.report += info_fmt_left
                #if int(name) == 9 or int(name) == 11:
                   #print("**********", name, threshold, float(threshold), 1000000.0*float(threshold))
                 #  print("table_add MyIngress.level_", i_tree,"_", depth, " MyIngress.CheckFeature ", previous_id, " ", prevfeature, " ", result, " ", "=>", " ", current_id, " ", name," ", int(1000000.0*float(threshold)), sep='')

                #else:
                #print("table_add MyIngress.level_", i_tree,"_", depth, " MyIngress.CheckFeatureTCP ", previous_id, " ", prevfeature, " ", result, " ", "=>", " ", current_id, " ", name," ", int(float(threshold)), sep='')
                print("table_add MyIngress.TCPlevel_", depth, " MyIngress.CheckFeatureTCP ", previous_id, " ", prevfeature, " ", result, " ", "=>", " ", current_id, " ", name," ", int(float(threshold)), sep='')

                print_tree_recurse(tree_.children_left[node], depth+1, name, 1, current_id)

                export_text.report += left_child_fmt.format(indent,
                                                            name,
                                                            threshold)
                export_text.report += info_fmt_right
           #     print("level", depth, "checkfeature", prevfeature, result, "=>", name, threshold)
 

                print_tree_recurse(tree_.children_right[node], depth+1, name, 0, current_id)
            else:  # leaf
                _add_leaf(value, class_name, indent, prevfeature, result, depth, previous_id)
        else:
            subtree_depth = _compute_depth(tree_, node)
            if subtree_depth == 1:
                _add_leaf(value, class_name, indent, prevfeature, result, depth, previous_id)
            else:
                trunc_report = 'truncated branch of depth %d' % subtree_depth
                export_text.report += truncation_fmt.format(indent,
                                                            trunc_report)

    print_tree_recurse(0, 1, 0, 1, global_id)


for tree_in_forest in rf.estimators_:
  #r = export_text(tree_in_forest)
  #print(r)
  global i_tree

  i_tree = i_tree + 1
  export_p4(tree_in_forest)
# Out:
# table_add MyIngress.TCPlevel_1 MyIngress.CheckFeatureTCP 0 0 1 => 1 7 64
# table_add MyIngress.TCPlevel_2 MyIngress.CheckFeatureTCP 1 7 1 => 2 7 54
# table_add MyIngress.TCPlevel_3 MyIngress.CheckFeatureTCP 2 7 1 => 3 9 0
# table_add MyIngress.TCPlevel_4 MyIngress.CheckFeatureTCP 3 9 1 => 4 3 122
# table_add MyIngress.TCPlevel_5 MyIngress.CheckFeatureTCP 4 3 1 => 5 6 1
# table_add MyIngress.TCPlevel_6 MyIngress.CheckFeatureTCP 5 6 1 => 6 2 1
# table_add MyIngress.TCPlevel_7 MyIngress.CheckFeatureTCP 6 2 1 => 7 1 1
# table_add MyIngress.TCPlevel_8 MyIngress.CheckFeatureTCP 7 1 1 => 8 8 0
# table_add MyIngress.TCPlevel_9 MyIngress.CheckFeatureTCP 8 8 1 => 9 3 44
# table_add MyIngress.TCPlevel_10 MyIngress.SetClassTCP 9 3 1 => 10 1
# table_add MyIngress.TCPlevel_10 MyIngress.CheckFeatureTCP
# table_add MyIngress.TCPlevel_10 MyIngress.CheckFeatureTCP 399 12 1 => 400 5 9
# table_add MyIngress.TCPlevel_11 MyIngress.SetClassTCP 400 5 1 => 401 1
# table_add MyIngress.TCPlevel_11 MyIngress.SetClassTCP 400 5 0 => 402 1
# table_add MyIngress.TCPlevel_10 MyIngress.SetClassTCP 399 12 0 => 403 1
# table_add MyIngress.TCPlevel_9 MyIngress.SetClassTCP 398 0 0 => 404 1
# table_add MyIngress.TCPlevel_8 MyIngress.SetClassTCP 397 1 0 => 405 1
# table_add MyIngress.TCPlevel_6 MyIngress.CheckFeatureTCP 380 0 0 => 406 0 1921
# table_add MyIngress.TCPlevel_7 MyIngress.SetClassTCP 406 0 1 => 407 1
# table_add MyIngress.TCPlevel_7 MyIngress.CheckFeatureTCP 406 0 0 => 408 0 1925
# table_add MyIngress.TCPlevel_8 MyIngress.SetClassTCP 408 0 1 => 409 0
# table_add MyIngress.TCPlevel_8 MyIngress.CheckFeatureTCP 408 0 0 => 410 5 5
# table_add MyIngress.TCPlevel_9 MyIngress.CheckFeatureTCP 410 5 1 => 411 6 11
# table_add MyIngress.TCPlevel_10 MyIngress.SetClassTCP 411 6 1 => 412 1
# table_add MyIngress.TCPlevel_10 MyIngress.SetClassTCP 411 6 0 => 413 0
# table_add MyIngress.TCPlevel_9 MyIngress.CheckFeatureTCP 410 5 0 => 414 6 18
# table_add MyIngress.TCPlevel_10 MyIngress.CheckFeatureTCP 414 6 1 => 415 7 380
# table_add MyIngress.TCPlevel_11 MyIngress.SetClassTCP 415 7 1 => 416 1
# table_add MyIngress.TCPlevel_11 MyIngress.SetClassTCP 415 7 0 => 417 1
# table_add MyIngress.TCPlevel_10 MyIngress.SetClassTCP 414 6 0 => 418 1
# table_add MyIngress.TCPlevel_4 MyIngress.CheckFeatureTCP 373 2 0 => 419 11 0
# table_add MyIngress.TCPlevel_5 MyIngress.CheckFeatureTCP 419 11 1 => 420 6 19
# table_add MyIngress.TCPlevel_6 MyIngress.CheckFeatureTCP 420 6 1 => 421 7 192
# table_add MyIngress.TCPlevel_7 MyIngress.CheckFeatureTCP 421 7 1 => 422 1 5
# table_add MyIngress.TCPlevel_8 MyIngress.SetClassTCP 422 1 1 => 423 1
# table_add MyIngress.TCPlevel_8 MyIngress.CheckFeatureTCP 422 1 0 => 424 5 7
# table_add MyIngress.TCPlevel_9 MyIngress.SetClassTCP 424 5 1 => 425 0
# table_add MyIngress.TCPlevel_9 MyIngress.SetClassTCP 424 5 0 => 426 1
# table_add MyIngress.TCPlevel_7 MyIngress.CheckFeatureTCP 421 7 0 => 427 0 6311
# table_add MyIngress.TCPlevel_8 MyIngress.SetClassTCP 427 0 1 => 428 0
# table_add MyIngress.TCPlevel_8 MyIngress.SetClassTCP 427 0 0 => 429 1
# table_add MyIngress.TCPlevel_6 MyIngress.CheckFeatureTCP 420 6 0 => 430 5 17
# table_add MyIngress.TCPlevel_7 MyIngress.SetClassTCP 430 5 1 => 431 0
# table_add MyIngress.TCPlevel_7 MyIngress.SetClassTCP 430 5 0 => 432 1
# table_add MyIngress.TCPlevel_5 MyIngress.CheckFeatureTCP 419 11 0 => 433 2 5
# table_add MyIngress.TCPlevel_6 MyIngress.CheckFeatureTCP 433 2 1 => 434 1 5
# table_add MyIngress.TCPlevel_7 MyIngress.CheckFeatureTCP 434 1 1 => 435 5 13
# table_add MyIngress.TCPlevel_8 MyIngress.SetClassTCP 435 5 1 => 436 0
# table_add MyIngress.TCPlevel_8 MyIngress.SetClassTCP 435 5 0 => 437 1
# table_add MyIngress.TCPlevel_7 MyIngress.SetClassTCP 434 1 0 => 438 1
# table_add MyIngress.TCPlevel_6 MyIngress.CheckFeatureTCP 433 2 0 => 439 6 19
# table_add MyIngress.TCPlevel_7 MyIngress.CheckFeatureTCP 439 6 1 => 440 1 13
# table_add MyIngress.TCPlevel_8 MyIngress.CheckFeatureTCP 440 1 1 => 441 3 149
# table_add MyIngress.TCPlevel_9 MyIngress.CheckFeatureTCP 441 3 1 => 442 7 781
# table_add MyIngress.TCPlevel_10 MyIngress.SetClassTCP 442 7 1 => 443 0
# table_add MyIngress.TCPlevel_10 MyIngress.SetClassTCP 442 7 0 => 444 1
# table_add MyIngress.TCPlevel_9 MyIngress.SetClassTCP 441 3 0 => 445 0
# table_add MyIngress.TCPlevel_8 MyIngress.SetClassTCP 440 1 0 => 446 1
# table_add MyIngress.TCPlevel_7 MyIngress.CheckFeatureTCP 439 6 0 => 447 6 42
# table_add MyIngress.TCPlevel_8 MyIngress.CheckFeatureTCP 447 6 1 => 448 1 13
# table_add MyIngress.TCPlevel_9 MyIngress.CheckFeatureTCP 448 1 1 => 449 7 411
# table_add MyIngress.TCPlevel_10 MyIngress.SetClassTCP 449 7 1 => 450 0
# table_add MyIngress.TCPlevel_10 MyIngress.SetClassTCP 449 7 0 => 451 1
# table_add MyIngress.TCPlevel_9 MyIngress.CheckFeatureTCP 448 1 0 => 452 2 13
# table_add MyIngress.TCPlevel_10 MyIngress.SetClassTCP 452 2 1 => 453 0
# table_add MyIngress.TCPlevel_10 MyIngress.SetClassTCP 452 2 0 => 454 1
# table_add MyIngress.TCPlevel_8 MyIngress.SetClassTCP 447 6 0 => 455 1

# %% [markdown]
# # Now predicting about separatly processes data

# %%
current_path = os.getcwd()

file1='dataset/Benign_Test_1.csv'
benign = pd.read_csv(file1)
file2='dataset/RSTFIN_Test.csv'
rst = pd.read_csv(file2)
file3='dataset/TCPFlood.csv'
tcp = pd.read_csv(file3)
file4='dataset/SYN_Test.csv'
file5='dataset/HTTPFlood_Test.csv'
http = pd.read_csv(file5)
file6='dataset/SlowLoris_Test.csv'
slow = pd.read_csv(file6)
file7='dataset/PUSHACK_Test.csv'
psh = pd.read_csv(file7)
file8='dataset/ACKFrag_Test.csv'
ack = pd.read_csv(file8)

benign = benign[(benign['proto_type'] == 6)]
benign['attack'] = 0
rst['attack'] = 1
tcp['attack'] = 1
syn['attack'] = 1
ack['attack'] = 1
psh['attack'] = 1
http['attack'] = 1
slow['attack'] = 1

# %%
data = pd.concat([benign])
print(data.columns)
# Out:
# Index(['ts', 'srcip', 'dstip', 'srcport', 'dstport', 'proto_type', 'sbytes',
#        'dbytes', 'flow_bytes', 'rate', 'srate', 'drate', 'spkts', 'dpkts',
#        'ttl', 'iat', 'max_iat', 'min_iat', 'total_duration',
#        'N_IN_Conn_P_Src_IP', 'N_IN_Conn_P_Dst_IP', 'avg_pkt_len', 'state_con',
#        'state_int', 'state_rst', 'fin_flag_number', 'syn_flag_number',
#        'psh_flag_number', 'ack_flag_number', 'urg_flag_number',
#        'ece_flag_number', 'cwr_flag_number', 'attack'],
#       dtype='object')

# %% [markdown]
# # Test Benign

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_fscore_support

data = pd.concat([benign])
best_features = data[features]
target_features = data[['attack']]
prediction = rf.predict(best_features)
print("Accuracy:", 1- sum(prediction)/len(prediction))
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(target_features, prediction)
# Print the results for each class
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", fscore)
print("Support: ", support)
# Out:
# Accuracy: 0.998998998998999
# Precision:  [1. 0.]
# Recall:  [0.998999 0.      ]
# F1-score:  [0.99949925 0.        ]
# Support:  [999   0]
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # Test SYN Flood

# %%
data = pd.concat([syn])
best_features = data[features]
target_features = data[['attack']]
prediction = rf.predict(best_features)
print("Accuracy: ", sum(prediction)/len(prediction))
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(target_features, prediction)
# Print the results for each class
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", fscore)
print("Support: ", support)
# Out:
# Accuracy:  0.9764658598669227
# Precision:  [0. 1.]
# Recall:  [0.         0.97646586]
# F1-score:  [0.         0.98809282]
# Support:  [    0 44786]
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # TCP PUSH ACK

# %%
data = pd.concat([psh])
best_features = data[features]
target_features = data[['attack']]
prediction = rf.predict(best_features)
print("Accuracy: ", sum(prediction)/len(prediction))
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(target_features, prediction)
# Print the results for each class
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", fscore)
print("Support: ", support)
# Out:
# Accuracy:  0.9992763283184155
# Precision:  [0. 1.]
# Recall:  [0.         0.99927633]
# F1-score:  [0.         0.99963803]
# Support:  [    0 26255]
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # TCP ACK Fragmentation

# %%
data = pd.concat([ack])
best_features = data[features]
target_features = data[['attack']]
prediction = rf.predict(best_features)
print("Accuracy: ", sum(prediction)/len(prediction))
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(target_features, prediction)
# Print the results for each class
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", fscore)
print("Support: ", support)
# Out:
# Accuracy:  0.9640035118525022
# Precision:  [0. 1.]
# Recall:  [0.         0.96400351]
# F1-score:  [0.         0.98167188]
# Support:  [   0 1139]
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # Test TCP DoS

# %%
data = pd.concat([tcp])
best_features = data[features]
target_features = data[['attack']]
prediction = rf.predict(best_features)
print("Accuracy:", sum(prediction)/len(prediction))
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(target_features, prediction)
# Print the results for each class
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", fscore)
print("Support: ", support)
# Out:
# Accuracy: 0.998291939802419
# Precision:  [0. 1.]
# Recall:  [0.         0.99829194]
# F1-score:  [0.         0.99914524]
# Support:  [    0 43324]
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # Test RST FIN Flood

# %%
data = pd.concat([rst])
best_features = data[features]
target_features = data[['attack']]
prediction = rf.predict(best_features)
print("Accuracy: ", sum(prediction)/len(prediction))
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(target_features, prediction)
# Print the results for each class
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", fscore)
print("Support: ", support)
# Out:
# Accuracy:  0.9957322175732217
# Precision:  [0. 1.]
# Recall:  [0.         0.99573222]
# F1-score:  [0.         0.99786155]
# Support:  [    0 11950]
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # Test HTTP Flood

# %%
data = pd.concat([http])
best_features = data[features]
target_features = data[['attack']]
prediction = rf.predict(best_features)
print("Accuracy:",  sum(prediction)/len(prediction))
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(target_features, prediction)
# Print the results for each class
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", fscore)
print("Support: ", support)
# Out:
# Accuracy: 0.9168842471714534
# Precision:  [0. 1.]
# Recall:  [0.         0.91688425]
# F1-score:  [0.         0.95664018]
# Support:  [   0 2298]
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # Test Slowloris

# %%
data = pd.concat([slow])
best_features = data[features]
target_features = data[['attack']]
prediction = rf.predict(best_features)
print("Accuracy:",  sum(prediction)/len(prediction))
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(target_features, prediction)
# Print the results for each class
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", fscore)
print("Support: ", support)
# Out:
# Accuracy: 0.8771222410865874
# Precision:  [0. 1.]
# Recall:  [0.         0.87712224]
# F1-score:  [0.         0.93453929]
# Support:  [   0 4712]
# C:\Users\MRAdmin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
